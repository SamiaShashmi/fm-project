# %%
import scanpy as sc
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.append(str(Path.cwd().parent))
from utils.adata import *
from utils.latent import *
from utils.plot import *
from utils.evaluation import *
import json
from sklearn.neighbors import NearestNeighbors
from umap import UMAP
import torch
import torch.nn.functional as F
import anndata
from torch import nn
from torch.utils.data import Dataset, DataLoader
from sklearn.decomposition import PCA
import scvi

# %%
adata = sc.read_h5ad("../data/thymocyte.h5ad")

# %%
plot_umap(adata, ['cell_type', 'dpt_pseudotime'])
# Out:
# /mnt/home/islamsa3/anaconda3/envs/global/lib/python3.10/site-packages/scanpy/neighbors/__init__.py:577: UserWarning: You’re trying to run this on 2000 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
#   x = _choose_representation(self._adata, use_rep=use_rep, n_pcs=n_pcs)
# /mnt/home/islamsa3/anaconda3/envs/global/lib/python3.10/site-packages/numba/np/ufunc/parallel.py:371: NumbaWarning: The TBB threading layer requires TBB version 2021 update 6 or later i.e., TBB_INTERFACE_VERSION >= 12060. Found TBB_INTERFACE_VERSION = 12050. The TBB threading layer is disabled.
#   warnings.warn(problem)

# %%
scvi.model.SCVI.setup_anndata(
    adata,
    layer=None,            
)

model = scvi.model.SCVI(adata, n_latent=512, n_layers=4, n_hidden=1024)   
model.train()
# Out:
# /mnt/home/islamsa3/.local/lib/python3.10/site-packages/lightning/fabric/plugins/environments/slurm.py:168: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python /mnt/home/islamsa3/.local/lib/python3.10/site-packag ...
#   rank_zero_warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /mnt/home/islamsa3/.local/lib/python3.10/site-packages/lightning/fabric/plugins/environments/slurm.py:168: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python /mnt/home/islamsa3/.local/lib/python3.10/site-packag ...
#   rank_zero_warn(
# You are using a CUDA device ('NVIDIA H200') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Training:   0%|          | 0/400 [00:00<?, ?it/s]
# /mnt/home/islamsa3/anaconda3/envs/global/lib/python3.10/site-packages/scvi/distributions/_negative_binomial.py:93: UserWarning: No PYTORCH_KERNEL_CACHE_PATH or HOME environment variable set! This disables kernel caching. (Triggered internally at ../aten/src/ATen/native/cuda/jit_utils.cpp:1426.)
#   + lgamma(x + theta)
# `Trainer.fit` stopped: `max_epochs=400` reached.

# %%
adata.obsm["X_scVI"] = model.get_latent_representation()

# %%
z_E = adata.obsm['X_scVI'][0]
z_M = adata.obsm['X_scVI'][-1]
X_latent = adata.obsm["X_scVI"]

# %%
Z_interp = interpolate(z_E, z_M, 200)
Z_interp = [tensor.numpy().squeeze() for tensor in Z_interp]
Z_interp = np.stack(Z_interp, axis=0)
Z_interp = Z_interp[::-1, :]

# %%
X_expr = adata.X
if not isinstance(X_expr, np.ndarray):
    X_expr = X_expr.todense() 
X_expr = X_expr.astype(np.float32)                               

n_cells, latent_dim = X_latent.shape
_, n_genes = X_expr.shape
print(latent_dim, n_genes)
# Out:
# 512 2000

# %%
idx = np.arange(n_cells)
np.random.shuffle(idx)
split = int(0.8 * n_cells)
train_idx, val_idx = idx[:split], idx[split:]

train_ds = LatentToExprDataset(X_latent[train_idx], X_expr[train_idx])
val_ds   = LatentToExprDataset(X_latent[val_idx],   X_expr[val_idx])

train_loader = DataLoader(train_ds, batch_size=256, shuffle=True)
val_loader   = DataLoader(val_ds, batch_size=256, shuffle=False)

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

decoder = LatentToGeneMLP(
    latent_dim=latent_dim,
    hidden_dim=1024,
    n_genes=n_genes
).to(device)

optimizer = torch.optim.Adam(decoder.parameters(), lr=1e-3, weight_decay=1e-5)
criterion = nn.MSELoss()

# %%
n_epochs = 1000

for epoch in range(n_epochs):
    decoder.train()
    train_loss = 0.0

    for z_batch, x_batch in train_loader:
        z_batch = z_batch.to(device)
        x_batch = x_batch.to(device)

        optimizer.zero_grad()
        x_pred = decoder(z_batch)
        loss = criterion(x_pred, x_batch)
        loss.backward()
        optimizer.step()

        train_loss += loss.item() * z_batch.size(0)

    train_loss /= len(train_ds)

    # validation
    decoder.eval()
    val_loss = 0.0
    with torch.no_grad():
        for z_batch, x_batch in val_loader:
            z_batch = z_batch.to(device)
            x_batch = x_batch.to(device)
            x_pred = decoder(z_batch)
            loss = criterion(x_pred, x_batch)
            val_loss += loss.item() * z_batch.size(0)
    val_loss /= len(val_ds)

    print(f"Epoch {epoch+1:02d} | train MSE: {train_loss:.4f} | val MSE: {val_loss:.4f}")
# Out:
# Epoch 01 | train MSE: 4.6328 | val MSE: 2.3170
# Epoch 02 | train MSE: 2.1845 | val MSE: 1.9553
# Epoch 03 | train MSE: 1.8429 | val MSE: 1.6849
# Epoch 04 | train MSE: 1.5785 | val MSE: 1.4613
# Epoch 05 | train MSE: 1.3956 | val MSE: 1.3320
# Epoch 06 | train MSE: 1.2813 | val MSE: 1.2894
# Epoch 07 | train MSE: 1.2210 | val MSE: 1.1871
# Epoch 08 | train MSE: 1.1774 | val MSE: 1.1638
# Epoch 09 | train MSE: 1.1533 | val MSE: 1.1466
# Epoch 10 | train MSE: 1.1374 | val MSE: 1.1294
# Epoch 11 | train MSE: 1.1203 | val MSE: 1.1123
# Epoch 12 | train MSE: 1.0948 | val MSE: 1.0993
# Epoch 13 | train MSE: 1.0852 | val MSE: 1.1107
# Epoch 14 | train MSE: 1.0765 | val MSE: 1.0826
# Epoch 15 | train MSE: 1.0595 | val MSE: 1.0849
# Epoch 16 | train MSE: 1.0521 | val MSE: 1.0661
# Epoch 17 | train MSE: 1.0452 | val MSE: 1.0706
# Epoch 18 | train MSE: 1.0424 | val MSE: 1.0617
# Epoch 19 | train MSE: 1.0437 | val MSE: 1.0562
# Epoch 20 | train MSE: 1.0314 | val MSE: 1.0578
# Epoch 21 | train MSE: 1.0252 | val MSE: 1.0651
# Epoch 22 | train MSE: 1.0229 | val MSE: 1.0503
# Epoch 23 | train MSE: 1.0112 | val MSE: 1.0511
# Epoch 24 | train MSE: 1.0249 | val MSE: 1.0398
# Epoch 25 | train MSE: 1.0062 | val MSE: 1.0468
# Epoch 26 | train MSE: 1.0017 | val MSE: 1.0440
# Epoch 27 | train MSE: 0.9958 | val MSE: 1.0206
# Epoch 28 | train MSE: 0.9935 | val MSE: 1.0280
# Epoch 29 | train MSE: 1.0003 | val MSE: 1.0763
# Epoch 30 | train MSE: 0.9885 | val MSE: 1.0400
# Epoch 31 | train MSE: 0.9854 | val MSE: 1.0292
# Epoch 32 | train MSE: 0.9800 | val MSE: 1.0318
# Epoch 33 | train MSE: 0.9905 | val MSE: 1.0462
# Epoch 34 | train MSE: 0.9793 | val MSE: 1.0283
# Epoch 35 | train MSE: 0.9760 | val MSE: 1.0351
# Epoch 36 | train MSE: 0.9757 | val MSE: 1.0207
# Epoch 37 | train MSE: 0.9675 | val MSE: 1.0187
# Epoch 38 | train MSE: 0.9771 | val MSE: 1.0177
# Epoch 39 | train MSE: 0.9728 | val MSE: 1.0252
# Epoch 40 | train MSE: 0.9683 | val MSE: 1.0082
# Epoch 41 | train MSE: 0.9610 | val MSE: 1.0175
# Epoch 42 | train MSE: 0.9613 | val MSE: 1.0197
# Epoch 43 | train MSE: 0.9588 | val MSE: 1.0036
# Epoch 44 | train MSE: 0.9560 | val MSE: 1.0305
# Epoch 45 | train MSE: 0.9558 | val MSE: 1.0167
# Epoch 46 | train MSE: 0.9568 | val MSE: 1.0164
# Epoch 47 | train MSE: 0.9496 | val MSE: 1.0101
# Epoch 48 | train MSE: 0.9476 | val MSE: 1.0047
# Epoch 49 | train MSE: 0.9504 | val MSE: 1.0064
# Epoch 50 | train MSE: 0.9523 | val MSE: 1.0241
# Epoch 51 | train MSE: 0.9458 | val MSE: 1.0156
# Epoch 52 | train MSE: 0.9514 | val MSE: 1.0148
# Epoch 53 | train MSE: 0.9450 | val MSE: 1.0117
# Epoch 54 | train MSE: 0.9422 | val MSE: 1.0156
# Epoch 55 | train MSE: 0.9506 | val MSE: 1.0095
# Epoch 56 | train MSE: 0.9396 | val MSE: 1.0050
# Epoch 57 | train MSE: 0.9325 | val MSE: 1.0010
# Epoch 58 | train MSE: 0.9373 | val MSE: 1.0015
# Epoch 59 | train MSE: 0.9299 | val MSE: 1.0098
# Epoch 60 | train MSE: 0.9348 | val MSE: 1.0051
# Epoch 61 | train MSE: 0.9277 | val MSE: 0.9939
# Epoch 62 | train MSE: 0.9281 | val MSE: 1.0004
# Epoch 63 | train MSE: 0.9257 | val MSE: 0.9989
# Epoch 64 | train MSE: 0.9180 | val MSE: 1.0079
# Epoch 65 | train MSE: 0.9246 | val MSE: 1.0049
# Epoch 66 | train MSE: 0.9259 | val MSE: 1.0293
# Epoch 67 | train MSE: 0.9275 | val MSE: 1.0183
# Epoch 68 | train MSE: 0.9180 | val MSE: 1.0333
# Epoch 69 | train MSE: 0.9178 | val MSE: 1.0019
# Epoch 70 | train MSE: 0.9173 | val MSE: 1.0165
# Epoch 71 | train MSE: 0.9244 | val MSE: 1.0020
# Epoch 72 | train MSE: 0.9156 | val MSE: 1.0099
# Epoch 73 | train MSE: 0.9130 | val MSE: 1.0028
# Epoch 74 | train MSE: 0.9298 | val MSE: 1.0249
# Epoch 75 | train MSE: 0.9152 | val MSE: 0.9966
# Epoch 76 | train MSE: 0.9091 | val MSE: 1.0040
# Epoch 77 | train MSE: 0.9133 | val MSE: 1.0104
# Epoch 78 | train MSE: 0.9109 | val MSE: 1.0034
# Epoch 79 | train MSE: 0.9094 | val MSE: 1.0250
# Epoch 80 | train MSE: 0.9069 | val MSE: 1.0075
# Epoch 81 | train MSE: 0.9053 | val MSE: 0.9974
# Epoch 82 | train MSE: 0.9079 | val MSE: 0.9911
# Epoch 83 | train MSE: 0.9026 | val MSE: 1.0075
# Epoch 84 | train MSE: 0.8940 | val MSE: 0.9921
# Epoch 85 | train MSE: 0.9051 | val MSE: 0.9946
# Epoch 86 | train MSE: 0.9046 | val MSE: 1.0218
# Epoch 87 | train MSE: 0.9250 | val MSE: 1.0144
# Epoch 88 | train MSE: 0.8999 | val MSE: 0.9969
# Epoch 89 | train MSE: 0.9000 | val MSE: 0.9880
# Epoch 90 | train MSE: 0.9069 | val MSE: 0.9971
# Epoch 91 | train MSE: 0.8981 | val MSE: 0.9889
# Epoch 92 | train MSE: 0.8903 | val MSE: 1.0002
# Epoch 93 | train MSE: 0.8926 | val MSE: 1.0009
# Epoch 94 | train MSE: 0.8962 | val MSE: 0.9984
# Epoch 95 | train MSE: 0.9008 | val MSE: 1.0011
# Epoch 96 | train MSE: 0.9075 | val MSE: 0.9877
# Epoch 97 | train MSE: 0.8964 | val MSE: 1.0102
# Epoch 98 | train MSE: 0.8924 | val MSE: 0.9849
# Epoch 99 | train MSE: 0.8869 | val MSE: 0.9980
# Epoch 100 | train MSE: 0.8871 | val MSE: 1.0003
# Epoch 101 | train MSE: 0.8825 | val MSE: 0.9880
# Epoch 102 | train MSE: 0.8861 | val MSE: 0.9906
# Epoch 103 | train MSE: 0.8953 | val MSE: 0.9845
# Epoch 104 | train MSE: 0.8840 | val MSE: 0.9885
# Epoch 105 | train MSE: 0.8804 | val MSE: 0.9853
# Epoch 106 | train MSE: 0.8841 | val MSE: 1.0030
# Epoch 107 | train MSE: 0.8808 | val MSE: 0.9891
# Epoch 108 | train MSE: 0.8841 | val MSE: 0.9917
# Epoch 109 | train MSE: 0.8832 | val MSE: 0.9998
# Epoch 110 | train MSE: 0.8892 | val MSE: 0.9929
# Epoch 111 | train MSE: 0.8808 | val MSE: 1.0002
# Epoch 112 | train MSE: 0.8827 | val MSE: 0.9894
# Epoch 113 | train MSE: 0.8787 | val MSE: 1.0065
# Epoch 114 | train MSE: 0.8821 | val MSE: 0.9907
# Epoch 115 | train MSE: 0.8767 | val MSE: 0.9967
# Epoch 116 | train MSE: 0.8810 | val MSE: 1.0232
# Epoch 117 | train MSE: 0.8784 | val MSE: 1.0017
# Epoch 118 | train MSE: 0.8751 | val MSE: 0.9857
# Epoch 119 | train MSE: 0.8724 | val MSE: 0.9871
# Epoch 120 | train MSE: 0.8724 | val MSE: 0.9942
# Epoch 121 | train MSE: 0.8740 | val MSE: 0.9844
# Epoch 122 | train MSE: 0.8768 | val MSE: 0.9854
# Epoch 123 | train MSE: 0.8788 | val MSE: 0.9868
# Epoch 124 | train MSE: 0.8757 | val MSE: 0.9956
# Epoch 125 | train MSE: 0.8721 | val MSE: 0.9955
# Epoch 126 | train MSE: 0.8770 | val MSE: 0.9787
# Epoch 127 | train MSE: 0.8735 | val MSE: 0.9988
# Epoch 128 | train MSE: 0.8675 | val MSE: 0.9958
# Epoch 129 | train MSE: 0.8758 | val MSE: 0.9853
# Epoch 130 | train MSE: 0.8681 | val MSE: 0.9912
# Epoch 131 | train MSE: 0.8738 | val MSE: 1.0047
# Epoch 132 | train MSE: 0.8745 | val MSE: 0.9858
# Epoch 133 | train MSE: 0.8821 | val MSE: 1.0034
# Epoch 134 | train MSE: 0.8693 | val MSE: 0.9965
# Epoch 135 | train MSE: 0.8674 | val MSE: 0.9890
# Epoch 136 | train MSE: 0.8684 | val MSE: 0.9852
# Epoch 137 | train MSE: 0.8666 | val MSE: 0.9888
# Epoch 138 | train MSE: 0.8684 | val MSE: 0.9981
# Epoch 139 | train MSE: 0.8749 | val MSE: 1.0063
# Epoch 140 | train MSE: 0.8631 | val MSE: 0.9933
# Epoch 141 | train MSE: 0.8693 | val MSE: 1.0124
# Epoch 142 | train MSE: 0.8600 | val MSE: 1.0160
# Epoch 143 | train MSE: 0.8617 | val MSE: 1.0027
# Epoch 144 | train MSE: 0.8616 | val MSE: 0.9967
# Epoch 145 | train MSE: 0.8621 | val MSE: 1.0119
# Epoch 146 | train MSE: 0.8653 | val MSE: 0.9868
# Epoch 147 | train MSE: 0.8514 | val MSE: 0.9813
# Epoch 148 | train MSE: 0.8612 | val MSE: 0.9994
# Epoch 149 | train MSE: 0.8590 | val MSE: 0.9855
# Epoch 150 | train MSE: 0.8590 | val MSE: 0.9875
# Epoch 151 | train MSE: 0.8618 | val MSE: 1.0043
# Epoch 152 | train MSE: 0.8631 | val MSE: 1.0001
# Epoch 153 | train MSE: 0.8548 | val MSE: 1.0059
# Epoch 154 | train MSE: 0.8581 | val MSE: 1.0028
# Epoch 155 | train MSE: 0.8620 | val MSE: 0.9934
# Epoch 156 | train MSE: 0.8552 | val MSE: 0.9798
# Epoch 157 | train MSE: 0.8543 | val MSE: 0.9825
# Epoch 158 | train MSE: 0.8576 | val MSE: 0.9857
# Epoch 159 | train MSE: 0.8633 | val MSE: 0.9921
# Epoch 160 | train MSE: 0.8519 | val MSE: 0.9956
# Epoch 161 | train MSE: 0.8532 | val MSE: 1.0012
# Epoch 162 | train MSE: 0.8625 | val MSE: 1.0114
# Epoch 163 | train MSE: 0.8630 | val MSE: 0.9841
# Epoch 164 | train MSE: 0.8562 | val MSE: 0.9924
# Epoch 165 | train MSE: 0.8498 | val MSE: 0.9976
# Epoch 166 | train MSE: 0.8542 | val MSE: 1.0099
# Epoch 167 | train MSE: 0.8536 | val MSE: 0.9926
# Epoch 168 | train MSE: 0.8501 | val MSE: 0.9950
# Epoch 169 | train MSE: 0.8491 | val MSE: 0.9908
# Epoch 170 | train MSE: 0.8522 | val MSE: 0.9995
# Epoch 171 | train MSE: 0.8668 | val MSE: 0.9886
# Epoch 172 | train MSE: 0.8629 | val MSE: 0.9982
# Epoch 173 | train MSE: 0.8590 | val MSE: 0.9941
# Epoch 174 | train MSE: 0.8473 | val MSE: 0.9826
# Epoch 175 | train MSE: 0.8489 | val MSE: 0.9986
# Epoch 176 | train MSE: 0.8500 | val MSE: 0.9938
# Epoch 177 | train MSE: 0.8481 | val MSE: 0.9824
# Epoch 178 | train MSE: 0.8417 | val MSE: 0.9996
# Epoch 179 | train MSE: 0.8542 | val MSE: 0.9992
# Epoch 180 | train MSE: 0.8455 | val MSE: 0.9988
# Epoch 181 | train MSE: 0.8550 | val MSE: 1.0007
# Epoch 182 | train MSE: 0.8538 | val MSE: 0.9913
# Epoch 183 | train MSE: 0.8479 | val MSE: 0.9909
# Epoch 184 | train MSE: 0.8454 | val MSE: 0.9890
# Epoch 185 | train MSE: 0.8426 | val MSE: 1.0241
# Epoch 186 | train MSE: 0.8456 | val MSE: 0.9931
# Epoch 187 | train MSE: 0.8401 | val MSE: 0.9835
# Epoch 188 | train MSE: 0.8387 | val MSE: 0.9943
# Epoch 189 | train MSE: 0.8460 | val MSE: 1.0012
# Epoch 190 | train MSE: 0.8433 | val MSE: 0.9940
# Epoch 191 | train MSE: 0.8448 | val MSE: 0.9998
# Epoch 192 | train MSE: 0.8420 | val MSE: 0.9921
# Epoch 193 | train MSE: 0.8506 | val MSE: 1.0161
# Epoch 194 | train MSE: 0.8641 | val MSE: 0.9976
# Epoch 195 | train MSE: 0.8523 | val MSE: 0.9977
# Epoch 196 | train MSE: 0.8424 | val MSE: 0.9984
# Epoch 197 | train MSE: 0.8399 | val MSE: 0.9888
# Epoch 198 | train MSE: 0.8440 | val MSE: 0.9934
# Epoch 199 | train MSE: 0.8394 | val MSE: 0.9993
# Epoch 200 | train MSE: 0.8390 | val MSE: 1.0039
# Epoch 201 | train MSE: 0.8470 | val MSE: 1.0012
# Epoch 202 | train MSE: 0.8490 | val MSE: 1.0057
# Epoch 203 | train MSE: 0.8411 | val MSE: 1.0028
# Epoch 204 | train MSE: 0.8420 | val MSE: 0.9944
# Epoch 205 | train MSE: 0.8395 | val MSE: 1.0011
# Epoch 206 | train MSE: 0.8340 | val MSE: 0.9966
# Epoch 207 | train MSE: 0.8340 | val MSE: 0.9905
# Epoch 208 | train MSE: 0.8369 | val MSE: 1.0059
# Epoch 209 | train MSE: 0.8398 | val MSE: 0.9994
# Epoch 210 | train MSE: 0.8459 | val MSE: 0.9893
# Epoch 211 | train MSE: 0.8312 | val MSE: 0.9931
# Epoch 212 | train MSE: 0.8342 | val MSE: 0.9913
# Epoch 213 | train MSE: 0.8386 | val MSE: 1.0003
# Epoch 214 | train MSE: 0.8373 | val MSE: 0.9997
# Epoch 215 | train MSE: 0.8433 | val MSE: 1.0026
# Epoch 216 | train MSE: 0.8437 | val MSE: 1.0037
# Epoch 217 | train MSE: 0.8401 | val MSE: 1.0099
# Epoch 218 | train MSE: 0.8369 | val MSE: 0.9861
# Epoch 219 | train MSE: 0.8334 | val MSE: 0.9867
# Epoch 220 | train MSE: 0.8434 | val MSE: 1.0008
# Epoch 221 | train MSE: 0.8330 | val MSE: 1.0007
# Epoch 222 | train MSE: 0.8330 | val MSE: 1.0085
# Epoch 223 | train MSE: 0.8292 | val MSE: 0.9923
# Epoch 224 | train MSE: 0.8301 | val MSE: 0.9940
# Epoch 225 | train MSE: 0.8311 | val MSE: 1.0015
# Epoch 226 | train MSE: 0.8257 | val MSE: 0.9858
# Epoch 227 | train MSE: 0.8262 | val MSE: 0.9936
# Epoch 228 | train MSE: 0.8340 | val MSE: 1.0052
# Epoch 229 | train MSE: 0.8287 | val MSE: 0.9949
# Epoch 230 | train MSE: 0.8268 | val MSE: 0.9976
# Epoch 231 | train MSE: 0.8339 | val MSE: 1.0044
# Epoch 232 | train MSE: 0.8243 | val MSE: 0.9969
# Epoch 233 | train MSE: 0.8324 | val MSE: 1.0012
# Epoch 234 | train MSE: 0.8289 | val MSE: 1.0020
# Epoch 235 | train MSE: 0.8375 | val MSE: 0.9895
# Epoch 236 | train MSE: 0.8367 | val MSE: 0.9912
# Epoch 237 | train MSE: 0.8301 | val MSE: 1.0122
# Epoch 238 | train MSE: 0.8376 | val MSE: 1.0023
# Epoch 239 | train MSE: 0.8270 | val MSE: 0.9924
# Epoch 240 | train MSE: 0.8254 | val MSE: 1.0040
# Epoch 241 | train MSE: 0.8286 | val MSE: 0.9895
# Epoch 242 | train MSE: 0.8262 | val MSE: 1.0037
# Epoch 243 | train MSE: 0.8283 | val MSE: 0.9829
# Epoch 244 | train MSE: 0.8248 | val MSE: 0.9987
# Epoch 245 | train MSE: 0.8263 | val MSE: 1.0012
# Epoch 246 | train MSE: 0.8316 | val MSE: 1.0066
# Epoch 247 | train MSE: 0.8258 | val MSE: 1.0201
# Epoch 248 | train MSE: 0.8331 | val MSE: 1.0384
# Epoch 249 | train MSE: 0.8234 | val MSE: 0.9981
# Epoch 250 | train MSE: 0.8200 | val MSE: 0.9920
# Epoch 251 | train MSE: 0.8248 | val MSE: 0.9943
# Epoch 252 | train MSE: 0.8297 | val MSE: 1.0051
# Epoch 253 | train MSE: 0.8173 | val MSE: 1.0011
# Epoch 254 | train MSE: 0.8271 | val MSE: 0.9958
# Epoch 255 | train MSE: 0.8182 | val MSE: 0.9901
# Epoch 256 | train MSE: 0.8253 | val MSE: 0.9928
# Epoch 257 | train MSE: 0.8271 | val MSE: 0.9859
# Epoch 258 | train MSE: 0.8257 | val MSE: 1.0177
# Epoch 259 | train MSE: 0.8276 | val MSE: 1.0176
# Epoch 260 | train MSE: 0.8223 | val MSE: 1.0021
# Epoch 261 | train MSE: 0.8235 | val MSE: 1.0068
# Epoch 262 | train MSE: 0.8279 | val MSE: 0.9905
# Epoch 263 | train MSE: 0.8209 | val MSE: 0.9945
# Epoch 264 | train MSE: 0.8169 | val MSE: 0.9966
# Epoch 265 | train MSE: 0.8136 | val MSE: 1.0141
# Epoch 266 | train MSE: 0.8206 | val MSE: 1.0042
# Epoch 267 | train MSE: 0.8196 | val MSE: 1.0167
# Epoch 268 | train MSE: 0.8280 | val MSE: 1.0030
# Epoch 269 | train MSE: 0.8215 | val MSE: 0.9934
# Epoch 270 | train MSE: 0.8167 | val MSE: 0.9986
# Epoch 271 | train MSE: 0.8193 | val MSE: 1.0138
# Epoch 272 | train MSE: 0.8130 | val MSE: 1.0089
# Epoch 273 | train MSE: 0.8165 | val MSE: 0.9909
# Epoch 274 | train MSE: 0.8166 | val MSE: 1.0019
# Epoch 275 | train MSE: 0.8180 | val MSE: 1.0126
# Epoch 276 | train MSE: 0.8174 | val MSE: 0.9991
# Epoch 277 | train MSE: 0.8148 | val MSE: 1.0047
# Epoch 278 | train MSE: 0.8232 | val MSE: 1.0040
# Epoch 279 | train MSE: 0.8209 | val MSE: 1.0227
# Epoch 280 | train MSE: 0.8144 | val MSE: 0.9943
# Epoch 281 | train MSE: 0.8163 | val MSE: 1.0053
# Epoch 282 | train MSE: 0.8136 | val MSE: 1.0115
# Epoch 283 | train MSE: 0.8133 | val MSE: 1.0031
# Epoch 284 | train MSE: 0.8165 | val MSE: 0.9991
# Epoch 285 | train MSE: 0.8184 | val MSE: 1.0046
# Epoch 286 | train MSE: 0.8129 | val MSE: 1.0002
# Epoch 287 | train MSE: 0.8166 | val MSE: 1.0272
# Epoch 288 | train MSE: 0.8188 | val MSE: 1.0075
# Epoch 289 | train MSE: 0.8076 | val MSE: 1.0095
# Epoch 290 | train MSE: 0.8095 | val MSE: 0.9894
# Epoch 291 | train MSE: 0.8099 | val MSE: 0.9994
# Epoch 292 | train MSE: 0.8184 | val MSE: 1.0055
# Epoch 293 | train MSE: 0.8169 | val MSE: 1.0155
# Epoch 294 | train MSE: 0.8113 | val MSE: 0.9936
# Epoch 295 | train MSE: 0.8109 | val MSE: 0.9966
# Epoch 296 | train MSE: 0.8100 | val MSE: 1.0176
# Epoch 297 | train MSE: 0.8112 | val MSE: 1.0256
# Epoch 298 | train MSE: 0.8138 | val MSE: 0.9947
# Epoch 299 | train MSE: 0.8053 | val MSE: 0.9919
# Epoch 300 | train MSE: 0.8139 | val MSE: 0.9878
# Epoch 301 | train MSE: 0.8116 | val MSE: 1.0056
# Epoch 302 | train MSE: 0.8067 | val MSE: 1.0019
# Epoch 303 | train MSE: 0.8237 | val MSE: 1.0154
# Epoch 304 | train MSE: 0.8080 | val MSE: 1.0013
# Epoch 305 | train MSE: 0.8069 | val MSE: 0.9982
# Epoch 306 | train MSE: 0.8197 | val MSE: 0.9932
# Epoch 307 | train MSE: 0.8050 | val MSE: 0.9998
# Epoch 308 | train MSE: 0.8101 | val MSE: 0.9992
# Epoch 309 | train MSE: 0.8047 | val MSE: 1.0048
# Epoch 310 | train MSE: 0.8090 | val MSE: 0.9972
# Epoch 311 | train MSE: 0.8093 | val MSE: 1.0124
# Epoch 312 | train MSE: 0.8100 | val MSE: 1.0431
# Epoch 313 | train MSE: 0.8112 | val MSE: 0.9924
# Epoch 314 | train MSE: 0.8037 | val MSE: 0.9982
# Epoch 315 | train MSE: 0.8093 | val MSE: 1.0013
# Epoch 316 | train MSE: 0.8053 | val MSE: 1.0023
# Epoch 317 | train MSE: 0.8033 | val MSE: 1.0046
# Epoch 318 | train MSE: 0.8102 | val MSE: 0.9972
# Epoch 319 | train MSE: 0.8045 | val MSE: 1.0238
# Epoch 320 | train MSE: 0.8019 | val MSE: 1.0037
# Epoch 321 | train MSE: 0.8031 | val MSE: 1.0040
# Epoch 322 | train MSE: 0.8053 | val MSE: 0.9990
# Epoch 323 | train MSE: 0.8038 | val MSE: 0.9993
# Epoch 324 | train MSE: 0.8099 | val MSE: 1.0346
# Epoch 325 | train MSE: 0.8090 | val MSE: 1.0070
# Epoch 326 | train MSE: 0.8025 | val MSE: 1.0029
# Epoch 327 | train MSE: 0.8020 | val MSE: 0.9945
# Epoch 328 | train MSE: 0.7975 | val MSE: 1.0082
# Epoch 329 | train MSE: 0.8024 | val MSE: 1.0055
# Epoch 330 | train MSE: 0.8020 | val MSE: 1.0044
# Epoch 331 | train MSE: 0.8006 | val MSE: 1.0047
# Epoch 332 | train MSE: 0.8036 | val MSE: 1.0088
# Epoch 333 | train MSE: 0.8055 | val MSE: 1.0107
# Epoch 334 | train MSE: 0.8026 | val MSE: 1.0092
# Epoch 335 | train MSE: 0.8078 | val MSE: 1.0083
# Epoch 336 | train MSE: 0.8010 | val MSE: 1.0015
# Epoch 337 | train MSE: 0.7984 | val MSE: 1.0095
# Epoch 338 | train MSE: 0.8013 | val MSE: 1.0081
# Epoch 339 | train MSE: 0.8005 | val MSE: 1.0109
# Epoch 340 | train MSE: 0.7942 | val MSE: 1.0094
# Epoch 341 | train MSE: 0.7995 | val MSE: 1.0097
# Epoch 342 | train MSE: 0.8036 | val MSE: 1.0168
# Epoch 343 | train MSE: 0.8117 | val MSE: 1.0149
# Epoch 344 | train MSE: 0.7962 | val MSE: 1.0048
# Epoch 345 | train MSE: 0.7998 | val MSE: 1.0072
# Epoch 346 | train MSE: 0.7941 | val MSE: 0.9958
# Epoch 347 | train MSE: 0.8049 | val MSE: 1.0153
# Epoch 348 | train MSE: 0.7954 | val MSE: 1.0061
# Epoch 349 | train MSE: 0.7978 | val MSE: 1.0243
# Epoch 350 | train MSE: 0.7998 | val MSE: 1.0254
# Epoch 351 | train MSE: 0.8001 | val MSE: 1.0051
# Epoch 352 | train MSE: 0.7950 | val MSE: 1.0183
# Epoch 353 | train MSE: 0.7972 | val MSE: 1.0110
# Epoch 354 | train MSE: 0.7969 | val MSE: 1.0148
# Epoch 355 | train MSE: 0.7994 | val MSE: 1.0161
# Epoch 356 | train MSE: 0.8036 | val MSE: 1.0009
# Epoch 357 | train MSE: 0.7917 | val MSE: 1.0075
# Epoch 358 | train MSE: 0.8024 | val MSE: 1.0154
# Epoch 359 | train MSE: 0.7978 | val MSE: 1.0259
# Epoch 360 | train MSE: 0.7985 | val MSE: 1.0107
# Epoch 361 | train MSE: 0.7960 | val MSE: 1.0227
# Epoch 362 | train MSE: 0.7928 | val MSE: 1.0106
# Epoch 363 | train MSE: 0.7922 | val MSE: 1.0015
# Epoch 364 | train MSE: 0.7940 | val MSE: 1.0121
# Epoch 365 | train MSE: 0.7918 | val MSE: 1.0228
# Epoch 366 | train MSE: 0.7907 | val MSE: 1.0055
# Epoch 367 | train MSE: 0.7903 | val MSE: 1.0390
# Epoch 368 | train MSE: 0.7943 | val MSE: 1.0009
# Epoch 369 | train MSE: 0.7960 | val MSE: 1.0092
# Epoch 370 | train MSE: 0.7997 | val MSE: 1.0397
# Epoch 371 | train MSE: 0.8089 | val MSE: 1.0164
# Epoch 372 | train MSE: 0.7957 | val MSE: 1.0015
# Epoch 373 | train MSE: 0.7924 | val MSE: 1.0065
# Epoch 374 | train MSE: 0.7901 | val MSE: 1.0005
# Epoch 375 | train MSE: 0.7866 | val MSE: 1.0113
# Epoch 376 | train MSE: 0.7971 | val MSE: 1.0411
# Epoch 377 | train MSE: 0.7956 | val MSE: 1.0031
# Epoch 378 | train MSE: 0.7887 | val MSE: 1.0206
# Epoch 379 | train MSE: 0.7877 | val MSE: 1.0029
# Epoch 380 | train MSE: 0.7843 | val MSE: 0.9976
# Epoch 381 | train MSE: 0.7893 | val MSE: 1.0128
# Epoch 382 | train MSE: 0.7896 | val MSE: 1.0109
# Epoch 383 | train MSE: 0.7904 | val MSE: 1.0234
# Epoch 384 | train MSE: 0.8063 | val MSE: 1.0132
# Epoch 385 | train MSE: 0.7879 | val MSE: 1.0097
# Epoch 386 | train MSE: 0.7888 | val MSE: 1.0041
# Epoch 387 | train MSE: 0.7883 | val MSE: 1.0152
# Epoch 388 | train MSE: 0.7843 | val MSE: 1.0024
# Epoch 389 | train MSE: 0.7909 | val MSE: 1.0321
# Epoch 390 | train MSE: 0.7920 | val MSE: 1.0056
# Epoch 391 | train MSE: 0.7909 | val MSE: 1.0077
# Epoch 392 | train MSE: 0.7796 | val MSE: 1.0073
# Epoch 393 | train MSE: 0.7868 | val MSE: 1.0126
# Epoch 394 | train MSE: 0.7801 | val MSE: 1.0215
# Epoch 395 | train MSE: 0.7916 | val MSE: 1.0774
# Epoch 396 | train MSE: 0.7881 | val MSE: 1.0190
# Epoch 397 | train MSE: 0.7893 | val MSE: 1.0265
# Epoch 398 | train MSE: 0.7920 | val MSE: 1.0183
# Epoch 399 | train MSE: 0.7845 | val MSE: 1.0198
# Epoch 400 | train MSE: 0.7791 | val MSE: 1.0039
# Epoch 401 | train MSE: 0.7841 | val MSE: 1.0120
# Epoch 402 | train MSE: 0.7807 | val MSE: 1.0068
# Epoch 403 | train MSE: 0.7827 | val MSE: 1.0552
# Epoch 404 | train MSE: 0.7865 | val MSE: 1.0115
# Epoch 405 | train MSE: 0.7830 | val MSE: 1.0197
# Epoch 406 | train MSE: 0.7869 | val MSE: 1.0101
# Epoch 407 | train MSE: 0.7827 | val MSE: 1.0074
# Epoch 408 | train MSE: 0.7834 | val MSE: 1.0249
# Epoch 409 | train MSE: 0.7886 | val MSE: 1.0169
# Epoch 410 | train MSE: 0.7821 | val MSE: 1.0319
# Epoch 411 | train MSE: 0.7804 | val MSE: 1.0122
# Epoch 412 | train MSE: 0.7816 | val MSE: 1.0157
# Epoch 413 | train MSE: 0.7825 | val MSE: 1.0217
# Epoch 414 | train MSE: 0.7855 | val MSE: 1.0009
# Epoch 415 | train MSE: 0.7817 | val MSE: 1.0138
# Epoch 416 | train MSE: 0.7836 | val MSE: 1.0040
# Epoch 417 | train MSE: 0.7855 | val MSE: 1.0318
# Epoch 418 | train MSE: 0.7817 | val MSE: 1.0433
# Epoch 419 | train MSE: 0.7870 | val MSE: 1.0116
# Epoch 420 | train MSE: 0.7868 | val MSE: 1.0218
# Epoch 421 | train MSE: 0.7838 | val MSE: 1.0115
# Epoch 422 | train MSE: 0.7944 | val MSE: 1.0279
# Epoch 423 | train MSE: 0.7856 | val MSE: 1.0247
# Epoch 424 | train MSE: 0.7790 | val MSE: 1.0177
# Epoch 425 | train MSE: 0.7801 | val MSE: 1.0240
# Epoch 426 | train MSE: 0.7810 | val MSE: 1.0324
# Epoch 427 | train MSE: 0.7833 | val MSE: 1.0261
# Epoch 428 | train MSE: 0.7783 | val MSE: 1.0133
# Epoch 429 | train MSE: 0.7787 | val MSE: 1.0097
# Epoch 430 | train MSE: 0.7802 | val MSE: 1.0394
# Epoch 431 | train MSE: 0.7876 | val MSE: 1.0182
# Epoch 432 | train MSE: 0.7771 | val MSE: 1.0207
# Epoch 433 | train MSE: 0.7766 | val MSE: 1.0172
# Epoch 434 | train MSE: 0.7803 | val MSE: 1.0249
# Epoch 435 | train MSE: 0.7814 | val MSE: 1.0356
# Epoch 436 | train MSE: 0.7783 | val MSE: 1.0080
# Epoch 437 | train MSE: 0.7774 | val MSE: 1.0228
# Epoch 438 | train MSE: 0.7851 | val MSE: 1.0229
# Epoch 439 | train MSE: 0.7817 | val MSE: 1.0188
# Epoch 440 | train MSE: 0.7779 | val MSE: 1.0150
# Epoch 441 | train MSE: 0.7747 | val MSE: 1.0220
# Epoch 442 | train MSE: 0.7763 | val MSE: 1.0238
# Epoch 443 | train MSE: 0.7791 | val MSE: 1.0243
# Epoch 444 | train MSE: 0.7762 | val MSE: 1.0236
# Epoch 445 | train MSE: 0.7818 | val MSE: 1.0279
# Epoch 446 | train MSE: 0.7779 | val MSE: 1.0355
# Epoch 447 | train MSE: 0.7729 | val MSE: 1.0142
# Epoch 448 | train MSE: 0.7761 | val MSE: 1.0098
# Epoch 449 | train MSE: 0.7800 | val MSE: 1.0148
# Epoch 450 | train MSE: 0.7868 | val MSE: 1.0528
# Epoch 451 | train MSE: 0.7743 | val MSE: 1.0166
# Epoch 452 | train MSE: 0.7758 | val MSE: 1.0120
# Epoch 453 | train MSE: 0.7754 | val MSE: 1.0140
# Epoch 454 | train MSE: 0.7710 | val MSE: 1.0114
# Epoch 455 | train MSE: 0.7723 | val MSE: 1.0170
# Epoch 456 | train MSE: 0.7758 | val MSE: 1.0129
# Epoch 457 | train MSE: 0.7719 | val MSE: 1.0140
# Epoch 458 | train MSE: 0.7748 | val MSE: 1.0104
# Epoch 459 | train MSE: 0.7746 | val MSE: 1.0299
# Epoch 460 | train MSE: 0.7717 | val MSE: 1.0481
# Epoch 461 | train MSE: 0.7731 | val MSE: 1.0207
# Epoch 462 | train MSE: 0.7707 | val MSE: 1.0179
# Epoch 463 | train MSE: 0.7728 | val MSE: 1.0153
# Epoch 464 | train MSE: 0.7785 | val MSE: 1.0244
# Epoch 465 | train MSE: 0.7735 | val MSE: 1.0201
# Epoch 466 | train MSE: 0.7689 | val MSE: 1.0341
# Epoch 467 | train MSE: 0.7719 | val MSE: 1.0293
# Epoch 468 | train MSE: 0.7708 | val MSE: 1.0174
# Epoch 469 | train MSE: 0.7749 | val MSE: 1.0181
# Epoch 470 | train MSE: 0.7720 | val MSE: 1.0094
# Epoch 471 | train MSE: 0.7687 | val MSE: 1.0304
# Epoch 472 | train MSE: 0.7784 | val MSE: 1.0258
# Epoch 473 | train MSE: 0.7727 | val MSE: 1.0261
# Epoch 474 | train MSE: 0.7766 | val MSE: 1.0220
# Epoch 475 | train MSE: 0.7736 | val MSE: 1.0416
# Epoch 476 | train MSE: 0.7773 | val MSE: 1.0252
# Epoch 477 | train MSE: 0.7678 | val MSE: 1.0247
# Epoch 478 | train MSE: 0.7685 | val MSE: 1.0180
# Epoch 479 | train MSE: 0.7726 | val MSE: 1.0247
# Epoch 480 | train MSE: 0.7708 | val MSE: 1.0232
# Epoch 481 | train MSE: 0.7719 | val MSE: 1.0182
# Epoch 482 | train MSE: 0.7697 | val MSE: 1.0207
# Epoch 483 | train MSE: 0.7708 | val MSE: 1.0143
# Epoch 484 | train MSE: 0.7721 | val MSE: 1.0379
# Epoch 485 | train MSE: 0.7748 | val MSE: 1.0192
# Epoch 486 | train MSE: 0.7686 | val MSE: 1.0146
# Epoch 487 | train MSE: 0.7690 | val MSE: 1.0205
# Epoch 488 | train MSE: 0.7736 | val MSE: 1.0300
# Epoch 489 | train MSE: 0.7621 | val MSE: 1.0261
# Epoch 490 | train MSE: 0.7633 | val MSE: 1.0278
# Epoch 491 | train MSE: 0.7600 | val MSE: 1.0201
# Epoch 492 | train MSE: 0.7646 | val MSE: 1.0297
# Epoch 493 | train MSE: 0.7611 | val MSE: 1.0245
# Epoch 494 | train MSE: 0.7682 | val MSE: 1.0175
# Epoch 495 | train MSE: 0.7644 | val MSE: 1.0222
# Epoch 496 | train MSE: 0.7646 | val MSE: 1.0468
# Epoch 497 | train MSE: 0.7659 | val MSE: 1.0356
# Epoch 498 | train MSE: 0.7675 | val MSE: 1.0222
# Epoch 499 | train MSE: 0.7716 | val MSE: 1.0554
# Epoch 500 | train MSE: 0.7670 | val MSE: 1.0459
# Epoch 501 | train MSE: 0.7622 | val MSE: 1.0118
# Epoch 502 | train MSE: 0.7640 | val MSE: 1.0252
# Epoch 503 | train MSE: 0.7673 | val MSE: 1.0348
# Epoch 504 | train MSE: 0.7652 | val MSE: 1.0189
# Epoch 505 | train MSE: 0.7645 | val MSE: 1.0350
# Epoch 506 | train MSE: 0.7593 | val MSE: 1.0121
# Epoch 507 | train MSE: 0.7582 | val MSE: 1.0319
# Epoch 508 | train MSE: 0.7630 | val MSE: 1.0465
# Epoch 509 | train MSE: 0.7634 | val MSE: 1.0327
# Epoch 510 | train MSE: 0.7649 | val MSE: 1.0248
# Epoch 511 | train MSE: 0.7595 | val MSE: 1.0275
# Epoch 512 | train MSE: 0.7692 | val MSE: 1.0358
# Epoch 513 | train MSE: 0.7641 | val MSE: 1.0414
# Epoch 514 | train MSE: 0.7618 | val MSE: 1.0331
# Epoch 515 | train MSE: 0.7622 | val MSE: 1.0195
# Epoch 516 | train MSE: 0.7624 | val MSE: 1.0186
# Epoch 517 | train MSE: 0.7614 | val MSE: 1.0536
# Epoch 518 | train MSE: 0.7655 | val MSE: 1.0634
# Epoch 519 | train MSE: 0.7656 | val MSE: 1.0358
# Epoch 520 | train MSE: 0.7649 | val MSE: 1.0490
# Epoch 521 | train MSE: 0.7606 | val MSE: 1.0227
# Epoch 522 | train MSE: 0.7658 | val MSE: 1.0344
# Epoch 523 | train MSE: 0.7660 | val MSE: 1.0328
# Epoch 524 | train MSE: 0.7620 | val MSE: 1.0277
# Epoch 525 | train MSE: 0.7579 | val MSE: 1.0142
# Epoch 526 | train MSE: 0.7640 | val MSE: 1.0206
# Epoch 527 | train MSE: 0.7582 | val MSE: 1.0301
# Epoch 528 | train MSE: 0.7629 | val MSE: 1.0313
# Epoch 529 | train MSE: 0.7654 | val MSE: 1.0391
# Epoch 530 | train MSE: 0.7658 | val MSE: 1.0282
# Epoch 531 | train MSE: 0.7619 | val MSE: 1.0191
# Epoch 532 | train MSE: 0.7567 | val MSE: 1.0390
# Epoch 533 | train MSE: 0.7631 | val MSE: 1.0187
# Epoch 534 | train MSE: 0.7586 | val MSE: 1.0507
# Epoch 535 | train MSE: 0.7632 | val MSE: 1.0311
# Epoch 536 | train MSE: 0.7591 | val MSE: 1.0290
# Epoch 537 | train MSE: 0.7577 | val MSE: 1.0285
# Epoch 538 | train MSE: 0.7573 | val MSE: 1.0125
# Epoch 539 | train MSE: 0.7592 | val MSE: 1.0308
# Epoch 540 | train MSE: 0.7597 | val MSE: 1.0216
# Epoch 541 | train MSE: 0.7569 | val MSE: 1.0222
# Epoch 542 | train MSE: 0.7582 | val MSE: 1.0479
# Epoch 543 | train MSE: 0.7592 | val MSE: 1.0379
# Epoch 544 | train MSE: 0.7624 | val MSE: 1.0491
# Epoch 545 | train MSE: 0.7619 | val MSE: 1.0410
# Epoch 546 | train MSE: 0.7555 | val MSE: 1.0146
# Epoch 547 | train MSE: 0.7546 | val MSE: 1.0236
# Epoch 548 | train MSE: 0.7569 | val MSE: 1.0342
# Epoch 549 | train MSE: 0.7594 | val MSE: 1.0259
# Epoch 550 | train MSE: 0.7506 | val MSE: 1.0326
# Epoch 551 | train MSE: 0.7537 | val MSE: 1.0302
# Epoch 552 | train MSE: 0.7577 | val MSE: 1.0271
# Epoch 553 | train MSE: 0.7524 | val MSE: 1.0259
# Epoch 554 | train MSE: 0.7565 | val MSE: 1.0314
# Epoch 555 | train MSE: 0.7560 | val MSE: 1.0283
# Epoch 556 | train MSE: 0.7501 | val MSE: 1.0592
# Epoch 557 | train MSE: 0.7496 | val MSE: 1.0214
# Epoch 558 | train MSE: 0.7488 | val MSE: 1.0257
# Epoch 559 | train MSE: 0.7543 | val MSE: 1.0432
# Epoch 560 | train MSE: 0.7522 | val MSE: 1.0556
# Epoch 561 | train MSE: 0.7603 | val MSE: 1.0444
# Epoch 562 | train MSE: 0.7619 | val MSE: 1.0561
# Epoch 563 | train MSE: 0.7594 | val MSE: 1.0325
# Epoch 564 | train MSE: 0.7546 | val MSE: 1.0520
# Epoch 565 | train MSE: 0.7548 | val MSE: 1.0530
# Epoch 566 | train MSE: 0.7545 | val MSE: 1.0299
# Epoch 567 | train MSE: 0.7559 | val MSE: 1.0377
# Epoch 568 | train MSE: 0.7584 | val MSE: 1.0300
# Epoch 569 | train MSE: 0.7582 | val MSE: 1.0323
# Epoch 570 | train MSE: 0.7532 | val MSE: 1.0915
# Epoch 571 | train MSE: 0.7509 | val MSE: 1.0296
# Epoch 572 | train MSE: 0.7566 | val MSE: 1.0280
# Epoch 573 | train MSE: 0.7497 | val MSE: 1.0244
# Epoch 574 | train MSE: 0.7543 | val MSE: 1.0550
# Epoch 575 | train MSE: 0.7600 | val MSE: 1.0576
# Epoch 576 | train MSE: 0.7517 | val MSE: 1.0628
# Epoch 577 | train MSE: 0.7505 | val MSE: 1.0320
# Epoch 578 | train MSE: 0.7543 | val MSE: 1.0308
# Epoch 579 | train MSE: 0.7498 | val MSE: 1.0533
# Epoch 580 | train MSE: 0.7536 | val MSE: 1.0261
# Epoch 581 | train MSE: 0.7524 | val MSE: 1.0333
# Epoch 582 | train MSE: 0.7527 | val MSE: 1.0465
# Epoch 583 | train MSE: 0.7540 | val MSE: 1.0201
# Epoch 584 | train MSE: 0.7495 | val MSE: 1.0345
# Epoch 585 | train MSE: 0.7517 | val MSE: 1.0386
# Epoch 586 | train MSE: 0.7486 | val MSE: 1.0218
# Epoch 587 | train MSE: 0.7498 | val MSE: 1.0339
# Epoch 588 | train MSE: 0.7528 | val MSE: 1.0210
# Epoch 589 | train MSE: 0.7533 | val MSE: 1.0234
# Epoch 590 | train MSE: 0.7513 | val MSE: 1.0322
# Epoch 591 | train MSE: 0.7566 | val MSE: 1.0316
# Epoch 592 | train MSE: 0.7599 | val MSE: 1.0369
# Epoch 593 | train MSE: 0.7518 | val MSE: 1.0619
# Epoch 594 | train MSE: 0.7509 | val MSE: 1.0339
# Epoch 595 | train MSE: 0.7480 | val MSE: 1.0470
# Epoch 596 | train MSE: 0.7499 | val MSE: 1.0294
# Epoch 597 | train MSE: 0.7541 | val MSE: 1.0328
# Epoch 598 | train MSE: 0.7541 | val MSE: 1.0430
# Epoch 599 | train MSE: 0.7461 | val MSE: 1.0327
# Epoch 600 | train MSE: 0.7474 | val MSE: 1.0347
# Epoch 601 | train MSE: 0.7485 | val MSE: 1.0648
# Epoch 602 | train MSE: 0.7467 | val MSE: 1.0304
# Epoch 603 | train MSE: 0.7476 | val MSE: 1.0474
# Epoch 604 | train MSE: 0.7451 | val MSE: 1.0611
# Epoch 605 | train MSE: 0.7464 | val MSE: 1.0254
# Epoch 606 | train MSE: 0.7447 | val MSE: 1.0318
# Epoch 607 | train MSE: 0.7488 | val MSE: 1.0397
# Epoch 608 | train MSE: 0.7440 | val MSE: 1.0338
# Epoch 609 | train MSE: 0.7472 | val MSE: 1.0260
# Epoch 610 | train MSE: 0.7489 | val MSE: 1.0355
# Epoch 611 | train MSE: 0.7427 | val MSE: 1.0288
# Epoch 612 | train MSE: 0.7460 | val MSE: 1.0417
# Epoch 613 | train MSE: 0.7448 | val MSE: 1.0318
# Epoch 614 | train MSE: 0.7452 | val MSE: 1.0334
# Epoch 615 | train MSE: 0.7437 | val MSE: 1.0406
# Epoch 616 | train MSE: 0.7452 | val MSE: 1.0385
# Epoch 617 | train MSE: 0.7466 | val MSE: 1.0339
# Epoch 618 | train MSE: 0.7484 | val MSE: 1.0636
# Epoch 619 | train MSE: 0.7496 | val MSE: 1.0382
# Epoch 620 | train MSE: 0.7499 | val MSE: 1.0348
# Epoch 621 | train MSE: 0.7492 | val MSE: 1.0404
# Epoch 622 | train MSE: 0.7495 | val MSE: 1.0566
# Epoch 623 | train MSE: 0.7453 | val MSE: 1.0857
# Epoch 624 | train MSE: 0.7455 | val MSE: 1.0318
# Epoch 625 | train MSE: 0.7491 | val MSE: 1.0566
# Epoch 626 | train MSE: 0.7482 | val MSE: 1.0360
# Epoch 627 | train MSE: 0.7438 | val MSE: 1.0290
# Epoch 628 | train MSE: 0.7413 | val MSE: 1.0276
# Epoch 629 | train MSE: 0.7438 | val MSE: 1.0469
# Epoch 630 | train MSE: 0.7434 | val MSE: 1.0318
# Epoch 631 | train MSE: 0.7456 | val MSE: 1.0319
# Epoch 632 | train MSE: 0.7445 | val MSE: 1.0568
# Epoch 633 | train MSE: 0.7472 | val MSE: 1.0298
# Epoch 634 | train MSE: 0.7445 | val MSE: 1.0433
# Epoch 635 | train MSE: 0.7439 | val MSE: 1.0300
# Epoch 636 | train MSE: 0.7444 | val MSE: 1.0371
# Epoch 637 | train MSE: 0.7483 | val MSE: 1.0323
# Epoch 638 | train MSE: 0.7445 | val MSE: 1.0273
# Epoch 639 | train MSE: 0.7425 | val MSE: 1.0347
# Epoch 640 | train MSE: 0.7436 | val MSE: 1.0284
# Epoch 641 | train MSE: 0.7443 | val MSE: 1.0341
# Epoch 642 | train MSE: 0.7412 | val MSE: 1.0255
# Epoch 643 | train MSE: 0.7446 | val MSE: 1.0394
# Epoch 644 | train MSE: 0.7474 | val MSE: 1.0379
# Epoch 645 | train MSE: 0.7420 | val MSE: 1.0559
# Epoch 646 | train MSE: 0.7415 | val MSE: 1.0420
# Epoch 647 | train MSE: 0.7455 | val MSE: 1.0420
# Epoch 648 | train MSE: 0.7449 | val MSE: 1.0454
# Epoch 649 | train MSE: 0.7390 | val MSE: 1.0387
# Epoch 650 | train MSE: 0.7364 | val MSE: 1.0532
# Epoch 651 | train MSE: 0.7372 | val MSE: 1.0302
# Epoch 652 | train MSE: 0.7441 | val MSE: 1.0622
# Epoch 653 | train MSE: 0.7487 | val MSE: 1.0299
# Epoch 654 | train MSE: 0.7408 | val MSE: 1.0327
# Epoch 655 | train MSE: 0.7401 | val MSE: 1.0489
# Epoch 656 | train MSE: 0.7384 | val MSE: 1.0823
# Epoch 657 | train MSE: 0.7434 | val MSE: 1.0341
# Epoch 658 | train MSE: 0.7397 | val MSE: 1.0694
# Epoch 659 | train MSE: 0.7398 | val MSE: 1.0314
# Epoch 660 | train MSE: 0.7413 | val MSE: 1.0429
# Epoch 661 | train MSE: 0.7362 | val MSE: 1.0430
# Epoch 662 | train MSE: 0.7375 | val MSE: 1.0349
# Epoch 663 | train MSE: 0.7350 | val MSE: 1.0503
# Epoch 664 | train MSE: 0.7411 | val MSE: 1.0563
# Epoch 665 | train MSE: 0.7404 | val MSE: 1.0415
# Epoch 666 | train MSE: 0.7393 | val MSE: 1.0556
# Epoch 667 | train MSE: 0.7371 | val MSE: 1.0254
# Epoch 668 | train MSE: 0.7429 | val MSE: 1.0526
# Epoch 669 | train MSE: 0.7409 | val MSE: 1.0347
# Epoch 670 | train MSE: 0.7402 | val MSE: 1.0625
# Epoch 671 | train MSE: 0.7350 | val MSE: 1.0501
# Epoch 672 | train MSE: 0.7355 | val MSE: 1.0495
# Epoch 673 | train MSE: 0.7409 | val MSE: 1.0379
# Epoch 674 | train MSE: 0.7380 | val MSE: 1.0258
# Epoch 675 | train MSE: 0.7342 | val MSE: 1.0307
# Epoch 676 | train MSE: 0.7374 | val MSE: 1.0419
# Epoch 677 | train MSE: 0.7391 | val MSE: 1.0495
# Epoch 678 | train MSE: 0.7370 | val MSE: 1.0406
# Epoch 679 | train MSE: 0.7381 | val MSE: 1.0515
# Epoch 680 | train MSE: 0.7375 | val MSE: 1.0323
# Epoch 681 | train MSE: 0.7392 | val MSE: 1.0389
# Epoch 682 | train MSE: 0.7392 | val MSE: 1.0555
# Epoch 683 | train MSE: 0.7362 | val MSE: 1.0532
# Epoch 684 | train MSE: 0.7385 | val MSE: 1.0442
# Epoch 685 | train MSE: 0.7335 | val MSE: 1.0331
# Epoch 686 | train MSE: 0.7380 | val MSE: 1.0872
# Epoch 687 | train MSE: 0.7404 | val MSE: 1.0425
# Epoch 688 | train MSE: 0.7382 | val MSE: 1.0603
# Epoch 689 | train MSE: 0.7367 | val MSE: 1.0409
# Epoch 690 | train MSE: 0.7392 | val MSE: 1.0418
# Epoch 691 | train MSE: 0.7347 | val MSE: 1.0353
# Epoch 692 | train MSE: 0.7321 | val MSE: 1.0587
# Epoch 693 | train MSE: 0.7408 | val MSE: 1.0508
# Epoch 694 | train MSE: 0.7322 | val MSE: 1.0394
# Epoch 695 | train MSE: 0.7298 | val MSE: 1.0464
# Epoch 696 | train MSE: 0.7304 | val MSE: 1.0546
# Epoch 697 | train MSE: 0.7332 | val MSE: 1.0391
# Epoch 698 | train MSE: 0.7380 | val MSE: 1.0511
# Epoch 699 | train MSE: 0.7394 | val MSE: 1.0666
# Epoch 700 | train MSE: 0.7352 | val MSE: 1.0624
# Epoch 701 | train MSE: 0.7366 | val MSE: 1.0482
# Epoch 702 | train MSE: 0.7312 | val MSE: 1.0563
# Epoch 703 | train MSE: 0.7316 | val MSE: 1.0533
# Epoch 704 | train MSE: 0.7340 | val MSE: 1.0447
# Epoch 705 | train MSE: 0.7383 | val MSE: 1.0386
# Epoch 706 | train MSE: 0.7328 | val MSE: 1.0793
# Epoch 707 | train MSE: 0.7381 | val MSE: 1.0629
# Epoch 708 | train MSE: 0.7379 | val MSE: 1.0648
# Epoch 709 | train MSE: 0.7327 | val MSE: 1.0421
# Epoch 710 | train MSE: 0.7340 | val MSE: 1.0436
# Epoch 711 | train MSE: 0.7328 | val MSE: 1.0889
# Epoch 712 | train MSE: 0.7316 | val MSE: 1.0362
# Epoch 713 | train MSE: 0.7379 | val MSE: 1.0558
# Epoch 714 | train MSE: 0.7294 | val MSE: 1.0515
# Epoch 715 | train MSE: 0.7375 | val MSE: 1.0713
# Epoch 716 | train MSE: 0.7379 | val MSE: 1.0496
# Epoch 717 | train MSE: 0.7299 | val MSE: 1.0660
# Epoch 718 | train MSE: 0.7268 | val MSE: 1.0533
# Epoch 719 | train MSE: 0.7278 | val MSE: 1.0389
# Epoch 720 | train MSE: 0.7317 | val MSE: 1.0405
# Epoch 721 | train MSE: 0.7322 | val MSE: 1.0393
# Epoch 722 | train MSE: 0.7311 | val MSE: 1.0497
# Epoch 723 | train MSE: 0.7292 | val MSE: 1.0397
# Epoch 724 | train MSE: 0.7324 | val MSE: 1.0600
# Epoch 725 | train MSE: 0.7274 | val MSE: 1.0517
# Epoch 726 | train MSE: 0.7326 | val MSE: 1.0637
# Epoch 727 | train MSE: 0.7298 | val MSE: 1.0775
# Epoch 728 | train MSE: 0.7393 | val MSE: 1.0557
# Epoch 729 | train MSE: 0.7325 | val MSE: 1.0344
# Epoch 730 | train MSE: 0.7299 | val MSE: 1.0490
# Epoch 731 | train MSE: 0.7305 | val MSE: 1.0500
# Epoch 732 | train MSE: 0.7304 | val MSE: 1.0539
# Epoch 733 | train MSE: 0.7307 | val MSE: 1.0476
# Epoch 734 | train MSE: 0.7283 | val MSE: 1.0505
# Epoch 735 | train MSE: 0.7314 | val MSE: 1.0503
# Epoch 736 | train MSE: 0.7261 | val MSE: 1.0298
# Epoch 737 | train MSE: 0.7293 | val MSE: 1.0600
# Epoch 738 | train MSE: 0.7291 | val MSE: 1.0668
# Epoch 739 | train MSE: 0.7275 | val MSE: 1.0389
# Epoch 740 | train MSE: 0.7308 | val MSE: 1.0373
# Epoch 741 | train MSE: 0.7300 | val MSE: 1.0464
# Epoch 742 | train MSE: 0.7296 | val MSE: 1.0334
# Epoch 743 | train MSE: 0.7307 | val MSE: 1.0535
# Epoch 744 | train MSE: 0.7303 | val MSE: 1.0541
# Epoch 745 | train MSE: 0.7277 | val MSE: 1.0460
# Epoch 746 | train MSE: 0.7284 | val MSE: 1.0495
# Epoch 747 | train MSE: 0.7268 | val MSE: 1.0583
# Epoch 748 | train MSE: 0.7261 | val MSE: 1.0530
# Epoch 749 | train MSE: 0.7284 | val MSE: 1.0722
# Epoch 750 | train MSE: 0.7322 | val MSE: 1.0495
# Epoch 751 | train MSE: 0.7276 | val MSE: 1.0369
# Epoch 752 | train MSE: 0.7300 | val MSE: 1.0454
# Epoch 753 | train MSE: 0.7283 | val MSE: 1.0544
# Epoch 754 | train MSE: 0.7321 | val MSE: 1.0596
# Epoch 755 | train MSE: 0.7357 | val MSE: 1.0358
# Epoch 756 | train MSE: 0.7269 | val MSE: 1.0490
# Epoch 757 | train MSE: 0.7276 | val MSE: 1.0517
# Epoch 758 | train MSE: 0.7264 | val MSE: 1.0311
# Epoch 759 | train MSE: 0.7232 | val MSE: 1.0604
# Epoch 760 | train MSE: 0.7263 | val MSE: 1.0601
# Epoch 761 | train MSE: 0.7267 | val MSE: 1.0499
# Epoch 762 | train MSE: 0.7256 | val MSE: 1.0685
# Epoch 763 | train MSE: 0.7280 | val MSE: 1.0489
# Epoch 764 | train MSE: 0.7304 | val MSE: 1.0630
# Epoch 765 | train MSE: 0.7283 | val MSE: 1.0496
# Epoch 766 | train MSE: 0.7251 | val MSE: 1.0466
# Epoch 767 | train MSE: 0.7289 | val MSE: 1.0702
# Epoch 768 | train MSE: 0.7266 | val MSE: 1.0605
# Epoch 769 | train MSE: 0.7258 | val MSE: 1.0531
# Epoch 770 | train MSE: 0.7237 | val MSE: 1.0533
# Epoch 771 | train MSE: 0.7240 | val MSE: 1.0546
# Epoch 772 | train MSE: 0.7225 | val MSE: 1.0377
# Epoch 773 | train MSE: 0.7264 | val MSE: 1.0389
# Epoch 774 | train MSE: 0.7259 | val MSE: 1.0457
# Epoch 775 | train MSE: 0.7244 | val MSE: 1.0564
# Epoch 776 | train MSE: 0.7266 | val MSE: 1.0405
# Epoch 777 | train MSE: 0.7244 | val MSE: 1.0591
# Epoch 778 | train MSE: 0.7213 | val MSE: 1.0528
# Epoch 779 | train MSE: 0.7252 | val MSE: 1.0614
# Epoch 780 | train MSE: 0.7267 | val MSE: 1.0640
# Epoch 781 | train MSE: 0.7246 | val MSE: 1.0511
# Epoch 782 | train MSE: 0.7242 | val MSE: 1.0480
# Epoch 783 | train MSE: 0.7261 | val MSE: 1.0763
# Epoch 784 | train MSE: 0.7226 | val MSE: 1.0654
# Epoch 785 | train MSE: 0.7232 | val MSE: 1.0553
# Epoch 786 | train MSE: 0.7218 | val MSE: 1.0432
# Epoch 787 | train MSE: 0.7364 | val MSE: 1.0720
# Epoch 788 | train MSE: 0.7240 | val MSE: 1.0638
# Epoch 789 | train MSE: 0.7287 | val MSE: 1.0514
# Epoch 790 | train MSE: 0.7211 | val MSE: 1.0775
# Epoch 791 | train MSE: 0.7261 | val MSE: 1.0524
# Epoch 792 | train MSE: 0.7204 | val MSE: 1.0584
# Epoch 793 | train MSE: 0.7174 | val MSE: 1.0531
# Epoch 794 | train MSE: 0.7209 | val MSE: 1.0474
# Epoch 795 | train MSE: 0.7213 | val MSE: 1.0484
# Epoch 796 | train MSE: 0.7214 | val MSE: 1.0492
# Epoch 797 | train MSE: 0.7203 | val MSE: 1.0570
# Epoch 798 | train MSE: 0.7258 | val MSE: 1.0357
# Epoch 799 | train MSE: 0.7226 | val MSE: 1.0510
# Epoch 800 | train MSE: 0.7252 | val MSE: 1.0475
# Epoch 801 | train MSE: 0.7240 | val MSE: 1.0399
# Epoch 802 | train MSE: 0.7222 | val MSE: 1.0458
# Epoch 803 | train MSE: 0.7204 | val MSE: 1.0354
# Epoch 804 | train MSE: 0.7198 | val MSE: 1.0579
# Epoch 805 | train MSE: 0.7225 | val MSE: 1.0811
# Epoch 806 | train MSE: 0.7236 | val MSE: 1.0480
# Epoch 807 | train MSE: 0.7209 | val MSE: 1.0568
# Epoch 808 | train MSE: 0.7217 | val MSE: 1.0682
# Epoch 809 | train MSE: 0.7202 | val MSE: 1.0671
# Epoch 810 | train MSE: 0.7198 | val MSE: 1.0450
# Epoch 811 | train MSE: 0.7227 | val MSE: 1.0453
# Epoch 812 | train MSE: 0.7227 | val MSE: 1.0439
# Epoch 813 | train MSE: 0.7287 | val MSE: 1.0401
# Epoch 814 | train MSE: 0.7224 | val MSE: 1.0446
# Epoch 815 | train MSE: 0.7182 | val MSE: 1.0584
# Epoch 816 | train MSE: 0.7179 | val MSE: 1.0829
# Epoch 817 | train MSE: 0.7286 | val MSE: 1.0946
# Epoch 818 | train MSE: 0.7222 | val MSE: 1.0406
# Epoch 819 | train MSE: 0.7187 | val MSE: 1.0591
# Epoch 820 | train MSE: 0.7151 | val MSE: 1.0690
# Epoch 821 | train MSE: 0.7137 | val MSE: 1.0620
# Epoch 822 | train MSE: 0.7153 | val MSE: 1.0677
# Epoch 823 | train MSE: 0.7218 | val MSE: 1.0594
# Epoch 824 | train MSE: 0.7210 | val MSE: 1.0614
# Epoch 825 | train MSE: 0.7149 | val MSE: 1.0532
# Epoch 826 | train MSE: 0.7213 | val MSE: 1.0748
# Epoch 827 | train MSE: 0.7225 | val MSE: 1.1089
# Epoch 828 | train MSE: 0.7193 | val MSE: 1.0976
# Epoch 829 | train MSE: 0.7164 | val MSE: 1.0423
# Epoch 830 | train MSE: 0.7156 | val MSE: 1.0658
# Epoch 831 | train MSE: 0.7213 | val MSE: 1.0460
# Epoch 832 | train MSE: 0.7193 | val MSE: 1.0881
# Epoch 833 | train MSE: 0.7283 | val MSE: 1.0556
# Epoch 834 | train MSE: 0.7201 | val MSE: 1.0524
# Epoch 835 | train MSE: 0.7202 | val MSE: 1.0599
# Epoch 836 | train MSE: 0.7213 | val MSE: 1.0659
# Epoch 837 | train MSE: 0.7201 | val MSE: 1.0608
# Epoch 838 | train MSE: 0.7174 | val MSE: 1.0500
# Epoch 839 | train MSE: 0.7137 | val MSE: 1.0603
# Epoch 840 | train MSE: 0.7194 | val MSE: 1.0581
# Epoch 841 | train MSE: 0.7191 | val MSE: 1.0767
# Epoch 842 | train MSE: 0.7192 | val MSE: 1.0824
# Epoch 843 | train MSE: 0.7177 | val MSE: 1.0515
# Epoch 844 | train MSE: 0.7182 | val MSE: 1.0680
# Epoch 845 | train MSE: 0.7158 | val MSE: 1.0677
# Epoch 846 | train MSE: 0.7184 | val MSE: 1.0487
# Epoch 847 | train MSE: 0.7157 | val MSE: 1.0411
# Epoch 848 | train MSE: 0.7121 | val MSE: 1.0512
# Epoch 849 | train MSE: 0.7178 | val MSE: 1.0441
# Epoch 850 | train MSE: 0.7172 | val MSE: 1.0656
# Epoch 851 | train MSE: 0.7184 | val MSE: 1.0471
# Epoch 852 | train MSE: 0.7135 | val MSE: 1.0623
# Epoch 853 | train MSE: 0.7172 | val MSE: 1.0844
# Epoch 854 | train MSE: 0.7161 | val MSE: 1.0529
# Epoch 855 | train MSE: 0.7174 | val MSE: 1.0479
# Epoch 856 | train MSE: 0.7198 | val MSE: 1.0463
# Epoch 857 | train MSE: 0.7159 | val MSE: 1.0604
# Epoch 858 | train MSE: 0.7108 | val MSE: 1.0683
# Epoch 859 | train MSE: 0.7145 | val MSE: 1.0503
# Epoch 860 | train MSE: 0.7158 | val MSE: 1.0714
# Epoch 861 | train MSE: 0.7181 | val MSE: 1.0723
# Epoch 862 | train MSE: 0.7117 | val MSE: 1.0475
# Epoch 863 | train MSE: 0.7120 | val MSE: 1.0600
# Epoch 864 | train MSE: 0.7157 | val MSE: 1.0557
# Epoch 865 | train MSE: 0.7223 | val MSE: 1.0530
# Epoch 866 | train MSE: 0.7159 | val MSE: 1.0511
# Epoch 867 | train MSE: 0.7160 | val MSE: 1.0555
# Epoch 868 | train MSE: 0.7105 | val MSE: 1.0739
# Epoch 869 | train MSE: 0.7195 | val MSE: 1.0662
# Epoch 870 | train MSE: 0.7154 | val MSE: 1.0973
# Epoch 871 | train MSE: 0.7175 | val MSE: 1.0457
# Epoch 872 | train MSE: 0.7172 | val MSE: 1.0630
# Epoch 873 | train MSE: 0.7144 | val MSE: 1.1345
# Epoch 874 | train MSE: 0.7195 | val MSE: 1.0668
# Epoch 875 | train MSE: 0.7153 | val MSE: 1.0990
# Epoch 876 | train MSE: 0.7138 | val MSE: 1.0456
# Epoch 877 | train MSE: 0.7168 | val MSE: 1.0475
# Epoch 878 | train MSE: 0.7192 | val MSE: 1.0532
# Epoch 879 | train MSE: 0.7147 | val MSE: 1.0881
# Epoch 880 | train MSE: 0.7082 | val MSE: 1.0569
# Epoch 881 | train MSE: 0.7146 | val MSE: 1.0470
# Epoch 882 | train MSE: 0.7166 | val MSE: 1.0558
# Epoch 883 | train MSE: 0.7093 | val MSE: 1.0663
# Epoch 884 | train MSE: 0.7107 | val MSE: 1.0728
# Epoch 885 | train MSE: 0.7135 | val MSE: 1.0629
# Epoch 886 | train MSE: 0.7141 | val MSE: 1.0772
# Epoch 887 | train MSE: 0.7127 | val MSE: 1.0651
# Epoch 888 | train MSE: 0.7104 | val MSE: 1.0580
# Epoch 889 | train MSE: 0.7115 | val MSE: 1.0716
# Epoch 890 | train MSE: 0.7118 | val MSE: 1.0623
# Epoch 891 | train MSE: 0.7093 | val MSE: 1.0709
# Epoch 892 | train MSE: 0.7080 | val MSE: 1.0678
# Epoch 893 | train MSE: 0.7115 | val MSE: 1.0481
# Epoch 894 | train MSE: 0.7123 | val MSE: 1.0688
# Epoch 895 | train MSE: 0.7110 | val MSE: 1.0805
# Epoch 896 | train MSE: 0.7123 | val MSE: 1.0530
# Epoch 897 | train MSE: 0.7117 | val MSE: 1.0712
# Epoch 898 | train MSE: 0.7163 | val MSE: 1.0846
# Epoch 899 | train MSE: 0.7122 | val MSE: 1.0552
# Epoch 900 | train MSE: 0.7148 | val MSE: 1.0632
# Epoch 901 | train MSE: 0.7098 | val MSE: 1.0611
# Epoch 902 | train MSE: 0.7084 | val MSE: 1.0671
# Epoch 903 | train MSE: 0.7132 | val MSE: 1.0564
# Epoch 904 | train MSE: 0.7138 | val MSE: 1.0543
# Epoch 905 | train MSE: 0.7114 | val MSE: 1.0647
# Epoch 906 | train MSE: 0.7164 | val MSE: 1.0734
# Epoch 907 | train MSE: 0.7124 | val MSE: 1.0756
# Epoch 908 | train MSE: 0.7124 | val MSE: 1.0586
# Epoch 909 | train MSE: 0.7076 | val MSE: 1.0786
# Epoch 910 | train MSE: 0.7120 | val MSE: 1.0587
# Epoch 911 | train MSE: 0.7176 | val MSE: 1.0660
# Epoch 912 | train MSE: 0.7071 | val MSE: 1.0446
# Epoch 913 | train MSE: 0.7187 | val MSE: 1.0684
# Epoch 914 | train MSE: 0.7142 | val MSE: 1.0547
# Epoch 915 | train MSE: 0.7125 | val MSE: 1.0779
# Epoch 916 | train MSE: 0.7118 | val MSE: 1.0569
# Epoch 917 | train MSE: 0.7069 | val MSE: 1.0639
# Epoch 918 | train MSE: 0.7075 | val MSE: 1.0522
# Epoch 919 | train MSE: 0.7076 | val MSE: 1.0725
# Epoch 920 | train MSE: 0.7052 | val MSE: 1.0447
# Epoch 921 | train MSE: 0.7058 | val MSE: 1.0621
# Epoch 922 | train MSE: 0.7088 | val MSE: 1.0723
# Epoch 923 | train MSE: 0.7095 | val MSE: 1.0844
# Epoch 924 | train MSE: 0.7094 | val MSE: 1.0498
# Epoch 925 | train MSE: 0.7130 | val MSE: 1.0895
# Epoch 926 | train MSE: 0.7072 | val MSE: 1.0860
# Epoch 927 | train MSE: 0.7116 | val MSE: 1.0687
# Epoch 928 | train MSE: 0.7084 | val MSE: 1.0572
# Epoch 929 | train MSE: 0.7075 | val MSE: 1.0614
# Epoch 930 | train MSE: 0.7073 | val MSE: 1.0787
# Epoch 931 | train MSE: 0.7062 | val MSE: 1.0658
# Epoch 932 | train MSE: 0.7051 | val MSE: 1.0754
# Epoch 933 | train MSE: 0.7041 | val MSE: 1.0640
# Epoch 934 | train MSE: 0.7058 | val MSE: 1.0630
# Epoch 935 | train MSE: 0.7094 | val MSE: 1.0500
# Epoch 936 | train MSE: 0.7174 | val MSE: 1.0910
# Epoch 937 | train MSE: 0.7101 | val MSE: 1.0973
# Epoch 938 | train MSE: 0.7084 | val MSE: 1.0654
# Epoch 939 | train MSE: 0.7066 | val MSE: 1.0756
# Epoch 940 | train MSE: 0.7049 | val MSE: 1.0705
# Epoch 941 | train MSE: 0.7061 | val MSE: 1.0735
# Epoch 942 | train MSE: 0.7116 | val MSE: 1.0761
# Epoch 943 | train MSE: 0.7077 | val MSE: 1.0726
# Epoch 944 | train MSE: 0.7081 | val MSE: 1.0886
# Epoch 945 | train MSE: 0.7047 | val MSE: 1.0700
# Epoch 946 | train MSE: 0.7069 | val MSE: 1.0731
# Epoch 947 | train MSE: 0.7053 | val MSE: 1.0653
# Epoch 948 | train MSE: 0.7054 | val MSE: 1.0607
# Epoch 949 | train MSE: 0.7037 | val MSE: 1.0815
# Epoch 950 | train MSE: 0.7052 | val MSE: 1.0769
# Epoch 951 | train MSE: 0.7094 | val MSE: 1.0908
# Epoch 952 | train MSE: 0.7082 | val MSE: 1.0749
# Epoch 953 | train MSE: 0.7064 | val MSE: 1.0650
# Epoch 954 | train MSE: 0.7094 | val MSE: 1.0631
# Epoch 955 | train MSE: 0.7130 | val MSE: 1.0730
# Epoch 956 | train MSE: 0.7043 | val MSE: 1.0401
# Epoch 957 | train MSE: 0.7058 | val MSE: 1.0662
# Epoch 958 | train MSE: 0.7049 | val MSE: 1.0496
# Epoch 959 | train MSE: 0.7067 | val MSE: 1.0601
# Epoch 960 | train MSE: 0.7041 | val MSE: 1.0654
# Epoch 961 | train MSE: 0.7053 | val MSE: 1.0716
# Epoch 962 | train MSE: 0.7091 | val MSE: 1.0668
# Epoch 963 | train MSE: 0.7044 | val MSE: 1.0599
# Epoch 964 | train MSE: 0.7093 | val MSE: 1.0738
# Epoch 965 | train MSE: 0.7069 | val MSE: 1.0626
# Epoch 966 | train MSE: 0.7000 | val MSE: 1.0634
# Epoch 967 | train MSE: 0.7026 | val MSE: 1.0673
# Epoch 968 | train MSE: 0.7048 | val MSE: 1.0631
# Epoch 969 | train MSE: 0.7098 | val MSE: 1.0964
# Epoch 970 | train MSE: 0.7101 | val MSE: 1.0995
# Epoch 971 | train MSE: 0.7074 | val MSE: 1.0711
# Epoch 972 | train MSE: 0.7048 | val MSE: 1.0656
# Epoch 973 | train MSE: 0.7100 | val MSE: 1.0741
# Epoch 974 | train MSE: 0.7074 | val MSE: 1.0677
# Epoch 975 | train MSE: 0.7065 | val MSE: 1.0680
# Epoch 976 | train MSE: 0.7039 | val MSE: 1.0581
# Epoch 977 | train MSE: 0.7042 | val MSE: 1.0694
# Epoch 978 | train MSE: 0.6981 | val MSE: 1.0688
# Epoch 979 | train MSE: 0.7050 | val MSE: 1.0658
# Epoch 980 | train MSE: 0.7036 | val MSE: 1.0785
# Epoch 981 | train MSE: 0.7046 | val MSE: 1.0929
# Epoch 982 | train MSE: 0.7020 | val MSE: 1.0614
# Epoch 983 | train MSE: 0.7021 | val MSE: 1.0898
# Epoch 984 | train MSE: 0.7103 | val MSE: 1.0619
# Epoch 985 | train MSE: 0.7026 | val MSE: 1.0618
# Epoch 986 | train MSE: 0.7000 | val MSE: 1.0589
# Epoch 987 | train MSE: 0.7059 | val MSE: 1.0628
# Epoch 988 | train MSE: 0.7045 | val MSE: 1.0681
# Epoch 989 | train MSE: 0.7016 | val MSE: 1.0595
# Epoch 990 | train MSE: 0.7008 | val MSE: 1.0574
# Epoch 991 | train MSE: 0.7047 | val MSE: 1.0734
# Epoch 992 | train MSE: 0.7039 | val MSE: 1.0529
# Epoch 993 | train MSE: 0.7008 | val MSE: 1.0955
# Epoch 994 | train MSE: 0.7013 | val MSE: 1.0544
# Epoch 995 | train MSE: 0.7022 | val MSE: 1.0602
# Epoch 996 | train MSE: 0.7005 | val MSE: 1.0751
# Epoch 997 | train MSE: 0.6994 | val MSE: 1.0603
# Epoch 998 | train MSE: 0.7048 | val MSE: 1.0624
# Epoch 999 | train MSE: 0.7024 | val MSE: 1.0838
# Epoch 1000 | train MSE: 0.7128 | val MSE: 1.0981

# %%
decoder.eval()
with torch.no_grad():
    z_t = torch.from_numpy(Z_interp.copy()).to(device)
    X_syn = decoder(z_t).cpu().numpy()

# %%
adata_interpolated_cells = anndata.AnnData(X_syn)

# %%
adata_interpolated_cells.var_names = adata.var_names
adata_interpolated_cells.obs['cell_type'] = 'Interpolated'

# %%
combined_adata = combine_adatas(adata, adata_interpolated_cells)

# %%
plot_umap(combined_adata, 'cell_type')
# Out:
# /mnt/home/islamsa3/anaconda3/envs/global/lib/python3.10/site-packages/scanpy/neighbors/__init__.py:577: UserWarning: You’re trying to run this on 2000 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
#   x = _choose_representation(self._adata, use_rep=use_rep, n_pcs=n_pcs)

# %%
adata.var_names = adata.var_names.str.upper()
adata.var.index = adata.var_names
adata.var['gene_short_name'] = adata.var.index

# %%
dp_markers = ['RAG1', 'RAG2', 'DNTT']
immature_cd4_markers = ['TRAC', 'TRBC1', 'CD69']
mature_cd4_markers = ['IL7R', 'CCR7', 'LST1']

gene_names = adata.var['gene_short_name'].values if 'gene_short_name' in adata.var else adata.var_names.values

available_dp = [g for g in dp_markers if g in gene_names]
available_immature_cd4 = [g for g in immature_cd4_markers if g in gene_names]
available_mature_cd4 = [g for g in mature_cd4_markers if g in gene_names]

print(f"Available dp markers: {available_dp}")
print(f"Available immature cd4 markers: {available_immature_cd4}")
print(f"Available mature cd4 markers: {available_mature_cd4}")

if available_dp or available_immature_cd4 or available_mature_cd4:
    n_markers = len(available_dp) + len(available_immature_cd4) + len(available_mature_cd4)
    n_cols = 3
    n_rows = 3
    
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(5*n_cols, 6*n_rows))
    axes = axes.flatten() if n_markers > 1 else [axes]
    
    pseudotime = np.linspace(0,1,200)
    
    plot_idx = 0
    for gene in available_dp:
        gene_idx = np.where(gene_names == gene)[0][0]
        expression = X_syn[:, gene_idx]
        
        ax = axes[plot_idx]
        ax.scatter(pseudotime, expression, c=pseudotime, cmap='viridis', s=10, alpha=0.6)
        ax.plot(pseudotime, expression, 'k-', alpha=0.3, linewidth=0.5)
        ax.set_xlabel('Pseudotime')
        ax.set_ylabel('Expression')
        ax.set_title(f'{gene} (DP)', fontsize=10)
        plot_idx += 1
    
    for gene in available_immature_cd4:
        gene_idx = np.where(gene_names == gene)[0][0]
        expression = X_syn[:, gene_idx]
        
        ax = axes[plot_idx]
        ax.scatter(pseudotime, expression, c=pseudotime, cmap='viridis', s=10, alpha=0.6)
        ax.plot(pseudotime, expression, 'k-', alpha=0.3, linewidth=0.5)
        ax.set_xlabel('Pseudotime')
        ax.set_ylabel('Expression')
        ax.set_title(f'{gene} (Immature CD4)', fontsize=10)
        plot_idx += 1

    for gene in available_mature_cd4:
        gene_idx = np.where(gene_names == gene)[0][0]
        expression = X_syn[:, gene_idx]
        
        ax = axes[plot_idx]
        ax.scatter(pseudotime, expression, c=pseudotime, cmap='viridis', s=10, alpha=0.6)
        ax.plot(pseudotime, expression, 'k-', alpha=0.3, linewidth=0.5)
        ax.set_xlabel('Pseudotime')
        ax.set_ylabel('Expression')
        ax.set_title(f'{gene} (Mature CD4)', fontsize=10)
        plot_idx += 1
    
    for i in range(plot_idx, len(axes)):
        axes[i].set_visible(False)
    
    plt.tight_layout()
    plt.show()
else:
    print("No common markers found in the dataset")
# Out:
# Available dp markers: ['RAG1', 'RAG2', 'DNTT']
# Available immature cd4 markers: ['TRAC', 'TRBC1', 'CD69']
# Available mature cd4 markers: ['IL7R', 'CCR7', 'LST1']

# %%
original_labels = adata.obs['cell_type'].values
interpolated_labels = np.array(['Interpolated'] * len(adata_interpolated_cells))

combined_latent = np.vstack([X_latent, Z_interp])
combined_labels = np.concatenate([original_labels, interpolated_labels])

pca = PCA(n_components=2, random_state=42)
latent_pca = pca.fit_transform(combined_latent)


unique_labels = np.unique(combined_labels)

unique_colors = plt.cm.tab10(np.linspace(0, 1, len(unique_labels)))
palette = {label: unique_colors[i] for i, label in enumerate(unique_labels)}
# figsize
plt.figure(figsize=(8,8))
for i, label in enumerate(unique_labels):
    mask = combined_labels == label
    plt.scatter(
        latent_pca[mask, 0], 
        latent_pca[mask, 1],
        color=palette[label],
        label=label,
        alpha=0.7,
        s=50 if label == 'interpolated' else 80,
        #edgecolors='w',
        linewidths=0.5
    )

plt.title('PCA of Latent Representations', fontsize=18)
plt.legend(fontsize=18)
plt.tight_layout()

# %%
adata_latent_syn = anndata.AnnData(Z_interp)
adata_latent_syn.obs["cell_type"] = "Interpolated"
adata_new = anndata.AnnData(
    X=X_latent,
    obs=adata.obs[['cell_type']].copy()
)
combined_adata_latent = combine_adatas(adata_new, adata_latent_syn)
plot_umap(combined_adata_latent, "cell_type")
# Out:
# /mnt/home/islamsa3/anaconda3/envs/global/lib/python3.10/site-packages/scanpy/neighbors/__init__.py:577: UserWarning: You’re trying to run this on 512 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
#   x = _choose_representation(self._adata, use_rep=use_rep, n_pcs=n_pcs)

# %%
pt_df, pt_summary = evaluate_pseudotime_distance_error(
    X_syn,
    np.linspace(0, 1, 200),
    adata,
    list(gene_names),
    real_pseudotime_key="dpt_pseudotime",
)

print(pt_summary)
pt_df.head()
# Out:
# {'delta_t_mean': 0.17979716505649404, 'delta_t_median': 0.15516789987608415, 'delta_t_max': 0.4813978344052281, 'dist_mean': 34.89012041568756, 'dist_median': 24.3467960357666, 'dist_max': 85.87890625}
# OpenBLAS warning: precompiled NUM_THREADS exceeded, adding auxiliary array for thread metadata.
# To avoid this warning, please rebuild your copy of OpenBLAS with a larger NUM_THREADS setting
# or set the environment variable OPENBLAS_NUM_THREADS to 64 or lower
#       alpha  nearest_pseudotime   delta_t  dist_to_nearest
# 0  0.000000            0.236926  0.236926        15.355396
# 1  0.005025            0.236926  0.231901        15.267482
# 2  0.010050            0.236926  0.226876        15.187986
# 3  0.015075            0.236926  0.221851        15.127986
# 4  0.020101            0.236926  0.216826        15.077099

# %%
dist_series, dist_summary = evaluate_distance_to_manifold_smoothness(
    X_syn,
    adata,
    list(gene_names),
)

print(dist_summary)
# Out:
# {'dist_mean': 34.89012041568756, 'dist_median': 24.3467960357666, 'dist_max': 85.87890625, 'smooth_mean_abs_delta': 0.5396817269636758, 'smooth_max_abs_delta': 2.8660202026367188}

# %%
marker_sets = {
    "HSC": ['THY1', 'KIT', 'GATA2'],
    "CMP": ['TFRC', 'KIT', 'IRF8'],
    "GMP": ['CEBPA', 'CEBPD', 'MPO']
}

expected_directions = {
    "HSC": -1,   
    "CMP": 1,   
    "GMP": 1,   
}


df_markers, summary_markers = evaluate_marker_monotonicity_general(
    X_syn=X_syn,
    traj_coord=np.linspace(0, 1, 200),      
    gene_list=list(gene_names),
    marker_sets=marker_sets,
    expected_directions=expected_directions,

)

print(summary_markers)
df_markers.head()
# Out:
#   group  n_genes  mean_rho  median_rho  frac_sign_ok
# 0   CMP        3 -0.063516    0.013803      0.666667
# 1   GMP        1 -0.627383   -0.627383      0.000000
# 2   HSC        1 -0.473092   -0.473092      1.000000
#   group   gene       rho          pval  expected_dir  sign_ok
# 0   HSC    KIT -0.473092  1.504408e-12            -1     True
# 1   CMP   TFRC  0.013803  8.461802e-01             1     True
# 2   CMP    KIT -0.473092  1.504408e-12             1    False
# 3   CMP   IRF8  0.268742  1.191864e-04             1     True
# 4   GMP  CEBPA -0.627383  2.784309e-23             1    False

# %%
adata_interpolated_cells.write_h5ad('../data/syn_thy_scvi.h5ad')
