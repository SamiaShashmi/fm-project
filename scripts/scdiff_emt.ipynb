# %%
import scanpy as sc
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.append(str(Path.cwd().parent))
from utils.adata import *
from utils.latent import *
from utils.plot import *
from utils.evaluation import *
import json
from sklearn.neighbors import NearestNeighbors
from umap import UMAP
import torch
import torch.nn.functional as F
import anndata
from torch import nn
from torch.utils.data import Dataset, DataLoader
from sklearn.decomposition import PCA
from src.scDiffusion import VAE, guided_diffusion
from src.scDiffusion.VAE.VAE_model import *

# %%
adata = sc.read_h5ad("../data/emt.h5ad")

# %%
adata.obs["celltype"] = adata.obs["cell_type"].map(
    {"Epithelial": "Epi", "Mesenchymal": "Mes"}
)
adata.obs["celltype"] = adata.obs["celltype"].astype("category")

# %%
adata.obs["period"] = adata.obs["celltype"]

# %%
adata.write("../data/emt_diff.h5ad")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 5027 × 2000
#     obs: 'cell', 'total_umis', 'sample', 'TSNE.1', 'TSNE.2', 'Size_Factor', 'treatment_id', 'spatial_id', 'cell_type', 'dpt_pseudotime', 'celltype', 'period'
#     var: 'id', 'gene_short_name', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm'
#     uns: 'X_name', 'cell_type_colors', 'diffmap_evals', 'hvg', 'iroot', 'neighbors', 'pca', 'umap'
#     obsm: 'X_diffmap', 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
# !python ../src/scDiffusion/VAE/VAE_train.py \
# --data_dir '../data/emt_diff.h5ad' \
# --num_genes 2000 \
# --save_dir '../models/scdiff/emt/VAE' \
# --state_dict '../models/scdiff/annotation_model_v1/' \
# --max_steps 200000
# Out:
# loading pretrained model from:
#  {'encoder': '../models/scdiff/annotation_model_v1/encoder.ckpt', 'decoder': '../models/scdiff/annotation_model_v1/decoder.ckpt', 'gene_order': '../models/scdiff/annotation_model_v1/gene_order.tsv'}
# /mnt/home/islamsa3/anaconda3/envs/global/lib/python3.10/site-packages/numba/np/ufunc/parallel.py:371: NumbaWarning: The TBB threading layer requires TBB version 2021 update 6 or later i.e., TBB_INTERFACE_VERSION >= 12060. Found TBB_INTERFACE_VERSION = 12050. The TBB threading layer is disabled.
#   warnings.warn(problem)
# step  0 loss  1.4337416887283325
# step  1000 loss  0.2901614010334015
# step  2000 loss  0.25145766139030457
# step  3000 loss  0.2434931993484497
# step  4000 loss  0.21504704654216766
# step  5000 loss  0.20773711800575256
# step  6000 loss  0.19371017813682556
# step  7000 loss  0.1876397430896759
# step  8000 loss  0.17543569207191467
# step  9000 loss  0.17463421821594238
# step  10000 loss  0.16368670761585236
# step  11000 loss  0.15742330253124237
# step  12000 loss  0.1545163244009018
# step  13000 loss  0.15365418791770935
# step  14000 loss  0.15154138207435608
# step  15000 loss  0.1463499814271927
# step  16000 loss  0.1404372900724411
# step  17000 loss  0.14103105664253235
# step  18000 loss  0.13104760646820068
# step  19000 loss  0.13053001463413239
# step  20000 loss  0.12824060022830963
# step  21000 loss  0.132013738155365
# step  22000 loss  0.12162985652685165
# step  23000 loss  0.12270721793174744
# step  24000 loss  0.11804430931806564
# step  25000 loss  0.12147390842437744
# step  26000 loss  0.11551664024591446
# step  27000 loss  0.11173836141824722
# step  28000 loss  0.11725763231515884
# step  29000 loss  0.11185933649539948
# step  30000 loss  0.11365486681461334
# step  31000 loss  0.11412692070007324
# step  32000 loss  0.1081935465335846
# step  33000 loss  0.10981198400259018
# step  34000 loss  0.10832783579826355
# step  35000 loss  0.1107705608010292
# step  36000 loss  0.10299123078584671
# step  37000 loss  0.10777215659618378
# step  38000 loss  0.10420498996973038
# step  39000 loss  0.10719412565231323
# step  40000 loss  0.10175017267465591
# step  41000 loss  0.10314162075519562
# step  42000 loss  0.1056881994009018
# step  43000 loss  0.10005835443735123
# step  44000 loss  0.09959039092063904
# step  45000 loss  0.09791182726621628
# step  46000 loss  0.09662403166294098
# step  47000 loss  0.09849143028259277
# step  48000 loss  0.09614840894937515
# step  49000 loss  0.09656967967748642
# step  50000 loss  0.09531065821647644
# step  51000 loss  0.0955483466386795
# step  52000 loss  0.0958714708685875
# step  53000 loss  0.09741643071174622
# step  54000 loss  0.09768945723772049
# step  55000 loss  0.09140969812870026
# step  56000 loss  0.08994916081428528
# step  57000 loss  0.09665592759847641
# step  58000 loss  0.08766207098960876
# step  59000 loss  0.0921555683016777
# step  60000 loss  0.09303891658782959
# step  61000 loss  0.09665597975254059
# step  62000 loss  0.08845364302396774
# step  63000 loss  0.09048668295145035
# step  64000 loss  0.08543027192354202
# step  65000 loss  0.08902610838413239
# step  66000 loss  0.08652745187282562
# step  67000 loss  0.0893290787935257
# step  68000 loss  0.08544392883777618
# step  69000 loss  0.08814280480146408
# step  70000 loss  0.08920896053314209
# step  71000 loss  0.08821217715740204
# step  72000 loss  0.08665134757757187
# step  73000 loss  0.0889471173286438
# step  74000 loss  0.08884838223457336
# step  75000 loss  0.08693953603506088
# step  76000 loss  0.09693881869316101
# step  77000 loss  0.08490505069494247
# step  78000 loss  0.08362219482660294
# step  79000 loss  0.08171238005161285
# step  80000 loss  0.08841007202863693
# step  81000 loss  0.08460143208503723
# step  82000 loss  0.0885198637843132
# step  83000 loss  0.0814950168132782
# step  84000 loss  0.08241867274045944
# step  85000 loss  0.08327002078294754
# step  86000 loss  0.07815705984830856
# step  87000 loss  0.0826232060790062
# step  88000 loss  0.08625300973653793
# step  89000 loss  0.07705368101596832
# step  90000 loss  0.08028433471918106
# step  91000 loss  0.08156566321849823
# step  92000 loss  0.08429183810949326
# step  93000 loss  0.08424102514982224
# step  94000 loss  0.07847334444522858
# step  95000 loss  0.08282070606946945
# step  96000 loss  0.08707695454359055
# step  97000 loss  0.07469671964645386
# step  98000 loss  0.08301078528165817
# step  99000 loss  0.0844959020614624
# step  100000 loss  0.08240942656993866
# step  101000 loss  0.07940294593572617
# step  102000 loss  0.08084484189748764
# step  103000 loss  0.07724341750144958
# step  104000 loss  0.0822216346859932
# step  105000 loss  0.07644118368625641
# step  106000 loss  0.08220411837100983
# step  107000 loss  0.07622738927602768
# step  108000 loss  0.07862459123134613
# step  109000 loss  0.07750481367111206
# step  110000 loss  0.0794009417295456
# step  111000 loss  0.07380138337612152
# step  112000 loss  0.07475733011960983
# step  113000 loss  0.07591915130615234
# step  114000 loss  0.07760434597730637
# step  115000 loss  0.08443795889616013
# step  116000 loss  0.08039992302656174
# step  117000 loss  0.07594180107116699
# step  118000 loss  0.07566148042678833
# step  119000 loss  0.08241342753171921
# step  120000 loss  0.07903669029474258
# step  121000 loss  0.07597678154706955
# step  122000 loss  0.07555697858333588
# step  123000 loss  0.07448671013116837
# step  124000 loss  0.07552358508110046
# step  125000 loss  0.07209749519824982
# step  126000 loss  0.07439567148685455
# step  127000 loss  0.07520898431539536
# step  128000 loss  0.07660466432571411
# step  129000 loss  0.07867380231618881
# step  130000 loss  0.07387962937355042
# step  131000 loss  0.0855775699019432
# step  132000 loss  0.07526202499866486
# step  133000 loss  0.08374669402837753
# step  134000 loss  0.07919483631849289
# step  135000 loss  0.07281264662742615
# step  136000 loss  0.07149914652109146
# step  137000 loss  0.07450766116380692
# step  138000 loss  0.07109563052654266
# step  139000 loss  0.07252998650074005
# step  140000 loss  0.08317947387695312
# step  141000 loss  0.07276443392038345
# step  142000 loss  0.07725603878498077
# step  143000 loss  0.06996496766805649
# step  144000 loss  0.07208819687366486
# step  145000 loss  0.07433073967695236
# step  146000 loss  0.07140149176120758
# step  147000 loss  0.07685549557209015
# step  148000 loss  0.07254711538553238
# step  149000 loss  0.0760386660695076
# step  150000 loss  0.07389749586582184
# step  151000 loss  0.07023922353982925
# step  152000 loss  0.07443942129611969
# step  153000 loss  0.07119348645210266
# step  154000 loss  0.07382415980100632
# step  155000 loss  0.07026609778404236
# step  156000 loss  0.06947407871484756
# step  157000 loss  0.06839259713888168
# step  158000 loss  0.06876548379659653
# step  159000 loss  0.07146237790584564
# step  160000 loss  0.07138429582118988
# step  161000 loss  0.06684505939483643
# step  162000 loss  0.07034789025783539
# step  163000 loss  0.07358074933290482
# step  164000 loss  0.0683106854557991
# step  165000 loss  0.06882532685995102
# step  166000 loss  0.06907779723405838
# step  167000 loss  0.07781827449798584
# step  168000 loss  0.07107903063297272
# step  169000 loss  0.06845460832118988
# step  170000 loss  0.07391990721225739
# step  171000 loss  0.06866316497325897
# step  172000 loss  0.06603352725505829
# step  173000 loss  0.07376328855752945
# step  174000 loss  0.06853725016117096
# step  175000 loss  0.06950785219669342
# step  176000 loss  0.0713256448507309
# step  177000 loss  0.06442289054393768
# step  178000 loss  0.07633695751428604
# step  179000 loss  0.07130047678947449
# step  180000 loss  0.07129333913326263
# step  181000 loss  0.06908086687326431
# step  182000 loss  0.07065398246049881
# step  183000 loss  0.06627997010946274
# step  184000 loss  0.07058903574943542
# step  185000 loss  0.06963025033473969
# step  186000 loss  0.0685637965798378
# step  187000 loss  0.07589380443096161
# step  188000 loss  0.06642992049455643
# step  189000 loss  0.07149381190538406
# step  190000 loss  0.07001904398202896
# step  191000 loss  0.07320484519004822
# step  192000 loss  0.06943587213754654
# step  193000 loss  0.07086613029241562
# step  194000 loss  0.0647810697555542
# step  195000 loss  0.06883074343204498
# step  196000 loss  0.06940726190805435
# step  197000 loss  0.0660863071680069
# step  198000 loss  0.07700851559638977
# step  199000 loss  0.06935593485832214

# %%
# !python ../src/scDiffusion/cell_train.py \
#   --data_dir '../data/emt_diff.h5ad' \
#   --vae_path '../models/scdiff/emt/VAE/model_seed=0_step=199999.pt' \
#   --model_name 'diffusion' \
#   --save_dir '../models/scdiff/emt' \
#   --batch_size 128 \
#   --lr 0.5e-5 \
#   --lr_anneal_steps 20000
# Out:
# Logging to ../models/scdiff/emt/diffusion/logs/diffusion
# creating model and diffusion...
# creating data loader...
# training...
# /mnt/home/islamsa3/anaconda3/envs/global/lib/python3.10/site-packages/numba/np/ufunc/parallel.py:371: NumbaWarning: The TBB threading layer requires TBB version 2021 update 6 or later i.e., TBB_INTERFACE_VERSION >= 12060. Found TBB_INTERFACE_VERSION = 12050. The TBB threading layer is disabled.
#   warnings.warn(problem)
# -------------------------
# | grad_norm  | 0.878    |
# | loss       | 1.13     |
# | loss_q0    | 1.17     |
# | loss_q1    | 1.12     |
# | loss_q2    | 1.27     |
# | loss_q3    | 1.28     |
# | mse        | 1.13     |
# | mse_q0     | 1.17     |
# | mse_q1     | 1.12     |
# | mse_q2     | 1.27     |
# | mse_q3     | 1.28     |
# | param_norm | 79       |
# | samples    | 128      |
# | step       | 0        |
# -------------------------
# saving model 0...
# saving model 0.9999...
# -------------------------
# | grad_norm  | 0.643    |
# | loss       | 1.02     |
# | loss_q0    | 0.958    |
# | loss_q1    | 1.17     |
# | loss_q2    | 1.08     |
# | loss_q3    | 0.973    |
# | mse        | 1.02     |
# | mse_q0     | 0.958    |
# | mse_q1     | 1.17     |
# | mse_q2     | 1.08     |
# | mse_q3     | 0.973    |
# | param_norm | 79       |
# | samples    | 1.29e+04 |
# | step       | 100      |
# -------------------------
# -------------------------
# | grad_norm  | 0.505    |
# | loss       | 0.975    |
# | loss_q0    | 0.925    |
# | loss_q1    | 0.895    |
# | loss_q2    | 0.913    |
# | loss_q3    | 0.927    |
# | mse        | 0.975    |
# | mse_q0     | 0.925    |
# | mse_q1     | 0.895    |
# | mse_q2     | 0.913    |
# | mse_q3     | 0.927    |
# | param_norm | 79       |
# | samples    | 2.57e+04 |
# | step       | 200      |
# -------------------------
# -------------------------
# | grad_norm  | 0.473    |
# | loss       | 0.921    |
# | loss_q0    | 0.849    |
# | loss_q1    | 0.943    |
# | loss_q2    | 0.938    |
# | loss_q3    | 1        |
# | mse        | 0.921    |
# | mse_q0     | 0.849    |
# | mse_q1     | 0.943    |
# | mse_q2     | 0.938    |
# | mse_q3     | 1        |
# | param_norm | 79       |
# | samples    | 3.85e+04 |
# | step       | 300      |
# -------------------------
# -------------------------
# | grad_norm  | 0.457    |
# | loss       | 0.897    |
# | loss_q0    | 1.01     |
# | loss_q1    | 0.88     |
# | loss_q2    | 1.04     |
# | loss_q3    | 0.778    |
# | mse        | 0.897    |
# | mse_q0     | 1.01     |
# | mse_q1     | 0.88     |
# | mse_q2     | 1.04     |
# | mse_q3     | 0.778    |
# | param_norm | 79       |
# | samples    | 5.13e+04 |
# | step       | 400      |
# -------------------------
# -------------------------
# | grad_norm  | 0.455    |
# | loss       | 0.857    |
# | loss_q0    | 0.804    |
# | loss_q1    | 0.774    |
# | loss_q2    | 0.752    |
# | loss_q3    | 0.855    |
# | mse        | 0.857    |
# | mse_q0     | 0.804    |
# | mse_q1     | 0.774    |
# | mse_q2     | 0.752    |
# | mse_q3     | 0.855    |
# | param_norm | 79       |
# | samples    | 6.41e+04 |
# | step       | 500      |
# -------------------------
# -------------------------
# | grad_norm  | 0.453    |
# | loss       | 0.821    |
# | loss_q0    | 0.799    |
# | loss_q1    | 0.766    |
# | loss_q2    | 0.876    |
# | loss_q3    | 0.614    |
# | mse        | 0.821    |
# | mse_q0     | 0.799    |
# | mse_q1     | 0.766    |
# | mse_q2     | 0.876    |
# | mse_q3     | 0.614    |
# | param_norm | 79       |
# | samples    | 7.69e+04 |
# | step       | 600      |
# -------------------------
# -------------------------
# | grad_norm  | 0.452    |
# | loss       | 0.769    |
# | loss_q0    | 0.706    |
# | loss_q1    | 0.856    |
# | loss_q2    | 0.712    |
# | loss_q3    | 0.742    |
# | mse        | 0.769    |
# | mse_q0     | 0.706    |
# | mse_q1     | 0.856    |
# | mse_q2     | 0.712    |
# | mse_q3     | 0.742    |
# | param_norm | 79       |
# | samples    | 8.97e+04 |
# | step       | 700      |
# -------------------------
# -------------------------
# | grad_norm  | 0.449    |
# | loss       | 0.74     |
# | loss_q0    | 0.789    |
# | loss_q1    | 0.609    |
# | loss_q2    | 0.776    |
# | loss_q3    | 0.909    |
# | mse        | 0.74     |
# | mse_q0     | 0.789    |
# | mse_q1     | 0.609    |
# | mse_q2     | 0.776    |
# | mse_q3     | 0.909    |
# | param_norm | 79       |
# | samples    | 1.03e+05 |
# | step       | 800      |
# -------------------------
# -------------------------
# | grad_norm  | 0.445    |
# | loss       | 0.694    |
# | loss_q0    | 0.829    |
# | loss_q1    | 0.635    |
# | loss_q2    | 0.804    |
# | loss_q3    | 0.479    |
# | mse        | 0.694    |
# | mse_q0     | 0.829    |
# | mse_q1     | 0.635    |
# | mse_q2     | 0.804    |
# | mse_q3     | 0.479    |
# | param_norm | 79       |
# | samples    | 1.15e+05 |
# | step       | 900      |
# -------------------------
# -------------------------
# | grad_norm  | 0.441    |
# | loss       | 0.674    |
# | loss_q0    | 0.72     |
# | loss_q1    | 0.573    |
# | loss_q2    | 0.653    |
# | loss_q3    | 0.608    |
# | mse        | 0.674    |
# | mse_q0     | 0.72     |
# | mse_q1     | 0.573    |
# | mse_q2     | 0.653    |
# | mse_q3     | 0.608    |
# | param_norm | 79       |
# | samples    | 1.28e+05 |
# | step       | 1e+03    |
# -------------------------
# -------------------------
# | grad_norm  | 0.437    |
# | loss       | 0.636    |
# | loss_q0    | 0.658    |
# | loss_q1    | 0.571    |
# | loss_q2    | 0.736    |
# | loss_q3    | 0.609    |
# | mse        | 0.636    |
# | mse_q0     | 0.658    |
# | mse_q1     | 0.571    |
# | mse_q2     | 0.736    |
# | mse_q3     | 0.609    |
# | param_norm | 79       |
# | samples    | 1.41e+05 |
# | step       | 1.1e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.434    |
# | loss       | 0.607    |
# | loss_q0    | 0.513    |
# | loss_q1    | 0.612    |
# | loss_q2    | 0.445    |
# | loss_q3    | 0.516    |
# | mse        | 0.607    |
# | mse_q0     | 0.513    |
# | mse_q1     | 0.612    |
# | mse_q2     | 0.445    |
# | mse_q3     | 0.516    |
# | param_norm | 79       |
# | samples    | 1.54e+05 |
# | step       | 1.2e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.428    |
# | loss       | 0.592    |
# | loss_q0    | 0.909    |
# | loss_q1    | 0.721    |
# | loss_q2    | 0.487    |
# | loss_q3    | 0.642    |
# | mse        | 0.592    |
# | mse_q0     | 0.909    |
# | mse_q1     | 0.721    |
# | mse_q2     | 0.487    |
# | mse_q3     | 0.642    |
# | param_norm | 79       |
# | samples    | 1.67e+05 |
# | step       | 1.3e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.426    |
# | loss       | 0.573    |
# | loss_q0    | 0.67     |
# | loss_q1    | 0.604    |
# | loss_q2    | 0.455    |
# | loss_q3    | 0.715    |
# | mse        | 0.573    |
# | mse_q0     | 0.67     |
# | mse_q1     | 0.604    |
# | mse_q2     | 0.455    |
# | mse_q3     | 0.715    |
# | param_norm | 79       |
# | samples    | 1.79e+05 |
# | step       | 1.4e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.425    |
# | loss       | 0.541    |
# | loss_q0    | 0.466    |
# | loss_q1    | 0.556    |
# | loss_q2    | 0.619    |
# | loss_q3    | 0.533    |
# | mse        | 0.541    |
# | mse_q0     | 0.466    |
# | mse_q1     | 0.556    |
# | mse_q2     | 0.619    |
# | mse_q3     | 0.533    |
# | param_norm | 79       |
# | samples    | 1.92e+05 |
# | step       | 1.5e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.423    |
# | loss       | 0.518    |
# | loss_q0    | 0.612    |
# | loss_q1    | 0.625    |
# | loss_q2    | 0.662    |
# | loss_q3    | 0.552    |
# | mse        | 0.518    |
# | mse_q0     | 0.612    |
# | mse_q1     | 0.625    |
# | mse_q2     | 0.662    |
# | mse_q3     | 0.552    |
# | param_norm | 79       |
# | samples    | 2.05e+05 |
# | step       | 1.6e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.423    |
# | loss       | 0.492    |
# | loss_q0    | 0.574    |
# | loss_q1    | 0.419    |
# | loss_q2    | 0.353    |
# | loss_q3    | 0.354    |
# | mse        | 0.492    |
# | mse_q0     | 0.574    |
# | mse_q1     | 0.419    |
# | mse_q2     | 0.353    |
# | mse_q3     | 0.354    |
# | param_norm | 79       |
# | samples    | 2.18e+05 |
# | step       | 1.7e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.422    |
# | loss       | 0.478    |
# | loss_q0    | 0.494    |
# | loss_q1    | 0.468    |
# | loss_q2    | 0.402    |
# | loss_q3    | 0.456    |
# | mse        | 0.478    |
# | mse_q0     | 0.494    |
# | mse_q1     | 0.468    |
# | mse_q2     | 0.402    |
# | mse_q3     | 0.456    |
# | param_norm | 79       |
# | samples    | 2.31e+05 |
# | step       | 1.8e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.431    |
# | loss       | 0.449    |
# | loss_q0    | 0.4      |
# | loss_q1    | 0.357    |
# | loss_q2    | 0.466    |
# | loss_q3    | 0.522    |
# | mse        | 0.449    |
# | mse_q0     | 0.4      |
# | mse_q1     | 0.357    |
# | mse_q2     | 0.466    |
# | mse_q3     | 0.522    |
# | param_norm | 79       |
# | samples    | 2.43e+05 |
# | step       | 1.9e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.436    |
# | loss       | 0.428    |
# | loss_q0    | 0.495    |
# | loss_q1    | 0.479    |
# | loss_q2    | 0.493    |
# | loss_q3    | 0.43     |
# | mse        | 0.428    |
# | mse_q0     | 0.495    |
# | mse_q1     | 0.479    |
# | mse_q2     | 0.493    |
# | mse_q3     | 0.43     |
# | param_norm | 79       |
# | samples    | 2.56e+05 |
# | step       | 2e+03    |
# -------------------------
# -------------------------
# | grad_norm  | 0.444    |
# | loss       | 0.413    |
# | loss_q0    | 0.387    |
# | loss_q1    | 0.39     |
# | loss_q2    | 0.332    |
# | loss_q3    | 0.284    |
# | mse        | 0.413    |
# | mse_q0     | 0.387    |
# | mse_q1     | 0.39     |
# | mse_q2     | 0.332    |
# | mse_q3     | 0.284    |
# | param_norm | 79       |
# | samples    | 2.69e+05 |
# | step       | 2.1e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.447    |
# | loss       | 0.381    |
# | loss_q0    | 0.54     |
# | loss_q1    | 0.503    |
# | loss_q2    | 0.352    |
# | loss_q3    | 0.386    |
# | mse        | 0.381    |
# | mse_q0     | 0.54     |
# | mse_q1     | 0.503    |
# | mse_q2     | 0.352    |
# | mse_q3     | 0.386    |
# | param_norm | 79       |
# | samples    | 2.82e+05 |
# | step       | 2.2e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.462    |
# | loss       | 0.385    |
# | loss_q0    | 0.275    |
# | loss_q1    | 0.385    |
# | loss_q2    | 0.395    |
# | loss_q3    | 0.448    |
# | mse        | 0.385    |
# | mse_q0     | 0.275    |
# | mse_q1     | 0.385    |
# | mse_q2     | 0.395    |
# | mse_q3     | 0.448    |
# | param_norm | 79       |
# | samples    | 2.95e+05 |
# | step       | 2.3e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.473    |
# | loss       | 0.353    |
# | loss_q0    | 0.392    |
# | loss_q1    | 0.233    |
# | loss_q2    | 0.247    |
# | loss_q3    | 0.455    |
# | mse        | 0.353    |
# | mse_q0     | 0.392    |
# | mse_q1     | 0.233    |
# | mse_q2     | 0.247    |
# | mse_q3     | 0.455    |
# | param_norm | 79       |
# | samples    | 3.07e+05 |
# | step       | 2.4e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.494    |
# | loss       | 0.347    |
# | loss_q0    | 0.416    |
# | loss_q1    | 0.362    |
# | loss_q2    | 0.334    |
# | loss_q3    | 0.259    |
# | mse        | 0.347    |
# | mse_q0     | 0.416    |
# | mse_q1     | 0.362    |
# | mse_q2     | 0.334    |
# | mse_q3     | 0.259    |
# | param_norm | 79.1     |
# | samples    | 3.2e+05  |
# | step       | 2.5e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.512    |
# | loss       | 0.317    |
# | loss_q0    | 0.304    |
# | loss_q1    | 0.347    |
# | loss_q2    | 0.324    |
# | loss_q3    | 0.249    |
# | mse        | 0.317    |
# | mse_q0     | 0.304    |
# | mse_q1     | 0.347    |
# | mse_q2     | 0.324    |
# | mse_q3     | 0.249    |
# | param_norm | 79.1     |
# | samples    | 3.33e+05 |
# | step       | 2.6e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.522    |
# | loss       | 0.306    |
# | loss_q0    | 0.415    |
# | loss_q1    | 0.236    |
# | loss_q2    | 0.228    |
# | loss_q3    | 0.285    |
# | mse        | 0.306    |
# | mse_q0     | 0.415    |
# | mse_q1     | 0.236    |
# | mse_q2     | 0.228    |
# | mse_q3     | 0.285    |
# | param_norm | 79.1     |
# | samples    | 3.46e+05 |
# | step       | 2.7e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.534    |
# | loss       | 0.294    |
# | loss_q0    | 0.334    |
# | loss_q1    | 0.215    |
# | loss_q2    | 0.324    |
# | loss_q3    | 0.327    |
# | mse        | 0.294    |
# | mse_q0     | 0.334    |
# | mse_q1     | 0.215    |
# | mse_q2     | 0.324    |
# | mse_q3     | 0.327    |
# | param_norm | 79.1     |
# | samples    | 3.59e+05 |
# | step       | 2.8e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.55     |
# | loss       | 0.289    |
# | loss_q0    | 0.167    |
# | loss_q1    | 0.257    |
# | loss_q2    | 0.224    |
# | loss_q3    | 0.186    |
# | mse        | 0.289    |
# | mse_q0     | 0.167    |
# | mse_q1     | 0.257    |
# | mse_q2     | 0.224    |
# | mse_q3     | 0.186    |
# | param_norm | 79.1     |
# | samples    | 3.71e+05 |
# | step       | 2.9e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.556    |
# | loss       | 0.269    |
# | loss_q0    | 0.472    |
# | loss_q1    | 0.166    |
# | loss_q2    | 0.301    |
# | loss_q3    | 0.223    |
# | mse        | 0.269    |
# | mse_q0     | 0.472    |
# | mse_q1     | 0.166    |
# | mse_q2     | 0.301    |
# | mse_q3     | 0.223    |
# | param_norm | 79.1     |
# | samples    | 3.84e+05 |
# | step       | 3e+03    |
# -------------------------
# -------------------------
# | grad_norm  | 0.588    |
# | loss       | 0.255    |
# | loss_q0    | 0.291    |
# | loss_q1    | 0.229    |
# | loss_q2    | 0.277    |
# | loss_q3    | 0.209    |
# | mse        | 0.255    |
# | mse_q0     | 0.291    |
# | mse_q1     | 0.229    |
# | mse_q2     | 0.277    |
# | mse_q3     | 0.209    |
# | param_norm | 79.1     |
# | samples    | 3.97e+05 |
# | step       | 3.1e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.583    |
# | loss       | 0.252    |
# | loss_q0    | 0.304    |
# | loss_q1    | 0.3      |
# | loss_q2    | 0.208    |
# | loss_q3    | 0.32     |
# | mse        | 0.252    |
# | mse_q0     | 0.304    |
# | mse_q1     | 0.3      |
# | mse_q2     | 0.208    |
# | mse_q3     | 0.32     |
# | param_norm | 79.1     |
# | samples    | 4.1e+05  |
# | step       | 3.2e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.605    |
# | loss       | 0.257    |
# | loss_q0    | 0.339    |
# | loss_q1    | 0.334    |
# | loss_q2    | 0.228    |
# | loss_q3    | 0.192    |
# | mse        | 0.257    |
# | mse_q0     | 0.339    |
# | mse_q1     | 0.334    |
# | mse_q2     | 0.228    |
# | mse_q3     | 0.192    |
# | param_norm | 79.1     |
# | samples    | 4.23e+05 |
# | step       | 3.3e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.63     |
# | loss       | 0.227    |
# | loss_q0    | 0.24     |
# | loss_q1    | 0.18     |
# | loss_q2    | 0.196    |
# | loss_q3    | 0.166    |
# | mse        | 0.227    |
# | mse_q0     | 0.24     |
# | mse_q1     | 0.18     |
# | mse_q2     | 0.196    |
# | mse_q3     | 0.166    |
# | param_norm | 79.1     |
# | samples    | 4.35e+05 |
# | step       | 3.4e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.626    |
# | loss       | 0.227    |
# | loss_q0    | 0.289    |
# | loss_q1    | 0.219    |
# | loss_q2    | 0.127    |
# | loss_q3    | 0.157    |
# | mse        | 0.227    |
# | mse_q0     | 0.289    |
# | mse_q1     | 0.219    |
# | mse_q2     | 0.127    |
# | mse_q3     | 0.157    |
# | param_norm | 79.1     |
# | samples    | 4.48e+05 |
# | step       | 3.5e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.626    |
# | loss       | 0.213    |
# | loss_q0    | 0.164    |
# | loss_q1    | 0.181    |
# | loss_q2    | 0.171    |
# | loss_q3    | 0.113    |
# | mse        | 0.213    |
# | mse_q0     | 0.164    |
# | mse_q1     | 0.181    |
# | mse_q2     | 0.171    |
# | mse_q3     | 0.113    |
# | param_norm | 79.1     |
# | samples    | 4.61e+05 |
# | step       | 3.6e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.637    |
# | loss       | 0.19     |
# | loss_q0    | 0.217    |
# | loss_q1    | 0.206    |
# | loss_q2    | 0.151    |
# | loss_q3    | 0.154    |
# | mse        | 0.19     |
# | mse_q0     | 0.217    |
# | mse_q1     | 0.206    |
# | mse_q2     | 0.151    |
# | mse_q3     | 0.154    |
# | param_norm | 79.1     |
# | samples    | 4.74e+05 |
# | step       | 3.7e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.658    |
# | loss       | 0.187    |
# | loss_q0    | 0.109    |
# | loss_q1    | 0.187    |
# | loss_q2    | 0.234    |
# | loss_q3    | 0.261    |
# | mse        | 0.187    |
# | mse_q0     | 0.109    |
# | mse_q1     | 0.187    |
# | mse_q2     | 0.234    |
# | mse_q3     | 0.261    |
# | param_norm | 79.2     |
# | samples    | 4.87e+05 |
# | step       | 3.8e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.653    |
# | loss       | 0.184    |
# | loss_q0    | 0.141    |
# | loss_q1    | 0.146    |
# | loss_q2    | 0.294    |
# | loss_q3    | 0.215    |
# | mse        | 0.184    |
# | mse_q0     | 0.141    |
# | mse_q1     | 0.146    |
# | mse_q2     | 0.294    |
# | mse_q3     | 0.215    |
# | param_norm | 79.2     |
# | samples    | 4.99e+05 |
# | step       | 3.9e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.67     |
# | loss       | 0.178    |
# | loss_q0    | 0.117    |
# | loss_q1    | 0.134    |
# | loss_q2    | 0.227    |
# | loss_q3    | 0.168    |
# | mse        | 0.178    |
# | mse_q0     | 0.117    |
# | mse_q1     | 0.134    |
# | mse_q2     | 0.227    |
# | mse_q3     | 0.168    |
# | param_norm | 79.2     |
# | samples    | 5.12e+05 |
# | step       | 4e+03    |
# -------------------------
# -------------------------
# | grad_norm  | 0.664    |
# | loss       | 0.169    |
# | loss_q0    | 0.124    |
# | loss_q1    | 0.142    |
# | loss_q2    | 0.116    |
# | loss_q3    | 0.148    |
# | mse        | 0.169    |
# | mse_q0     | 0.124    |
# | mse_q1     | 0.142    |
# | mse_q2     | 0.116    |
# | mse_q3     | 0.148    |
# | param_norm | 79.2     |
# | samples    | 5.25e+05 |
# | step       | 4.1e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.693    |
# | loss       | 0.158    |
# | loss_q0    | 0.239    |
# | loss_q1    | 0.138    |
# | loss_q2    | 0.0871   |
# | loss_q3    | 0.135    |
# | mse        | 0.158    |
# | mse_q0     | 0.239    |
# | mse_q1     | 0.138    |
# | mse_q2     | 0.0871   |
# | mse_q3     | 0.135    |
# | param_norm | 79.2     |
# | samples    | 5.38e+05 |
# | step       | 4.2e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.695    |
# | loss       | 0.15     |
# | loss_q0    | 0.165    |
# | loss_q1    | 0.182    |
# | loss_q2    | 0.128    |
# | loss_q3    | 0.186    |
# | mse        | 0.15     |
# | mse_q0     | 0.165    |
# | mse_q1     | 0.182    |
# | mse_q2     | 0.128    |
# | mse_q3     | 0.186    |
# | param_norm | 79.2     |
# | samples    | 5.51e+05 |
# | step       | 4.3e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.693    |
# | loss       | 0.145    |
# | loss_q0    | 0.163    |
# | loss_q1    | 0.128    |
# | loss_q2    | 0.12     |
# | loss_q3    | 0.126    |
# | mse        | 0.145    |
# | mse_q0     | 0.163    |
# | mse_q1     | 0.128    |
# | mse_q2     | 0.12     |
# | mse_q3     | 0.126    |
# | param_norm | 79.2     |
# | samples    | 5.63e+05 |
# | step       | 4.4e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.726    |
# | loss       | 0.145    |
# | loss_q0    | 0.168    |
# | loss_q1    | 0.0929   |
# | loss_q2    | 0.116    |
# | loss_q3    | 0.133    |
# | mse        | 0.145    |
# | mse_q0     | 0.168    |
# | mse_q1     | 0.0929   |
# | mse_q2     | 0.116    |
# | mse_q3     | 0.133    |
# | param_norm | 79.2     |
# | samples    | 5.76e+05 |
# | step       | 4.5e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.726    |
# | loss       | 0.129    |
# | loss_q0    | 0.107    |
# | loss_q1    | 0.124    |
# | loss_q2    | 0.183    |
# | loss_q3    | 0.172    |
# | mse        | 0.129    |
# | mse_q0     | 0.107    |
# | mse_q1     | 0.124    |
# | mse_q2     | 0.183    |
# | mse_q3     | 0.172    |
# | param_norm | 79.2     |
# | samples    | 5.89e+05 |
# | step       | 4.6e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.722    |
# | loss       | 0.132    |
# | loss_q0    | 0.101    |
# | loss_q1    | 0.118    |
# | loss_q2    | 0.0955   |
# | loss_q3    | 0.098    |
# | mse        | 0.132    |
# | mse_q0     | 0.101    |
# | mse_q1     | 0.118    |
# | mse_q2     | 0.0955   |
# | mse_q3     | 0.098    |
# | param_norm | 79.2     |
# | samples    | 6.02e+05 |
# | step       | 4.7e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.728    |
# | loss       | 0.121    |
# | loss_q0    | 0.0999   |
# | loss_q1    | 0.209    |
# | loss_q2    | 0.166    |
# | loss_q3    | 0.104    |
# | mse        | 0.121    |
# | mse_q0     | 0.0999   |
# | mse_q1     | 0.209    |
# | mse_q2     | 0.166    |
# | mse_q3     | 0.104    |
# | param_norm | 79.2     |
# | samples    | 6.15e+05 |
# | step       | 4.8e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.733    |
# | loss       | 0.119    |
# | loss_q0    | 0.0717   |
# | loss_q1    | 0.136    |
# | loss_q2    | 0.0995   |
# | loss_q3    | 0.0592   |
# | mse        | 0.119    |
# | mse_q0     | 0.0717   |
# | mse_q1     | 0.136    |
# | mse_q2     | 0.0995   |
# | mse_q3     | 0.0592   |
# | param_norm | 79.2     |
# | samples    | 6.27e+05 |
# | step       | 4.9e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.719    |
# | loss       | 0.124    |
# | loss_q0    | 0.0881   |
# | loss_q1    | 0.133    |
# | loss_q2    | 0.105    |
# | loss_q3    | 0.104    |
# | mse        | 0.124    |
# | mse_q0     | 0.0881   |
# | mse_q1     | 0.133    |
# | mse_q2     | 0.105    |
# | mse_q3     | 0.104    |
# | param_norm | 79.2     |
# | samples    | 6.4e+05  |
# | step       | 5e+03    |
# -------------------------
# -------------------------
# | grad_norm  | 0.73     |
# | loss       | 0.133    |
# | loss_q0    | 0.219    |
# | loss_q1    | 0.123    |
# | loss_q2    | 0.118    |
# | loss_q3    | 0.062    |
# | mse        | 0.133    |
# | mse_q0     | 0.219    |
# | mse_q1     | 0.123    |
# | mse_q2     | 0.118    |
# | mse_q3     | 0.062    |
# | param_norm | 79.2     |
# | samples    | 6.53e+05 |
# | step       | 5.1e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.743    |
# | loss       | 0.118    |
# | loss_q0    | 0.0722   |
# | loss_q1    | 0.093    |
# | loss_q2    | 0.109    |
# | loss_q3    | 0.0964   |
# | mse        | 0.118    |
# | mse_q0     | 0.0722   |
# | mse_q1     | 0.093    |
# | mse_q2     | 0.109    |
# | mse_q3     | 0.0964   |
# | param_norm | 79.2     |
# | samples    | 6.66e+05 |
# | step       | 5.2e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.757    |
# | loss       | 0.11     |
# | loss_q0    | 0.1      |
# | loss_q1    | 0.0568   |
# | loss_q2    | 0.0856   |
# | loss_q3    | 0.159    |
# | mse        | 0.11     |
# | mse_q0     | 0.1      |
# | mse_q1     | 0.0568   |
# | mse_q2     | 0.0856   |
# | mse_q3     | 0.159    |
# | param_norm | 79.3     |
# | samples    | 6.79e+05 |
# | step       | 5.3e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.765    |
# | loss       | 0.101    |
# | loss_q0    | 0.108    |
# | loss_q1    | 0.122    |
# | loss_q2    | 0.0893   |
# | loss_q3    | 0.104    |
# | mse        | 0.101    |
# | mse_q0     | 0.108    |
# | mse_q1     | 0.122    |
# | mse_q2     | 0.0893   |
# | mse_q3     | 0.104    |
# | param_norm | 79.3     |
# | samples    | 6.91e+05 |
# | step       | 5.4e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.758    |
# | loss       | 0.108    |
# | loss_q0    | 0.0825   |
# | loss_q1    | 0.197    |
# | loss_q2    | 0.0682   |
# | loss_q3    | 0.0884   |
# | mse        | 0.108    |
# | mse_q0     | 0.0825   |
# | mse_q1     | 0.197    |
# | mse_q2     | 0.0682   |
# | mse_q3     | 0.0884   |
# | param_norm | 79.3     |
# | samples    | 7.04e+05 |
# | step       | 5.5e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.779    |
# | loss       | 0.0994   |
# | loss_q0    | 0.156    |
# | loss_q1    | 0.0712   |
# | loss_q2    | 0.083    |
# | loss_q3    | 0.0955   |
# | mse        | 0.0994   |
# | mse_q0     | 0.156    |
# | mse_q1     | 0.0712   |
# | mse_q2     | 0.083    |
# | mse_q3     | 0.0955   |
# | param_norm | 79.3     |
# | samples    | 7.17e+05 |
# | step       | 5.6e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.803    |
# | loss       | 0.104    |
# | loss_q0    | 0.212    |
# | loss_q1    | 0.114    |
# | loss_q2    | 0.0658   |
# | loss_q3    | 0.0834   |
# | mse        | 0.104    |
# | mse_q0     | 0.212    |
# | mse_q1     | 0.114    |
# | mse_q2     | 0.0658   |
# | mse_q3     | 0.0834   |
# | param_norm | 79.3     |
# | samples    | 7.3e+05  |
# | step       | 5.7e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.782    |
# | loss       | 0.0959   |
# | loss_q0    | 0.0583   |
# | loss_q1    | 0.0663   |
# | loss_q2    | 0.0566   |
# | loss_q3    | 0.0687   |
# | mse        | 0.0959   |
# | mse_q0     | 0.0583   |
# | mse_q1     | 0.0663   |
# | mse_q2     | 0.0566   |
# | mse_q3     | 0.0687   |
# | param_norm | 79.3     |
# | samples    | 7.43e+05 |
# | step       | 5.8e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.777    |
# | loss       | 0.102    |
# | loss_q0    | 0.128    |
# | loss_q1    | 0.0923   |
# | loss_q2    | 0.138    |
# | loss_q3    | 0.0911   |
# | mse        | 0.102    |
# | mse_q0     | 0.128    |
# | mse_q1     | 0.0923   |
# | mse_q2     | 0.138    |
# | mse_q3     | 0.0911   |
# | param_norm | 79.3     |
# | samples    | 7.55e+05 |
# | step       | 5.9e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.803    |
# | loss       | 0.098    |
# | loss_q0    | 0.0605   |
# | loss_q1    | 0.0845   |
# | loss_q2    | 0.097    |
# | loss_q3    | 0.0667   |
# | mse        | 0.098    |
# | mse_q0     | 0.0605   |
# | mse_q1     | 0.0845   |
# | mse_q2     | 0.097    |
# | mse_q3     | 0.0667   |
# | param_norm | 79.3     |
# | samples    | 7.68e+05 |
# | step       | 6e+03    |
# -------------------------
# -------------------------
# | grad_norm  | 0.768    |
# | loss       | 0.085    |
# | loss_q0    | 0.0636   |
# | loss_q1    | 0.0616   |
# | loss_q2    | 0.0486   |
# | loss_q3    | 0.101    |
# | mse        | 0.085    |
# | mse_q0     | 0.0636   |
# | mse_q1     | 0.0616   |
# | mse_q2     | 0.0486   |
# | mse_q3     | 0.101    |
# | param_norm | 79.3     |
# | samples    | 7.81e+05 |
# | step       | 6.1e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.813    |
# | loss       | 0.0936   |
# | loss_q0    | 0.0791   |
# | loss_q1    | 0.131    |
# | loss_q2    | 0.062    |
# | loss_q3    | 0.0554   |
# | mse        | 0.0936   |
# | mse_q0     | 0.0791   |
# | mse_q1     | 0.131    |
# | mse_q2     | 0.062    |
# | mse_q3     | 0.0554   |
# | param_norm | 79.3     |
# | samples    | 7.94e+05 |
# | step       | 6.2e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.823    |
# | loss       | 0.0933   |
# | loss_q0    | 0.0595   |
# | loss_q1    | 0.0794   |
# | loss_q2    | 0.066    |
# | loss_q3    | 0.113    |
# | mse        | 0.0933   |
# | mse_q0     | 0.0595   |
# | mse_q1     | 0.0794   |
# | mse_q2     | 0.066    |
# | mse_q3     | 0.113    |
# | param_norm | 79.3     |
# | samples    | 8.07e+05 |
# | step       | 6.3e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.775    |
# | loss       | 0.0729   |
# | loss_q0    | 0.0514   |
# | loss_q1    | 0.112    |
# | loss_q2    | 0.0673   |
# | loss_q3    | 0.0958   |
# | mse        | 0.0729   |
# | mse_q0     | 0.0514   |
# | mse_q1     | 0.112    |
# | mse_q2     | 0.0673   |
# | mse_q3     | 0.0958   |
# | param_norm | 79.3     |
# | samples    | 8.19e+05 |
# | step       | 6.4e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.807    |
# | loss       | 0.0843   |
# | loss_q0    | 0.0403   |
# | loss_q1    | 0.0868   |
# | loss_q2    | 0.0596   |
# | loss_q3    | 0.0876   |
# | mse        | 0.0843   |
# | mse_q0     | 0.0403   |
# | mse_q1     | 0.0868   |
# | mse_q2     | 0.0596   |
# | mse_q3     | 0.0876   |
# | param_norm | 79.3     |
# | samples    | 8.32e+05 |
# | step       | 6.5e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.806    |
# | loss       | 0.0825   |
# | loss_q0    | 0.054    |
# | loss_q1    | 0.1      |
# | loss_q2    | 0.0633   |
# | loss_q3    | 0.059    |
# | mse        | 0.0825   |
# | mse_q0     | 0.054    |
# | mse_q1     | 0.1      |
# | mse_q2     | 0.0633   |
# | mse_q3     | 0.059    |
# | param_norm | 79.3     |
# | samples    | 8.45e+05 |
# | step       | 6.6e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.839    |
# | loss       | 0.0846   |
# | loss_q0    | 0.0838   |
# | loss_q1    | 0.0713   |
# | loss_q2    | 0.0634   |
# | loss_q3    | 0.0538   |
# | mse        | 0.0846   |
# | mse_q0     | 0.0838   |
# | mse_q1     | 0.0713   |
# | mse_q2     | 0.0634   |
# | mse_q3     | 0.0538   |
# | param_norm | 79.3     |
# | samples    | 8.58e+05 |
# | step       | 6.7e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.82     |
# | loss       | 0.0901   |
# | loss_q0    | 0.917    |
# | loss_q1    | 0.0874   |
# | loss_q2    | 0.0614   |
# | loss_q3    | 0.0409   |
# | mse        | 0.0901   |
# | mse_q0     | 0.917    |
# | mse_q1     | 0.0874   |
# | mse_q2     | 0.0614   |
# | mse_q3     | 0.0409   |
# | param_norm | 79.3     |
# | samples    | 8.71e+05 |
# | step       | 6.8e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.786    |
# | loss       | 0.07     |
# | loss_q0    | 0.0475   |
# | loss_q1    | 0.0529   |
# | loss_q2    | 0.0525   |
# | loss_q3    | 0.0742   |
# | mse        | 0.07     |
# | mse_q0     | 0.0475   |
# | mse_q1     | 0.0529   |
# | mse_q2     | 0.0525   |
# | mse_q3     | 0.0742   |
# | param_norm | 79.3     |
# | samples    | 8.83e+05 |
# | step       | 6.9e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.845    |
# | loss       | 0.0781   |
# | loss_q0    | 0.461    |
# | loss_q1    | 0.0398   |
# | loss_q2    | 0.16     |
# | loss_q3    | 0.0811   |
# | mse        | 0.0781   |
# | mse_q0     | 0.461    |
# | mse_q1     | 0.0398   |
# | mse_q2     | 0.16     |
# | mse_q3     | 0.0811   |
# | param_norm | 79.3     |
# | samples    | 8.96e+05 |
# | step       | 7e+03    |
# -------------------------
# -------------------------
# | grad_norm  | 0.824    |
# | loss       | 0.0739   |
# | loss_q0    | 0.238    |
# | loss_q1    | 0.0468   |
# | loss_q2    | 0.0589   |
# | loss_q3    | 0.0446   |
# | mse        | 0.0739   |
# | mse_q0     | 0.238    |
# | mse_q1     | 0.0468   |
# | mse_q2     | 0.0589   |
# | mse_q3     | 0.0446   |
# | param_norm | 79.3     |
# | samples    | 9.09e+05 |
# | step       | 7.1e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.811    |
# | loss       | 0.083    |
# | loss_q0    | 0.696    |
# | loss_q1    | 0.052    |
# | loss_q2    | 0.0562   |
# | loss_q3    | 0.071    |
# | mse        | 0.083    |
# | mse_q0     | 0.696    |
# | mse_q1     | 0.052    |
# | mse_q2     | 0.0562   |
# | mse_q3     | 0.071    |
# | param_norm | 79.3     |
# | samples    | 9.22e+05 |
# | step       | 7.2e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.85     |
# | loss       | 0.0881   |
# | loss_q0    | 0.13     |
# | loss_q1    | 0.0459   |
# | loss_q2    | 0.0639   |
# | loss_q3    | 0.0537   |
# | mse        | 0.0881   |
# | mse_q0     | 0.13     |
# | mse_q1     | 0.0459   |
# | mse_q2     | 0.0639   |
# | mse_q3     | 0.0537   |
# | param_norm | 79.4     |
# | samples    | 9.35e+05 |
# | step       | 7.3e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.841    |
# | loss       | 0.0704   |
# | loss_q0    | 0.0602   |
# | loss_q1    | 0.08     |
# | loss_q2    | 0.041    |
# | loss_q3    | 0.0589   |
# | mse        | 0.0704   |
# | mse_q0     | 0.0602   |
# | mse_q1     | 0.08     |
# | mse_q2     | 0.041    |
# | mse_q3     | 0.0589   |
# | param_norm | 79.4     |
# | samples    | 9.47e+05 |
# | step       | 7.4e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.869    |
# | loss       | 0.0729   |
# | loss_q0    | 0.0487   |
# | loss_q1    | 0.0819   |
# | loss_q2    | 0.0601   |
# | loss_q3    | 0.0737   |
# | mse        | 0.0729   |
# | mse_q0     | 0.0487   |
# | mse_q1     | 0.0819   |
# | mse_q2     | 0.0601   |
# | mse_q3     | 0.0737   |
# | param_norm | 79.4     |
# | samples    | 9.6e+05  |
# | step       | 7.5e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.799    |
# | loss       | 0.0708   |
# | loss_q0    | 0.0709   |
# | loss_q1    | 0.0655   |
# | loss_q2    | 0.0449   |
# | loss_q3    | 0.0462   |
# | mse        | 0.0708   |
# | mse_q0     | 0.0709   |
# | mse_q1     | 0.0655   |
# | mse_q2     | 0.0449   |
# | mse_q3     | 0.0462   |
# | param_norm | 79.4     |
# | samples    | 9.73e+05 |
# | step       | 7.6e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.846    |
# | loss       | 0.0722   |
# | loss_q0    | 0.0769   |
# | loss_q1    | 0.0396   |
# | loss_q2    | 0.0562   |
# | loss_q3    | 0.0573   |
# | mse        | 0.0722   |
# | mse_q0     | 0.0769   |
# | mse_q1     | 0.0396   |
# | mse_q2     | 0.0562   |
# | mse_q3     | 0.0573   |
# | param_norm | 79.4     |
# | samples    | 9.86e+05 |
# | step       | 7.7e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.827    |
# | loss       | 0.0677   |
# | loss_q0    | 0.19     |
# | loss_q1    | 0.0325   |
# | loss_q2    | 0.0738   |
# | loss_q3    | 0.0301   |
# | mse        | 0.0677   |
# | mse_q0     | 0.19     |
# | mse_q1     | 0.0325   |
# | mse_q2     | 0.0738   |
# | mse_q3     | 0.0301   |
# | param_norm | 79.4     |
# | samples    | 9.99e+05 |
# | step       | 7.8e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.83     |
# | loss       | 0.0668   |
# | loss_q0    | 0.105    |
# | loss_q1    | 0.0503   |
# | loss_q2    | 0.0776   |
# | loss_q3    | 0.048    |
# | mse        | 0.0668   |
# | mse_q0     | 0.105    |
# | mse_q1     | 0.0503   |
# | mse_q2     | 0.0776   |
# | mse_q3     | 0.048    |
# | param_norm | 79.4     |
# | samples    | 1.01e+06 |
# | step       | 7.9e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.862    |
# | loss       | 0.0679   |
# | loss_q0    | 0.704    |
# | loss_q1    | 0.0555   |
# | loss_q2    | 0.0435   |
# | loss_q3    | 0.0546   |
# | mse        | 0.0679   |
# | mse_q0     | 0.704    |
# | mse_q1     | 0.0555   |
# | mse_q2     | 0.0435   |
# | mse_q3     | 0.0546   |
# | param_norm | 79.4     |
# | samples    | 1.02e+06 |
# | step       | 8e+03    |
# -------------------------
# -------------------------
# | grad_norm  | 0.857    |
# | loss       | 0.0931   |
# | loss_q0    | 0.62     |
# | loss_q1    | 0.0783   |
# | loss_q2    | 0.0467   |
# | loss_q3    | 0.0474   |
# | mse        | 0.0931   |
# | mse_q0     | 0.62     |
# | mse_q1     | 0.0783   |
# | mse_q2     | 0.0467   |
# | mse_q3     | 0.0474   |
# | param_norm | 79.4     |
# | samples    | 1.04e+06 |
# | step       | 8.1e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.86     |
# | loss       | 0.0659   |
# | loss_q0    | 0.0573   |
# | loss_q1    | 0.0526   |
# | loss_q2    | 0.044    |
# | loss_q3    | 0.0506   |
# | mse        | 0.0659   |
# | mse_q0     | 0.0573   |
# | mse_q1     | 0.0526   |
# | mse_q2     | 0.044    |
# | mse_q3     | 0.0506   |
# | param_norm | 79.4     |
# | samples    | 1.05e+06 |
# | step       | 8.2e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.852    |
# | loss       | 0.0687   |
# | loss_q0    | 0.085    |
# | loss_q1    | 0.046    |
# | loss_q2    | 0.0444   |
# | loss_q3    | 0.0422   |
# | mse        | 0.0687   |
# | mse_q0     | 0.085    |
# | mse_q1     | 0.046    |
# | mse_q2     | 0.0444   |
# | mse_q3     | 0.0422   |
# | param_norm | 79.4     |
# | samples    | 1.06e+06 |
# | step       | 8.3e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.842    |
# | loss       | 0.0706   |
# | loss_q0    | 0.135    |
# | loss_q1    | 0.0425   |
# | loss_q2    | 0.0462   |
# | loss_q3    | 0.0597   |
# | mse        | 0.0706   |
# | mse_q0     | 0.135    |
# | mse_q1     | 0.0425   |
# | mse_q2     | 0.0462   |
# | mse_q3     | 0.0597   |
# | param_norm | 79.4     |
# | samples    | 1.08e+06 |
# | step       | 8.4e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.859    |
# | loss       | 0.0646   |
# | loss_q0    | 0.0479   |
# | loss_q1    | 0.0467   |
# | loss_q2    | 0.0945   |
# | loss_q3    | 0.0618   |
# | mse        | 0.0646   |
# | mse_q0     | 0.0479   |
# | mse_q1     | 0.0467   |
# | mse_q2     | 0.0945   |
# | mse_q3     | 0.0618   |
# | param_norm | 79.4     |
# | samples    | 1.09e+06 |
# | step       | 8.5e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.833    |
# | loss       | 0.0652   |
# | loss_q0    | 0.0938   |
# | loss_q1    | 0.0467   |
# | loss_q2    | 0.0505   |
# | loss_q3    | 0.0479   |
# | mse        | 0.0652   |
# | mse_q0     | 0.0938   |
# | mse_q1     | 0.0467   |
# | mse_q2     | 0.0505   |
# | mse_q3     | 0.0479   |
# | param_norm | 79.4     |
# | samples    | 1.1e+06  |
# | step       | 8.6e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.859    |
# | loss       | 0.0586   |
# | loss_q0    | 0.0506   |
# | loss_q1    | 0.0379   |
# | loss_q2    | 0.0573   |
# | loss_q3    | 0.0415   |
# | mse        | 0.0586   |
# | mse_q0     | 0.0506   |
# | mse_q1     | 0.0379   |
# | mse_q2     | 0.0573   |
# | mse_q3     | 0.0415   |
# | param_norm | 79.4     |
# | samples    | 1.11e+06 |
# | step       | 8.7e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.832    |
# | loss       | 0.0607   |
# | loss_q0    | 0.0755   |
# | loss_q1    | 0.11     |
# | loss_q2    | 0.0425   |
# | loss_q3    | 0.0426   |
# | mse        | 0.0607   |
# | mse_q0     | 0.0755   |
# | mse_q1     | 0.11     |
# | mse_q2     | 0.0425   |
# | mse_q3     | 0.0426   |
# | param_norm | 79.4     |
# | samples    | 1.13e+06 |
# | step       | 8.8e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.827    |
# | loss       | 0.0719   |
# | loss_q0    | 0.0529   |
# | loss_q1    | 0.0424   |
# | loss_q2    | 0.0277   |
# | loss_q3    | 0.0403   |
# | mse        | 0.0719   |
# | mse_q0     | 0.0529   |
# | mse_q1     | 0.0424   |
# | mse_q2     | 0.0277   |
# | mse_q3     | 0.0403   |
# | param_norm | 79.4     |
# | samples    | 1.14e+06 |
# | step       | 8.9e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.847    |
# | loss       | 0.0596   |
# | loss_q0    | 0.0449   |
# | loss_q1    | 0.0573   |
# | loss_q2    | 0.0528   |
# | loss_q3    | 0.0744   |
# | mse        | 0.0596   |
# | mse_q0     | 0.0449   |
# | mse_q1     | 0.0573   |
# | mse_q2     | 0.0528   |
# | mse_q3     | 0.0744   |
# | param_norm | 79.4     |
# | samples    | 1.15e+06 |
# | step       | 9e+03    |
# -------------------------
# -------------------------
# | grad_norm  | 0.866    |
# | loss       | 0.0749   |
# | loss_q0    | 0.351    |
# | loss_q1    | 0.0497   |
# | loss_q2    | 0.0588   |
# | loss_q3    | 0.0405   |
# | mse        | 0.0749   |
# | mse_q0     | 0.351    |
# | mse_q1     | 0.0497   |
# | mse_q2     | 0.0588   |
# | mse_q3     | 0.0405   |
# | param_norm | 79.4     |
# | samples    | 1.16e+06 |
# | step       | 9.1e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.839    |
# | loss       | 0.0674   |
# | loss_q0    | 0.0452   |
# | loss_q1    | 0.0377   |
# | loss_q2    | 0.0382   |
# | loss_q3    | 0.0638   |
# | mse        | 0.0674   |
# | mse_q0     | 0.0452   |
# | mse_q1     | 0.0377   |
# | mse_q2     | 0.0382   |
# | mse_q3     | 0.0638   |
# | param_norm | 79.4     |
# | samples    | 1.18e+06 |
# | step       | 9.2e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.844    |
# | loss       | 0.0656   |
# | loss_q0    | 0.0415   |
# | loss_q1    | 0.0359   |
# | loss_q2    | 0.0545   |
# | loss_q3    | 0.113    |
# | mse        | 0.0656   |
# | mse_q0     | 0.0415   |
# | mse_q1     | 0.0359   |
# | mse_q2     | 0.0545   |
# | mse_q3     | 0.113    |
# | param_norm | 79.4     |
# | samples    | 1.19e+06 |
# | step       | 9.3e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.82     |
# | loss       | 0.0621   |
# | loss_q0    | 0.166    |
# | loss_q1    | 0.0509   |
# | loss_q2    | 0.0695   |
# | loss_q3    | 0.0784   |
# | mse        | 0.0621   |
# | mse_q0     | 0.166    |
# | mse_q1     | 0.0509   |
# | mse_q2     | 0.0695   |
# | mse_q3     | 0.0784   |
# | param_norm | 79.4     |
# | samples    | 1.2e+06  |
# | step       | 9.4e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.873    |
# | loss       | 0.0574   |
# | loss_q0    | 0.106    |
# | loss_q1    | 0.0439   |
# | loss_q2    | 0.038    |
# | loss_q3    | 0.0392   |
# | mse        | 0.0574   |
# | mse_q0     | 0.106    |
# | mse_q1     | 0.0439   |
# | mse_q2     | 0.038    |
# | mse_q3     | 0.0392   |
# | param_norm | 79.4     |
# | samples    | 1.22e+06 |
# | step       | 9.5e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.82     |
# | loss       | 0.0652   |
# | loss_q0    | 0.0574   |
# | loss_q1    | 0.0425   |
# | loss_q2    | 0.0437   |
# | loss_q3    | 0.0762   |
# | mse        | 0.0652   |
# | mse_q0     | 0.0574   |
# | mse_q1     | 0.0425   |
# | mse_q2     | 0.0437   |
# | mse_q3     | 0.0762   |
# | param_norm | 79.4     |
# | samples    | 1.23e+06 |
# | step       | 9.6e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.811    |
# | loss       | 0.0516   |
# | loss_q0    | 0.0458   |
# | loss_q1    | 0.0536   |
# | loss_q2    | 0.0555   |
# | loss_q3    | 0.0383   |
# | mse        | 0.0516   |
# | mse_q0     | 0.0458   |
# | mse_q1     | 0.0536   |
# | mse_q2     | 0.0555   |
# | mse_q3     | 0.0383   |
# | param_norm | 79.4     |
# | samples    | 1.24e+06 |
# | step       | 9.7e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.847    |
# | loss       | 0.0575   |
# | loss_q0    | 0.0973   |
# | loss_q1    | 0.0416   |
# | loss_q2    | 0.0363   |
# | loss_q3    | 0.0412   |
# | mse        | 0.0575   |
# | mse_q0     | 0.0973   |
# | mse_q1     | 0.0416   |
# | mse_q2     | 0.0363   |
# | mse_q3     | 0.0412   |
# | param_norm | 79.4     |
# | samples    | 1.25e+06 |
# | step       | 9.8e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.832    |
# | loss       | 0.062    |
# | loss_q0    | 0.0455   |
# | loss_q1    | 0.0605   |
# | loss_q2    | 0.0505   |
# | loss_q3    | 0.0472   |
# | mse        | 0.062    |
# | mse_q0     | 0.0455   |
# | mse_q1     | 0.0605   |
# | mse_q2     | 0.0505   |
# | mse_q3     | 0.0472   |
# | param_norm | 79.4     |
# | samples    | 1.27e+06 |
# | step       | 9.9e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.855    |
# | loss       | 0.0671   |
# | loss_q0    | 0.0428   |
# | loss_q1    | 0.0435   |
# | loss_q2    | 0.0583   |
# | loss_q3    | 0.0609   |
# | mse        | 0.0671   |
# | mse_q0     | 0.0428   |
# | mse_q1     | 0.0435   |
# | mse_q2     | 0.0583   |
# | mse_q3     | 0.0609   |
# | param_norm | 79.4     |
# | samples    | 1.28e+06 |
# | step       | 1e+04    |
# -------------------------
# -------------------------
# | grad_norm  | 0.864    |
# | loss       | 0.0538   |
# | loss_q0    | 0.105    |
# | loss_q1    | 0.0526   |
# | loss_q2    | 0.0351   |
# | loss_q3    | 0.0498   |
# | mse        | 0.0538   |
# | mse_q0     | 0.105    |
# | mse_q1     | 0.0526   |
# | mse_q2     | 0.0351   |
# | mse_q3     | 0.0498   |
# | param_norm | 79.4     |
# | samples    | 1.29e+06 |
# | step       | 1.01e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.811    |
# | loss       | 0.054    |
# | loss_q0    | 0.0397   |
# | loss_q1    | 0.0469   |
# | loss_q2    | 0.0338   |
# | loss_q3    | 0.0453   |
# | mse        | 0.054    |
# | mse_q0     | 0.0397   |
# | mse_q1     | 0.0469   |
# | mse_q2     | 0.0338   |
# | mse_q3     | 0.0453   |
# | param_norm | 79.4     |
# | samples    | 1.31e+06 |
# | step       | 1.02e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.855    |
# | loss       | 0.0677   |
# | loss_q0    | 0.0465   |
# | loss_q1    | 0.0445   |
# | loss_q2    | 0.0375   |
# | loss_q3    | 0.0381   |
# | mse        | 0.0677   |
# | mse_q0     | 0.0465   |
# | mse_q1     | 0.0445   |
# | mse_q2     | 0.0375   |
# | mse_q3     | 0.0381   |
# | param_norm | 79.4     |
# | samples    | 1.32e+06 |
# | step       | 1.03e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.836    |
# | loss       | 0.0633   |
# | loss_q0    | 0.06     |
# | loss_q1    | 0.047    |
# | loss_q2    | 0.0378   |
# | loss_q3    | 0.0328   |
# | mse        | 0.0633   |
# | mse_q0     | 0.06     |
# | mse_q1     | 0.047    |
# | mse_q2     | 0.0378   |
# | mse_q3     | 0.0328   |
# | param_norm | 79.4     |
# | samples    | 1.33e+06 |
# | step       | 1.04e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.817    |
# | loss       | 0.0573   |
# | loss_q0    | 0.0665   |
# | loss_q1    | 0.0644   |
# | loss_q2    | 0.0562   |
# | loss_q3    | 0.0388   |
# | mse        | 0.0573   |
# | mse_q0     | 0.0665   |
# | mse_q1     | 0.0644   |
# | mse_q2     | 0.0562   |
# | mse_q3     | 0.0388   |
# | param_norm | 79.4     |
# | samples    | 1.34e+06 |
# | step       | 1.05e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.842    |
# | loss       | 0.0605   |
# | loss_q0    | 0.0439   |
# | loss_q1    | 0.0536   |
# | loss_q2    | 0.0431   |
# | loss_q3    | 0.0365   |
# | mse        | 0.0605   |
# | mse_q0     | 0.0439   |
# | mse_q1     | 0.0536   |
# | mse_q2     | 0.0431   |
# | mse_q3     | 0.0365   |
# | param_norm | 79.4     |
# | samples    | 1.36e+06 |
# | step       | 1.06e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.843    |
# | loss       | 0.0608   |
# | loss_q0    | 0.0437   |
# | loss_q1    | 0.0522   |
# | loss_q2    | 0.052    |
# | loss_q3    | 0.056    |
# | mse        | 0.0608   |
# | mse_q0     | 0.0437   |
# | mse_q1     | 0.0522   |
# | mse_q2     | 0.052    |
# | mse_q3     | 0.056    |
# | param_norm | 79.4     |
# | samples    | 1.37e+06 |
# | step       | 1.07e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.817    |
# | loss       | 0.0481   |
# | loss_q0    | 0.0449   |
# | loss_q1    | 0.0325   |
# | loss_q2    | 0.036    |
# | loss_q3    | 0.0961   |
# | mse        | 0.0481   |
# | mse_q0     | 0.0449   |
# | mse_q1     | 0.0325   |
# | mse_q2     | 0.036    |
# | mse_q3     | 0.0961   |
# | param_norm | 79.4     |
# | samples    | 1.38e+06 |
# | step       | 1.08e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.812    |
# | loss       | 0.0562   |
# | loss_q0    | 0.0717   |
# | loss_q1    | 0.0594   |
# | loss_q2    | 0.0322   |
# | loss_q3    | 0.037    |
# | mse        | 0.0562   |
# | mse_q0     | 0.0717   |
# | mse_q1     | 0.0594   |
# | mse_q2     | 0.0322   |
# | mse_q3     | 0.037    |
# | param_norm | 79.4     |
# | samples    | 1.4e+06  |
# | step       | 1.09e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.819    |
# | loss       | 0.0567   |
# | loss_q0    | 0.03     |
# | loss_q1    | 0.0534   |
# | loss_q2    | 0.0638   |
# | loss_q3    | 0.0444   |
# | mse        | 0.0567   |
# | mse_q0     | 0.03     |
# | mse_q1     | 0.0534   |
# | mse_q2     | 0.0638   |
# | mse_q3     | 0.0444   |
# | param_norm | 79.4     |
# | samples    | 1.41e+06 |
# | step       | 1.1e+04  |
# -------------------------
# -------------------------
# | grad_norm  | 0.838    |
# | loss       | 0.0607   |
# | loss_q0    | 0.0668   |
# | loss_q1    | 0.057    |
# | loss_q2    | 0.0414   |
# | loss_q3    | 0.0492   |
# | mse        | 0.0607   |
# | mse_q0     | 0.0668   |
# | mse_q1     | 0.057    |
# | mse_q2     | 0.0414   |
# | mse_q3     | 0.0492   |
# | param_norm | 79.4     |
# | samples    | 1.42e+06 |
# | step       | 1.11e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.826    |
# | loss       | 0.0575   |
# | loss_q0    | 0.049    |
# | loss_q1    | 0.0324   |
# | loss_q2    | 0.0456   |
# | loss_q3    | 0.0322   |
# | mse        | 0.0575   |
# | mse_q0     | 0.049    |
# | mse_q1     | 0.0324   |
# | mse_q2     | 0.0456   |
# | mse_q3     | 0.0322   |
# | param_norm | 79.4     |
# | samples    | 1.43e+06 |
# | step       | 1.12e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.82     |
# | loss       | 0.0489   |
# | loss_q0    | 0.0724   |
# | loss_q1    | 0.0423   |
# | loss_q2    | 0.0414   |
# | loss_q3    | 0.0391   |
# | mse        | 0.0489   |
# | mse_q0     | 0.0724   |
# | mse_q1     | 0.0423   |
# | mse_q2     | 0.0414   |
# | mse_q3     | 0.0391   |
# | param_norm | 79.5     |
# | samples    | 1.45e+06 |
# | step       | 1.13e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.821    |
# | loss       | 0.0552   |
# ...
# | mse_q3     | 0.028    |
# | param_norm | 79.5     |
# | samples    | 2.06e+06 |
# | step       | 1.61e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.778    |
# | loss       | 0.0519   |
# | loss_q0    | 0.066    |
# | loss_q1    | 0.0361   |
# | loss_q2    | 0.0326   |
# | loss_q3    | 0.0354   |
# | mse        | 0.0519   |
# | mse_q0     | 0.066    |
# | mse_q1     | 0.0361   |
# | mse_q2     | 0.0326   |
# | mse_q3     | 0.0354   |
# | param_norm | 79.5     |
# | samples    | 2.07e+06 |
# | step       | 1.62e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.751    |
# | loss       | 0.0516   |
# | loss_q0    | 0.0395   |
# | loss_q1    | 0.0449   |
# | loss_q2    | 0.0549   |
# | loss_q3    | 0.0404   |
# | mse        | 0.0516   |
# | mse_q0     | 0.0395   |
# | mse_q1     | 0.0449   |
# | mse_q2     | 0.0549   |
# | mse_q3     | 0.0404   |
# | param_norm | 79.5     |
# | samples    | 2.09e+06 |
# | step       | 1.63e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.807    |
# | loss       | 0.0512   |
# | loss_q0    | 0.029    |
# | loss_q1    | 0.0473   |
# | loss_q2    | 0.0531   |
# | loss_q3    | 0.0489   |
# | mse        | 0.0512   |
# | mse_q0     | 0.029    |
# | mse_q1     | 0.0473   |
# | mse_q2     | 0.0531   |
# | mse_q3     | 0.0489   |
# | param_norm | 79.5     |
# | samples    | 2.1e+06  |
# | step       | 1.64e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.776    |
# | loss       | 0.0428   |
# | loss_q0    | 0.16     |
# | loss_q1    | 0.0381   |
# | loss_q2    | 0.0364   |
# | loss_q3    | 0.0308   |
# | mse        | 0.0428   |
# | mse_q0     | 0.16     |
# | mse_q1     | 0.0381   |
# | mse_q2     | 0.0364   |
# | mse_q3     | 0.0308   |
# | param_norm | 79.5     |
# | samples    | 2.11e+06 |
# | step       | 1.65e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.762    |
# | loss       | 0.0398   |
# | loss_q0    | 0.0675   |
# | loss_q1    | 0.0258   |
# | loss_q2    | 0.0461   |
# | loss_q3    | 0.0377   |
# | mse        | 0.0398   |
# | mse_q0     | 0.0675   |
# | mse_q1     | 0.0258   |
# | mse_q2     | 0.0461   |
# | mse_q3     | 0.0377   |
# | param_norm | 79.5     |
# | samples    | 2.12e+06 |
# | step       | 1.66e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.772    |
# | loss       | 0.0391   |
# | loss_q0    | 0.0292   |
# | loss_q1    | 0.0363   |
# | loss_q2    | 0.0397   |
# | loss_q3    | 0.0296   |
# | mse        | 0.0391   |
# | mse_q0     | 0.0292   |
# | mse_q1     | 0.0363   |
# | mse_q2     | 0.0397   |
# | mse_q3     | 0.0296   |
# | param_norm | 79.5     |
# | samples    | 2.14e+06 |
# | step       | 1.67e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.756    |
# | loss       | 0.0381   |
# | loss_q0    | 0.0333   |
# | loss_q1    | 0.0255   |
# | loss_q2    | 0.0336   |
# | loss_q3    | 0.0246   |
# | mse        | 0.0381   |
# | mse_q0     | 0.0333   |
# | mse_q1     | 0.0255   |
# | mse_q2     | 0.0336   |
# | mse_q3     | 0.0246   |
# | param_norm | 79.5     |
# | samples    | 2.15e+06 |
# | step       | 1.68e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.758    |
# | loss       | 0.0538   |
# | loss_q0    | 0.0852   |
# | loss_q1    | 0.0348   |
# | loss_q2    | 0.0433   |
# | loss_q3    | 0.0259   |
# | mse        | 0.0538   |
# | mse_q0     | 0.0852   |
# | mse_q1     | 0.0348   |
# | mse_q2     | 0.0433   |
# | mse_q3     | 0.0259   |
# | param_norm | 79.5     |
# | samples    | 2.16e+06 |
# | step       | 1.69e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.768    |
# | loss       | 0.0496   |
# | loss_q0    | 0.843    |
# | loss_q1    | 0.0515   |
# | loss_q2    | 0.0359   |
# | loss_q3    | 0.0444   |
# | mse        | 0.0496   |
# | mse_q0     | 0.843    |
# | mse_q1     | 0.0515   |
# | mse_q2     | 0.0359   |
# | mse_q3     | 0.0444   |
# | param_norm | 79.5     |
# | samples    | 2.18e+06 |
# | step       | 1.7e+04  |
# -------------------------
# -------------------------
# | grad_norm  | 0.749    |
# | loss       | 0.0384   |
# | loss_q0    | 0.0398   |
# | loss_q1    | 0.0339   |
# | loss_q2    | 0.0285   |
# | loss_q3    | 0.0317   |
# | mse        | 0.0384   |
# | mse_q0     | 0.0398   |
# | mse_q1     | 0.0339   |
# | mse_q2     | 0.0285   |
# | mse_q3     | 0.0317   |
# | param_norm | 79.5     |
# | samples    | 2.19e+06 |
# | step       | 1.71e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.772    |
# | loss       | 0.0525   |
# | loss_q0    | 0.0376   |
# | loss_q1    | 0.0282   |
# | loss_q2    | 0.0452   |
# | loss_q3    | 0.0326   |
# | mse        | 0.0525   |
# | mse_q0     | 0.0376   |
# | mse_q1     | 0.0282   |
# | mse_q2     | 0.0452   |
# | mse_q3     | 0.0326   |
# | param_norm | 79.5     |
# | samples    | 2.2e+06  |
# | step       | 1.72e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.748    |
# | loss       | 0.047    |
# | loss_q0    | 0.293    |
# | loss_q1    | 0.0296   |
# | loss_q2    | 0.0361   |
# | loss_q3    | 0.0378   |
# | mse        | 0.047    |
# | mse_q0     | 0.293    |
# | mse_q1     | 0.0296   |
# | mse_q2     | 0.0361   |
# | mse_q3     | 0.0378   |
# | param_norm | 79.5     |
# | samples    | 2.21e+06 |
# | step       | 1.73e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.756    |
# | loss       | 0.0423   |
# | loss_q0    | 0.0311   |
# | loss_q1    | 0.0261   |
# | loss_q2    | 0.0277   |
# | loss_q3    | 0.0328   |
# | mse        | 0.0423   |
# | mse_q0     | 0.0311   |
# | mse_q1     | 0.0261   |
# | mse_q2     | 0.0277   |
# | mse_q3     | 0.0328   |
# | param_norm | 79.5     |
# | samples    | 2.23e+06 |
# | step       | 1.74e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.747    |
# | loss       | 0.0592   |
# | loss_q0    | 0.286    |
# | loss_q1    | 0.0294   |
# | loss_q2    | 0.0293   |
# | loss_q3    | 0.032    |
# | mse        | 0.0592   |
# | mse_q0     | 0.286    |
# | mse_q1     | 0.0294   |
# | mse_q2     | 0.0293   |
# | mse_q3     | 0.032    |
# | param_norm | 79.5     |
# | samples    | 2.24e+06 |
# | step       | 1.75e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.751    |
# | loss       | 0.0482   |
# | loss_q0    | 0.274    |
# | loss_q1    | 0.0279   |
# | loss_q2    | 0.0219   |
# | loss_q3    | 0.0186   |
# | mse        | 0.0482   |
# | mse_q0     | 0.274    |
# | mse_q1     | 0.0279   |
# | mse_q2     | 0.0219   |
# | mse_q3     | 0.0186   |
# | param_norm | 79.5     |
# | samples    | 2.25e+06 |
# | step       | 1.76e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.745    |
# | loss       | 0.0505   |
# | loss_q0    | 0.034    |
# | loss_q1    | 0.042    |
# | loss_q2    | 0.0343   |
# | loss_q3    | 0.0349   |
# | mse        | 0.0505   |
# | mse_q0     | 0.034    |
# | mse_q1     | 0.042    |
# | mse_q2     | 0.0343   |
# | mse_q3     | 0.0349   |
# | param_norm | 79.5     |
# | samples    | 2.27e+06 |
# | step       | 1.77e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.742    |
# | loss       | 0.0488   |
# | loss_q0    | 0.543    |
# | loss_q1    | 0.0386   |
# | loss_q2    | 0.0413   |
# | loss_q3    | 0.0355   |
# | mse        | 0.0488   |
# | mse_q0     | 0.543    |
# | mse_q1     | 0.0386   |
# | mse_q2     | 0.0413   |
# | mse_q3     | 0.0355   |
# | param_norm | 79.5     |
# | samples    | 2.28e+06 |
# | step       | 1.78e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.74     |
# | loss       | 0.0394   |
# | loss_q0    | 0.0301   |
# | loss_q1    | 0.0272   |
# | loss_q2    | 0.0251   |
# | loss_q3    | 0.0329   |
# | mse        | 0.0394   |
# | mse_q0     | 0.0301   |
# | mse_q1     | 0.0272   |
# | mse_q2     | 0.0251   |
# | mse_q3     | 0.0329   |
# | param_norm | 79.5     |
# | samples    | 2.29e+06 |
# | step       | 1.79e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.744    |
# | loss       | 0.0385   |
# | loss_q0    | 0.0534   |
# | loss_q1    | 0.0642   |
# | loss_q2    | 0.0277   |
# | loss_q3    | 0.0309   |
# | mse        | 0.0385   |
# | mse_q0     | 0.0534   |
# | mse_q1     | 0.0642   |
# | mse_q2     | 0.0277   |
# | mse_q3     | 0.0309   |
# | param_norm | 79.5     |
# | samples    | 2.3e+06  |
# | step       | 1.8e+04  |
# -------------------------
# -------------------------
# | grad_norm  | 0.753    |
# | loss       | 0.0417   |
# | loss_q0    | 0.0327   |
# | loss_q1    | 0.0254   |
# | loss_q2    | 0.0396   |
# | loss_q3    | 0.0518   |
# | mse        | 0.0417   |
# | mse_q0     | 0.0327   |
# | mse_q1     | 0.0254   |
# | mse_q2     | 0.0396   |
# | mse_q3     | 0.0518   |
# | param_norm | 79.5     |
# | samples    | 2.32e+06 |
# | step       | 1.81e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.767    |
# | loss       | 0.0411   |
# | loss_q0    | 0.0319   |
# | loss_q1    | 0.0545   |
# | loss_q2    | 0.033    |
# | loss_q3    | 0.0391   |
# | mse        | 0.0411   |
# | mse_q0     | 0.0319   |
# | mse_q1     | 0.0545   |
# | mse_q2     | 0.033    |
# | mse_q3     | 0.0391   |
# | param_norm | 79.5     |
# | samples    | 2.33e+06 |
# | step       | 1.82e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.732    |
# | loss       | 0.044    |
# | loss_q0    | 0.0339   |
# | loss_q1    | 0.0247   |
# | loss_q2    | 0.0302   |
# | loss_q3    | 0.0434   |
# | mse        | 0.044    |
# | mse_q0     | 0.0339   |
# | mse_q1     | 0.0247   |
# | mse_q2     | 0.0302   |
# | mse_q3     | 0.0434   |
# | param_norm | 79.5     |
# | samples    | 2.34e+06 |
# | step       | 1.83e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.769    |
# | loss       | 0.0457   |
# | loss_q0    | 0.303    |
# | loss_q1    | 0.0305   |
# | loss_q2    | 0.0353   |
# | loss_q3    | 0.0295   |
# | mse        | 0.0457   |
# | mse_q0     | 0.303    |
# | mse_q1     | 0.0305   |
# | mse_q2     | 0.0353   |
# | mse_q3     | 0.0295   |
# | param_norm | 79.5     |
# | samples    | 2.36e+06 |
# | step       | 1.84e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.755    |
# | loss       | 0.0472   |
# | loss_q0    | 0.034    |
# | loss_q1    | 0.0336   |
# | loss_q2    | 0.0373   |
# | loss_q3    | 0.0307   |
# | mse        | 0.0472   |
# | mse_q0     | 0.034    |
# | mse_q1     | 0.0336   |
# | mse_q2     | 0.0373   |
# | mse_q3     | 0.0307   |
# | param_norm | 79.5     |
# | samples    | 2.37e+06 |
# | step       | 1.85e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.726    |
# | loss       | 0.0495   |
# | loss_q0    | 0.0282   |
# | loss_q1    | 0.034    |
# | loss_q2    | 0.0465   |
# | loss_q3    | 0.0331   |
# | mse        | 0.0495   |
# | mse_q0     | 0.0282   |
# | mse_q1     | 0.034    |
# | mse_q2     | 0.0465   |
# | mse_q3     | 0.0331   |
# | param_norm | 79.5     |
# | samples    | 2.38e+06 |
# | step       | 1.86e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.732    |
# | loss       | 0.066    |
# | loss_q0    | 0.043    |
# | loss_q1    | 0.0295   |
# | loss_q2    | 0.0319   |
# | loss_q3    | 0.029    |
# | mse        | 0.066    |
# | mse_q0     | 0.043    |
# | mse_q1     | 0.0295   |
# | mse_q2     | 0.0319   |
# | mse_q3     | 0.029    |
# | param_norm | 79.5     |
# | samples    | 2.39e+06 |
# | step       | 1.87e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.714    |
# | loss       | 0.0569   |
# | loss_q0    | 0.0762   |
# | loss_q1    | 0.0344   |
# | loss_q2    | 0.0485   |
# | loss_q3    | 0.0277   |
# | mse        | 0.0569   |
# | mse_q0     | 0.0762   |
# | mse_q1     | 0.0344   |
# | mse_q2     | 0.0485   |
# | mse_q3     | 0.0277   |
# | param_norm | 79.5     |
# | samples    | 2.41e+06 |
# | step       | 1.88e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.724    |
# | loss       | 0.0571   |
# | loss_q0    | 0.0327   |
# | loss_q1    | 0.0388   |
# | loss_q2    | 0.0398   |
# | loss_q3    | 0.0371   |
# | mse        | 0.0571   |
# | mse_q0     | 0.0327   |
# | mse_q1     | 0.0388   |
# | mse_q2     | 0.0398   |
# | mse_q3     | 0.0371   |
# | param_norm | 79.5     |
# | samples    | 2.42e+06 |
# | step       | 1.89e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.746    |
# | loss       | 0.0542   |
# | loss_q0    | 0.0461   |
# | loss_q1    | 0.0495   |
# | loss_q2    | 0.022    |
# | loss_q3    | 0.0275   |
# | mse        | 0.0542   |
# | mse_q0     | 0.0461   |
# | mse_q1     | 0.0495   |
# | mse_q2     | 0.022    |
# | mse_q3     | 0.0275   |
# | param_norm | 79.5     |
# | samples    | 2.43e+06 |
# | step       | 1.9e+04  |
# -------------------------
# -------------------------
# | grad_norm  | 0.733    |
# | loss       | 0.0627   |
# | loss_q0    | 0.0227   |
# | loss_q1    | 0.0394   |
# | loss_q2    | 0.0295   |
# | loss_q3    | 0.0584   |
# | mse        | 0.0627   |
# | mse_q0     | 0.0227   |
# | mse_q1     | 0.0394   |
# | mse_q2     | 0.0295   |
# | mse_q3     | 0.0584   |
# | param_norm | 79.5     |
# | samples    | 2.44e+06 |
# | step       | 1.91e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.738    |
# | loss       | 0.0499   |
# | loss_q0    | 0.0709   |
# | loss_q1    | 0.0317   |
# | loss_q2    | 0.0313   |
# | loss_q3    | 0.0477   |
# | mse        | 0.0499   |
# | mse_q0     | 0.0709   |
# | mse_q1     | 0.0317   |
# | mse_q2     | 0.0313   |
# | mse_q3     | 0.0477   |
# | param_norm | 79.5     |
# | samples    | 2.46e+06 |
# | step       | 1.92e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.706    |
# | loss       | 0.0568   |
# | loss_q0    | 0.0447   |
# | loss_q1    | 0.0225   |
# | loss_q2    | 0.0456   |
# | loss_q3    | 0.0261   |
# | mse        | 0.0568   |
# | mse_q0     | 0.0447   |
# | mse_q1     | 0.0225   |
# | mse_q2     | 0.0456   |
# | mse_q3     | 0.0261   |
# | param_norm | 79.5     |
# | samples    | 2.47e+06 |
# | step       | 1.93e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.742    |
# | loss       | 0.0499   |
# | loss_q0    | 0.0408   |
# | loss_q1    | 0.0299   |
# | loss_q2    | 0.0207   |
# | loss_q3    | 0.0207   |
# | mse        | 0.0499   |
# | mse_q0     | 0.0408   |
# | mse_q1     | 0.0299   |
# | mse_q2     | 0.0207   |
# | mse_q3     | 0.0207   |
# | param_norm | 79.5     |
# | samples    | 2.48e+06 |
# | step       | 1.94e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.709    |
# | loss       | 0.0487   |
# | loss_q0    | 0.0485   |
# | loss_q1    | 0.0376   |
# | loss_q2    | 0.0282   |
# | loss_q3    | 0.0286   |
# | mse        | 0.0487   |
# | mse_q0     | 0.0485   |
# | mse_q1     | 0.0376   |
# | mse_q2     | 0.0282   |
# | mse_q3     | 0.0286   |
# | param_norm | 79.5     |
# | samples    | 2.5e+06  |
# | step       | 1.95e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.711    |
# | loss       | 0.0523   |
# | loss_q0    | 0.0386   |
# | loss_q1    | 0.055    |
# | loss_q2    | 0.0468   |
# | loss_q3    | 0.0549   |
# | mse        | 0.0523   |
# | mse_q0     | 0.0386   |
# | mse_q1     | 0.055    |
# | mse_q2     | 0.0468   |
# | mse_q3     | 0.0549   |
# | param_norm | 79.5     |
# | samples    | 2.51e+06 |
# | step       | 1.96e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.735    |
# | loss       | 0.0524   |
# | loss_q0    | 0.0316   |
# | loss_q1    | 0.0258   |
# | loss_q2    | 0.0423   |
# | loss_q3    | 0.0307   |
# | mse        | 0.0524   |
# | mse_q0     | 0.0316   |
# | mse_q1     | 0.0258   |
# | mse_q2     | 0.0423   |
# | mse_q3     | 0.0307   |
# | param_norm | 79.5     |
# | samples    | 2.52e+06 |
# | step       | 1.97e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.692    |
# | loss       | 0.0475   |
# | loss_q0    | 0.447    |
# | loss_q1    | 0.0771   |
# | loss_q2    | 0.0419   |
# | loss_q3    | 0.0359   |
# | mse        | 0.0475   |
# | mse_q0     | 0.447    |
# | mse_q1     | 0.0771   |
# | mse_q2     | 0.0419   |
# | mse_q3     | 0.0359   |
# | param_norm | 79.5     |
# | samples    | 2.53e+06 |
# | step       | 1.98e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.685    |
# | loss       | 0.0461   |
# | loss_q0    | 0.084    |
# | loss_q1    | 0.0335   |
# | loss_q2    | 0.0241   |
# | loss_q3    | 0.0391   |
# | mse        | 0.0461   |
# | mse_q0     | 0.084    |
# | mse_q1     | 0.0335   |
# | mse_q2     | 0.0241   |
# | mse_q3     | 0.0391   |
# | param_norm | 79.5     |
# | samples    | 2.55e+06 |
# | step       | 1.99e+04 |
# -------------------------
# saving model 0...
# saving model 0.9999...

# %%
device     = "cuda" if torch.cuda.is_available() else "cpu"
batch_size = 512
num_cells, num_genes = adata.shape

# %%
X = adata.X
if not isinstance(X, np.ndarray):
    X = X.toarray()

sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
X = adata.X
if not isinstance(X, np.ndarray):
    X = X.toarray()
# Out:
# /mnt/home/islamsa3/anaconda3/envs/global/lib/python3.10/site-packages/numba/np/ufunc/parallel.py:371: NumbaWarning: The TBB threading layer requires TBB version 2021 update 6 or later i.e., TBB_INTERFACE_VERSION >= 12060. Found TBB_INTERFACE_VERSION = 12050. The TBB threading layer is disabled.
#   warnings.warn(problem)

# %%
latent_dim = 128  

model = VAE(
    num_genes=num_genes,
    hidden_dim=latent_dim,
    device=device,
    seed=0,
    decoder_activation="ReLU",
)
state = torch.load('../models/scdiff/emt/VAE/model_seed=0_step=199999.pt', map_location=device)
model.load_state_dict(state)
model.to(device)
model.eval()
# Out:
# VAE(
#   (encoder): Encoder(
#     (network): ModuleList(
#       (0): Sequential(
#         (0): Dropout(p=0.0, inplace=False)
#         (1): Linear(in_features=2000, out_features=1024, bias=True)
#         (2): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): PReLU(num_parameters=1)
#       )
#       (1-2): 2 x Sequential(
#         (0): Dropout(p=0.0, inplace=False)
#         (1): Linear(in_features=1024, out_features=1024, bias=True)
#         (2): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): PReLU(num_parameters=1)
#       )
#       (3): Linear(in_features=1024, out_features=128, bias=True)
#     )
#   )
#   (decoder): Decoder(
#     (network): ModuleList(
#       (0): Sequential(
#         (0): Linear(in_features=128, out_features=1024, bias=True)
#         (1): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): PReLU(num_parameters=1)
#       )
#       (1-2): 2 x Sequential(
#         (0): Dropout(p=0.0, inplace=False)
#         (1): Linear(in_features=1024, out_features=1024, bias=True)
#         (2): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): PReLU(num_parameters=1)
#       )
#       (3): Linear(in_features=1024, out_features=2000, bias=True)
#     )
#   )
#   (loss_autoencoder): MSELoss()
# )

# %%
X_latent = np.zeros((num_cells, latent_dim), dtype=np.float32)

with torch.no_grad():
    for start in range(0, num_cells, batch_size):
        end = min(start + batch_size, num_cells)
        batch = torch.tensor(X[start:end], dtype=torch.float32, device=device)

        z = model.encoder(batch)    

        X_latent[start:end] = z.cpu().numpy()

# %%
# !python ../src/scDiffusion/classifier_train.py \
#   --data_dir '../data/emt_diff.h5ad' \
#   --vae_path '../models/scdiff/emt/VAE/model_seed=0_step=199999.pt' \
#   --model_path '../models/scdiff/emt/classifier/' \
#   --num_class 2 \
#   --batch_size 64 \
#   --iterations 10000 \
#   --lr 1e-3 \
#   --weight_decay 0.0 \
#   --log_interval 100 \
#   --save_interval 1000 \
#   --noised False
# Out:
# Logging to /tmp/openai-2025-12-11-00-57-28-467648
# creating model and diffusion...
# Running in single GPU mode without DDP
# creating data loader...
# creating optimizer...
# training classifier model...
# /mnt/home/islamsa3/anaconda3/envs/global/lib/python3.10/site-packages/numba/np/ufunc/parallel.py:371: NumbaWarning: The TBB threading layer requires TBB version 2021 update 6 or later i.e., TBB_INTERFACE_VERSION >= 12060. Found TBB_INTERFACE_VERSION = 12050. The TBB threading layer is disabled.
#   warnings.warn(problem)
# -----------------------------
# | grad_norm      | 2.79     |
# | param_norm     | 49.8     |
# | samples        | 64       |
# | step           | 0        |
# | train_acc@1    | 0.547    |
# | train_acc@1_q0 | 0        |
# | train_loss     | 0.696    |
# | train_loss_q0  | 0.871    |
# -----------------------------
# -----------------------------
# | grad_norm      | 1.01     |
# | param_norm     | 50       |
# | samples        | 6.46e+03 |
# | step           | 100      |
# | train_acc@1    | 0.875    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.222    |
# | train_loss_q0  | 0.0239   |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.797    |
# | param_norm     | 50.3     |
# | samples        | 1.29e+04 |
# | step           | 200      |
# | train_acc@1    | 0.906    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.159    |
# | train_loss_q0  | 1.67e-06 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.815    |
# | param_norm     | 50.7     |
# | samples        | 1.93e+04 |
# | step           | 300      |
# | train_acc@1    | 0.906    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.178    |
# | train_loss_q0  | 2.38e-07 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.798    |
# | param_norm     | 51       |
# | samples        | 2.57e+04 |
# | step           | 400      |
# | train_acc@1    | 0.969    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.119    |
# | train_loss_q0  | 2.12e-05 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.84     |
# | param_norm     | 51.5     |
# | samples        | 3.21e+04 |
# | step           | 500      |
# | train_acc@1    | 0.953    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0721   |
# | train_loss_q0  | 0.00135  |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.758    |
# | param_norm     | 51.9     |
# | samples        | 3.85e+04 |
# | step           | 600      |
# | train_acc@1    | 0.922    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.12     |
# | train_loss_q0  | 1.19e-07 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.783    |
# | param_norm     | 52.3     |
# | samples        | 4.49e+04 |
# | step           | 700      |
# | train_acc@1    | 0.969    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0625   |
# | train_loss_q0  | 2.15e-06 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.676    |
# | param_norm     | 52.7     |
# | samples        | 5.13e+04 |
# | step           | 800      |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0187   |
# | train_loss_q0  | 3.58e-07 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.687    |
# | param_norm     | 53.1     |
# | samples        | 5.77e+04 |
# | step           | 900      |
# | train_acc@1    | 0.969    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0902   |
# | train_loss_q0  | 0.00907  |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.641    |
# | param_norm     | 53.5     |
# | samples        | 6.41e+04 |
# | step           | 1e+03    |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00817  |
# | train_loss_q0  | -0       |
# -----------------------------
# saving model...
# -----------------------------
# | grad_norm      | 0.641    |
# | param_norm     | 53.9     |
# | samples        | 7.05e+04 |
# | step           | 1.1e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0035   |
# | train_loss_q0  | 0.00294  |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.524    |
# | param_norm     | 54.2     |
# | samples        | 7.69e+04 |
# | step           | 1.2e+03  |
# | train_acc@1    | 0.984    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0185   |
# | train_loss_q0  | 0.00305  |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.46     |
# | param_norm     | 54.4     |
# | samples        | 8.33e+04 |
# | step           | 1.3e+03  |
# | train_acc@1    | 0.984    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0259   |
# | train_loss_q0  | 2.11e-05 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.515    |
# | param_norm     | 54.7     |
# | samples        | 8.97e+04 |
# | step           | 1.4e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0169   |
# | train_loss_q0  | 7.15e-07 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.627    |
# | param_norm     | 55.2     |
# | samples        | 9.61e+04 |
# | step           | 1.5e+03  |
# | train_acc@1    | 0.984    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0533   |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.535    |
# | param_norm     | 58.4     |
# | samples        | 1.02e+05 |
# | step           | 1.6e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00909  |
# | train_loss_q0  | 2.38e-07 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.417    |
# | param_norm     | 59.4     |
# | samples        | 1.09e+05 |
# | step           | 1.7e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0035   |
# | train_loss_q0  | 9.6e-05  |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.505    |
# | param_norm     | 59.8     |
# | samples        | 1.15e+05 |
# | step           | 1.8e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00299  |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.441    |
# | param_norm     | 60.1     |
# | samples        | 1.22e+05 |
# | step           | 1.9e+03  |
# | train_acc@1    | 0.969    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0646   |
# | train_loss_q0  | 2.9e-05  |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.407    |
# | param_norm     | 60.4     |
# | samples        | 1.28e+05 |
# | step           | 2e+03    |
# | train_acc@1    | 0.984    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0181   |
# | train_loss_q0  | -0       |
# -----------------------------
# saving model...
# -----------------------------
# | grad_norm      | 0.353    |
# | param_norm     | 60.6     |
# | samples        | 1.34e+05 |
# | step           | 2.1e+03  |
# | train_acc@1    | 0.984    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0207   |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.363    |
# | param_norm     | 60.9     |
# | samples        | 1.41e+05 |
# | step           | 2.2e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0114   |
# | train_loss_q0  | 0.00151  |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.334    |
# | param_norm     | 61.1     |
# | samples        | 1.47e+05 |
# | step           | 2.3e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0089   |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.37     |
# | param_norm     | 61.3     |
# | samples        | 1.54e+05 |
# | step           | 2.4e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00276  |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.336    |
# | param_norm     | 61.6     |
# | samples        | 1.6e+05  |
# | step           | 2.5e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00045  |
# | train_loss_q0  | 0.0015   |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.374    |
# | param_norm     | 61.9     |
# | samples        | 1.66e+05 |
# | step           | 2.6e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00104  |
# | train_loss_q0  | 1.84e-05 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.273    |
# | param_norm     | 62.1     |
# | samples        | 1.73e+05 |
# | step           | 2.7e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.000962 |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.435    |
# | param_norm     | 62.4     |
# | samples        | 1.79e+05 |
# | step           | 2.8e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00157  |
# | train_loss_q0  | 0.000188 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.437    |
# | param_norm     | 62.8     |
# | samples        | 1.86e+05 |
# | step           | 2.9e+03  |
# | train_acc@1    | 0.984    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0212   |
# | train_loss_q0  | 0.00668  |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.251    |
# | param_norm     | 63.1     |
# | samples        | 1.92e+05 |
# | step           | 3e+03    |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.000521 |
# | train_loss_q0  | -0       |
# -----------------------------
# saving model...
# -----------------------------
# | grad_norm      | 0.185    |
# | param_norm     | 63.2     |
# | samples        | 1.98e+05 |
# | step           | 3.1e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.000359 |
# | train_loss_q0  | 2.21e-05 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.43     |
# | param_norm     | 63.4     |
# | samples        | 2.05e+05 |
# | step           | 3.2e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00538  |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.317    |
# | param_norm     | 63.8     |
# | samples        | 2.11e+05 |
# | step           | 3.3e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00423  |
# | train_loss_q0  | 0.000616 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.294    |
# | param_norm     | 64.1     |
# | samples        | 2.18e+05 |
# | step           | 3.4e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00802  |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.358    |
# | param_norm     | 64.5     |
# | samples        | 2.24e+05 |
# | step           | 3.5e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.000314 |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.22     |
# | param_norm     | 65.1     |
# | samples        | 2.3e+05  |
# | step           | 3.6e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00047  |
# | train_loss_q0  | 0.000365 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.13     |
# | param_norm     | 65.2     |
# | samples        | 2.37e+05 |
# | step           | 3.7e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00325  |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.223    |
# | param_norm     | 65.3     |
# | samples        | 2.43e+05 |
# | step           | 3.8e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.000106 |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.183    |
# | param_norm     | 65.5     |
# | samples        | 2.5e+05  |
# | step           | 3.9e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00198  |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.237    |
# | param_norm     | 65.6     |
# | samples        | 2.56e+05 |
# | step           | 4e+03    |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00904  |
# | train_loss_q0  | 3.91e-05 |
# -----------------------------
# saving model...
# -----------------------------
# | grad_norm      | 0.269    |
# | param_norm     | 65.9     |
# | samples        | 2.62e+05 |
# | step           | 4.1e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.000644 |
# | train_loss_q0  | 0.000113 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.29     |
# | param_norm     | 66.3     |
# | samples        | 2.69e+05 |
# | step           | 4.2e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.000736 |
# | train_loss_q0  | 2.38e-07 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.229    |
# | param_norm     | 66.6     |
# | samples        | 2.75e+05 |
# | step           | 4.3e+03  |
# | train_acc@1    | 0.984    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0375   |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.229    |
# | param_norm     | 66.8     |
# | samples        | 2.82e+05 |
# | step           | 4.4e+03  |
# | train_acc@1    | 0.969    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0408   |
# | train_loss_q0  | 2.62e-06 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.149    |
# | param_norm     | 67       |
# | samples        | 2.88e+05 |
# | step           | 4.5e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.000297 |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.145    |
# | param_norm     | 67.1     |
# | samples        | 2.94e+05 |
# | step           | 4.6e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00129  |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.222    |
# | param_norm     | 67.3     |
# | samples        | 3.01e+05 |
# | step           | 4.7e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00182  |
# | train_loss_q0  | 0.000604 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.285    |
# | param_norm     | 67.8     |
# | samples        | 3.07e+05 |
# | step           | 4.8e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.000542 |
# | train_loss_q0  | 2.26e-06 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.336    |
# | param_norm     | 68.6     |
# | samples        | 3.14e+05 |
# | step           | 4.9e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.000448 |
# | train_loss_q0  | 3.46e-06 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.251    |
# | param_norm     | 69.1     |
# | samples        | 3.2e+05  |
# | step           | 5e+03    |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0015   |
# | train_loss_q0  | 1.67e-06 |
# -----------------------------
# saving model...
# -----------------------------
# | grad_norm      | 0.155    |
# | param_norm     | 69.4     |
# | samples        | 3.26e+05 |
# | step           | 5.1e+03  |
# | train_acc@1    | 0.953    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.082    |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.148    |
# | param_norm     | 69.6     |
# | samples        | 3.33e+05 |
# | step           | 5.2e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 6.2e-05  |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.184    |
# | param_norm     | 69.8     |
# | samples        | 3.39e+05 |
# | step           | 5.3e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.000435 |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.186    |
# | param_norm     | 70       |
# | samples        | 3.46e+05 |
# | step           | 5.4e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0018   |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.132    |
# | param_norm     | 70.2     |
# | samples        | 3.52e+05 |
# | step           | 5.5e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00358  |
# | train_loss_q0  | 3.1e-06  |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.0945   |
# | param_norm     | 70.4     |
# | samples        | 3.58e+05 |
# | step           | 5.6e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 2.38e-05 |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.0728   |
# | param_norm     | 70.5     |
# | samples        | 3.65e+05 |
# | step           | 5.7e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.000151 |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.229    |
# | param_norm     | 70.9     |
# | samples        | 3.71e+05 |
# | step           | 5.8e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.000108 |
# | train_loss_q0  | 4.09e-05 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.226    |
# | param_norm     | 73.5     |
# | samples        | 3.78e+05 |
# | step           | 5.9e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.000371 |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.378    |
# | param_norm     | 74       |
# | samples        | 3.84e+05 |
# | step           | 6e+03    |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0145   |
# | train_loss_q0  | -0       |
# -----------------------------
# saving model...
# -----------------------------
# | grad_norm      | 0.283    |
# | param_norm     | 74.6     |
# | samples        | 3.9e+05  |
# | step           | 6.1e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.000148 |
# | train_loss_q0  | 1.19e-07 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.186    |
# | param_norm     | 75.4     |
# | samples        | 3.97e+05 |
# | step           | 6.2e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00292  |
# | train_loss_q0  | 1.19e-07 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.201    |
# | param_norm     | 77.6     |
# | samples        | 4.03e+05 |
# | step           | 6.3e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00047  |
# | train_loss_q0  | 4.54e-05 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.136    |
# | param_norm     | 78.6     |
# | samples        | 4.1e+05  |
# | step           | 6.4e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00367  |
# | train_loss_q0  | 0.0416   |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.0701   |
# | param_norm     | 78.8     |
# | samples        | 4.16e+05 |
# | step           | 6.5e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 2.94e-05 |
# | train_loss_q0  | 1.19e-07 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.113    |
# | param_norm     | 79       |
# | samples        | 4.22e+05 |
# | step           | 6.6e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00167  |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.0977   |
# | param_norm     | 79.1     |
# | samples        | 4.29e+05 |
# | step           | 6.7e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 3.44e-05 |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.233    |
# | param_norm     | 79.3     |
# | samples        | 4.35e+05 |
# | step           | 6.8e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.000981 |
# | train_loss_q0  | 0.00134  |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.144    |
# | param_norm     | 79.6     |
# | samples        | 4.42e+05 |
# | step           | 6.9e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.000527 |
# | train_loss_q0  | 5.96e-07 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.121    |
# | param_norm     | 79.8     |
# | samples        | 4.48e+05 |
# | step           | 7e+03    |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 1.41e-05 |
# | train_loss_q0  | -0       |
# -----------------------------
# saving model...
# -----------------------------
# | grad_norm      | 0.148    |
# | param_norm     | 79.9     |
# | samples        | 4.54e+05 |
# | step           | 7.1e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 1.25e-05 |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.234    |
# | param_norm     | 80.1     |
# | samples        | 4.61e+05 |
# | step           | 7.2e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0042   |
# | train_loss_q0  | 0.184    |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.222    |
# | param_norm     | 80.3     |
# | samples        | 4.67e+05 |
# | step           | 7.3e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00681  |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.344    |
# | param_norm     | 81.2     |
# | samples        | 4.74e+05 |
# | step           | 7.4e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00307  |
# | train_loss_q0  | 3.58e-07 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.315    |
# | param_norm     | 81.8     |
# | samples        | 4.8e+05  |
# | step           | 7.5e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 7.07e-05 |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.302    |
# | param_norm     | 81.6     |
# | samples        | 4.86e+05 |
# | step           | 7.6e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.000429 |
# | train_loss_q0  | 7.97e-05 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.404    |
# | param_norm     | 82.6     |
# | samples        | 4.93e+05 |
# | step           | 7.7e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00347  |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.918    |
# | param_norm     | 83.9     |
# | samples        | 4.99e+05 |
# | step           | 7.8e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.000225 |
# | train_loss_q0  | 0.0132   |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.694    |
# | param_norm     | 84.9     |
# | samples        | 5.06e+05 |
# | step           | 7.9e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00179  |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 1.79     |
# | param_norm     | 86.3     |
# | samples        | 5.12e+05 |
# | step           | 8e+03    |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 3.99e-05 |
# | train_loss_q0  | -0       |
# -----------------------------
# saving model...
# -----------------------------
# | grad_norm      | 5.58     |
# | param_norm     | 89.3     |
# | samples        | 5.18e+05 |
# | step           | 8.1e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.000541 |
# | train_loss_q0  | 3.58e-07 |
# -----------------------------
# -----------------------------
# | grad_norm      | 5.43     |
# | param_norm     | 89.7     |
# | samples        | 5.25e+05 |
# | step           | 8.2e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.000108 |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 6.25     |
# | param_norm     | 90.9     |
# | samples        | 5.31e+05 |
# | step           | 8.3e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.000112 |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 3.19     |
# | param_norm     | 91.7     |
# | samples        | 5.38e+05 |
# | step           | 8.4e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 3.86e-06 |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 2.26     |
# | param_norm     | 92.5     |
# | samples        | 5.44e+05 |
# | step           | 8.5e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 4.89e-05 |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 2.54     |
# | param_norm     | 93.1     |
# | samples        | 5.5e+05  |
# | step           | 8.6e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.000784 |
# | train_loss_q0  | 2.62e-06 |
# -----------------------------
# -----------------------------
# | grad_norm      | 10       |
# | param_norm     | 93.6     |
# | samples        | 5.57e+05 |
# | step           | 8.7e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 1.48e-05 |
# | train_loss_q0  | 4.05e-05 |
# -----------------------------
# -----------------------------
# | grad_norm      | 8.56     |
# | param_norm     | 93.4     |
# | samples        | 5.63e+05 |
# | step           | 8.8e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.000122 |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 7.1      |
# | param_norm     | 92.5     |
# | samples        | 5.7e+05  |
# | step           | 8.9e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00404  |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 15.5     |
# | param_norm     | 93.1     |
# | samples        | 5.76e+05 |
# | step           | 9e+03    |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 6.05e-05 |
# | train_loss_q0  | 0.00285  |
# -----------------------------
# saving model...
# -----------------------------
# | grad_norm      | 11.4     |
# | param_norm     | 95       |
# | samples        | 5.82e+05 |
# | step           | 9.1e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00105  |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 8.45     |
# | param_norm     | 95.5     |
# | samples        | 5.89e+05 |
# | step           | 9.2e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00115  |
# | train_loss_q0  | 3.42e-05 |
# -----------------------------
# -----------------------------
# | grad_norm      | 8.59     |
# | param_norm     | 96.6     |
# | samples        | 5.95e+05 |
# | step           | 9.3e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 9.76e-05 |
# | train_loss_q0  | 1.19e-06 |
# -----------------------------
# -----------------------------
# | grad_norm      | 11.8     |
# | param_norm     | 96.1     |
# | samples        | 6.02e+05 |
# | step           | 9.4e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00119  |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 5.14     |
# | param_norm     | 95.5     |
# | samples        | 6.08e+05 |
# | step           | 9.5e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.000605 |
# | train_loss_q0  | 1.19e-07 |
# -----------------------------
# -----------------------------
# | grad_norm      | 8.65     |
# | param_norm     | 95.8     |
# | samples        | 6.14e+05 |
# | step           | 9.6e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.000272 |
# | train_loss_q0  | 1.19e-07 |
# -----------------------------
# -----------------------------
# | grad_norm      | 7.42     |
# | param_norm     | 95.2     |
# | samples        | 6.21e+05 |
# | step           | 9.7e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 2.92e-05 |
# | train_loss_q0  | 1.67e-06 |
# -----------------------------
# -----------------------------
# | grad_norm      | 7.13     |
# | param_norm     | 95.2     |
# | samples        | 6.27e+05 |
# | step           | 9.8e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 6.09e-05 |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 7.85     |
# | param_norm     | 95.7     |
# | samples        | 6.34e+05 |
# | step           | 9.9e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.000203 |
# | train_loss_q0  | -0       |
# -----------------------------
# saving model...
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# !python ../src/scDiffusion/classifier_sample.py
# Out:
# Logging to /tmp/openai-2025-12-11-01-22-31-654349
# creating model and diffusion...
# loading classifier...
# /mnt/home/islamsa3/anaconda3/envs/global/lib/python3.10/site-packages/numba/np/ufunc/parallel.py:371: NumbaWarning: The TBB threading layer requires TBB version 2021 update 6 or later i.e., TBB_INTERFACE_VERSION >= 12060. Found TBB_INTERFACE_VERSION = 12050. The TBB threading layer is disabled.
#   warnings.warn(problem)
# sampling...
# Traceback (most recent call last):
#   File "/mnt/gs21/scratch/islamsa3/fm-project/scripts/../src/scDiffusion/classifier_sample.py", line 337, in <module>
#     main(cell_type=[0,1], inter=True, weight=[10-i,i])
#   File "/mnt/gs21/scratch/islamsa3/fm-project/scripts/../src/scDiffusion/classifier_sample.py", line 188, in main
#     start_x = autoencoder(torch.tensor(start_x,device=dist_util.dev()),return_latent=True).detach().cpu().numpy()
#   File "/mnt/home/islamsa3/anaconda3/envs/global/lib/python3.10/site-packages/scipy/sparse/_base.py", line 425, in __len__
#     raise TypeError("sparse array length is ambiguous; use getnnz()"
# TypeError: sparse array length is ambiguous; use getnnz() or shape[0]
