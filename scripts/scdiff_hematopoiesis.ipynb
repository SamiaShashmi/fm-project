# %%
import scanpy as sc
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.append(str(Path.cwd().parent))
from utils.adata import *
from utils.latent import *
from utils.plot import *
from utils.evaluation import *
import json
from sklearn.neighbors import NearestNeighbors
from umap import UMAP
import torch
import torch.nn.functional as F
import anndata
from torch import nn
from torch.utils.data import Dataset, DataLoader
from sklearn.decomposition import PCA
from src.scDiffusion import VAE, guided_diffusion
from src.scDiffusion.VAE.VAE_model import *

# %%
adata = sc.read_h5ad("../data/hematopoiesis.h5ad")

# %%
adata.obs["celltype"] = adata.obs["cell_type"].map(
    {"HSC": "HSC", "CMP": "CMP", "GMP": "GMP"}
)
adata.obs["celltype"] = adata.obs["celltype"].astype("category")

# %%
adata.obs["period"] = adata.obs["celltype"]

# %%
adata.write("../data/hem_diff.h5ad")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 3870 × 2000
#     obs: 'GSM_ID', 'biomaterial_id', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'n_genes', 'dpt_pseudotime', 'cell_type', 'celltype', 'period'
#     var: 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches'
#     uns: 'biomaterial_name_colors', 'cell_type_colors', 'diffmap_evals', 'hvg', 'iroot', 'log1p', 'neighbors', 'pca', 'umap'
#     obsm: 'X_diffmap', 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %% [markdown]
# ### Train the SCimilarity VAE

# %%
# !python ../src/scDiffusion/VAE/VAE_train.py \
--data_dir '../data/hem_diff.h5ad' \
--num_genes 2000 \
--save_dir '../models/scdiff/hem/VAE' \
--state_dict '../models/scdiff/annotation_model_v1/' \
--max_steps 200000
# Out:
# loading pretrained model from:
#  {'encoder': '../models/scdiff/annotation_model_v1/encoder.ckpt', 'decoder': '../models/scdiff/annotation_model_v1/decoder.ckpt', 'gene_order': '../models/scdiff/annotation_model_v1/gene_order.tsv'}
# WARNING: adata.X seems to be already log-transformed.
# step  0 loss  1.2739801406860352
# step  1000 loss  0.544532299041748
# step  2000 loss  0.4808112382888794
# step  3000 loss  0.3945019841194153
# step  4000 loss  0.34333375096321106
# step  5000 loss  0.3184998333454132
# step  6000 loss  0.2883681058883667
# step  7000 loss  0.2737604081630707
# step  8000 loss  0.2598544657230377
# step  9000 loss  0.2417260706424713
# step  10000 loss  0.2357143610715866
# step  11000 loss  0.2344638854265213
# step  12000 loss  0.21226294338703156
# step  13000 loss  0.2073047012090683
# step  14000 loss  0.21185679733753204
# step  15000 loss  0.1888638436794281
# step  16000 loss  0.18898899853229523
# step  17000 loss  0.19042545557022095
# step  18000 loss  0.18745706975460052
# step  19000 loss  0.17775923013687134
# step  20000 loss  0.174361914396286
# step  21000 loss  0.1756693422794342
# step  22000 loss  0.17033055424690247
# step  23000 loss  0.17538011074066162
# step  24000 loss  0.1579962819814682
# step  25000 loss  0.16356107592582703
# step  26000 loss  0.16515472531318665
# step  27000 loss  0.15924465656280518
# step  28000 loss  0.15199396014213562
# step  29000 loss  0.15786543488502502
# step  30000 loss  0.15055549144744873
# step  31000 loss  0.1580953747034073
# step  32000 loss  0.14627259969711304
# step  33000 loss  0.13818973302841187
# step  34000 loss  0.15026713907718658
# step  35000 loss  0.14884153008460999
# step  36000 loss  0.14776208996772766
# step  37000 loss  0.14837515354156494
# step  38000 loss  0.15948328375816345
# step  39000 loss  0.14024558663368225
# step  40000 loss  0.1455126404762268
# step  41000 loss  0.13974688947200775
# step  42000 loss  0.14189386367797852
# step  43000 loss  0.14068938791751862
# step  44000 loss  0.13476227223873138
# step  45000 loss  0.14303448796272278
# step  46000 loss  0.13785390555858612
# step  47000 loss  0.143093079328537
# step  48000 loss  0.13367079198360443
# step  49000 loss  0.135713130235672
# step  50000 loss  0.14420704543590546
# step  51000 loss  0.13444064557552338
# step  52000 loss  0.13319414854049683
# step  53000 loss  0.1372290551662445
# step  54000 loss  0.12611739337444305
# step  55000 loss  0.13157793879508972
# step  56000 loss  0.12447118014097214
# step  57000 loss  0.13411667943000793
# step  58000 loss  0.13177064061164856
# step  59000 loss  0.13280446827411652
# step  60000 loss  0.12251970171928406
# step  61000 loss  0.1309788078069687
# step  62000 loss  0.11875110864639282
# step  63000 loss  0.12529580295085907
# step  64000 loss  0.11744385212659836
# step  65000 loss  0.12422813475131989
# step  66000 loss  0.12121280282735825
# step  67000 loss  0.12452979385852814
# step  68000 loss  0.11908184736967087
# step  69000 loss  0.13406406342983246
# step  70000 loss  0.12067942321300507
# step  71000 loss  0.12278033047914505
# step  72000 loss  0.12289571762084961
# step  73000 loss  0.12098616361618042
# step  74000 loss  0.12143755704164505
# step  75000 loss  0.12123740464448929
# step  76000 loss  0.12144928425550461
# step  77000 loss  0.13307666778564453
# step  78000 loss  0.11883087456226349
# step  79000 loss  0.12368178367614746
# step  80000 loss  0.12322138249874115
# step  81000 loss  0.12205731123685837
# step  82000 loss  0.11666463315486908
# step  83000 loss  0.12179247289896011
# step  84000 loss  0.11355607956647873
# step  85000 loss  0.12036895006895065
# step  86000 loss  0.12134212255477905
# step  87000 loss  0.11174293607473373
# step  88000 loss  0.1250755786895752
# step  89000 loss  0.11986969411373138
# step  90000 loss  0.11130566895008087
# step  91000 loss  0.11226800829172134
# step  92000 loss  0.1338449865579605
# step  93000 loss  0.10336731374263763
# step  94000 loss  0.1078280657529831
# step  95000 loss  0.11048085242509842
# step  96000 loss  0.10706625878810883
# step  97000 loss  0.1093074381351471
# step  98000 loss  0.11272682994604111
# step  99000 loss  0.1126973107457161
# step  100000 loss  0.10530504584312439
# step  101000 loss  0.10968532413244247
# step  102000 loss  0.10586816072463989
# step  103000 loss  0.11744848638772964
# step  104000 loss  0.11716108024120331
# step  105000 loss  0.11135495454072952
# step  106000 loss  0.1062014177441597
# step  107000 loss  0.11334584653377533
# step  108000 loss  0.10035674273967743
# step  109000 loss  0.11029928177595139
# step  110000 loss  0.11230586469173431
# step  111000 loss  0.10302722454071045
# step  112000 loss  0.11256588250398636
# step  113000 loss  0.11862547695636749
# step  114000 loss  0.1106514111161232
# step  115000 loss  0.10586019605398178
# step  116000 loss  0.1062188670039177
# step  117000 loss  0.10379336774349213
# step  118000 loss  0.10155072063207626
# step  119000 loss  0.12367351353168488
# step  120000 loss  0.10534359514713287
# step  121000 loss  0.10379355400800705
# step  122000 loss  0.11003302037715912
# step  123000 loss  0.1050768494606018
# step  124000 loss  0.11069349944591522
# step  125000 loss  0.10292499512434006
# step  126000 loss  0.10710307955741882
# step  127000 loss  0.10173481702804565
# step  128000 loss  0.09954603761434555
# step  129000 loss  0.10075635462999344
# step  130000 loss  0.1051754578948021
# step  131000 loss  0.10761377215385437
# step  132000 loss  0.11705511808395386
# step  133000 loss  0.10066273808479309
# step  134000 loss  0.11027777194976807
# step  135000 loss  0.10082350671291351
# step  136000 loss  0.10330435633659363
# step  137000 loss  0.10841958224773407
# step  138000 loss  0.11354906111955643
# step  139000 loss  0.0965542122721672
# step  140000 loss  0.10106184333562851
# step  141000 loss  0.09918559342622757
# step  142000 loss  0.09936553984880447
# step  143000 loss  0.10207924246788025
# step  144000 loss  0.10608531534671783
# step  145000 loss  0.0994795709848404
# step  146000 loss  0.1048581525683403
# step  147000 loss  0.1001168042421341
# step  148000 loss  0.10139919817447662
# step  149000 loss  0.09922554343938828
# step  150000 loss  0.0965370237827301
# step  151000 loss  0.10423990339040756
# step  152000 loss  0.09783006459474564
# step  153000 loss  0.09675615280866623
# step  154000 loss  0.09978615492582321
# step  155000 loss  0.1052633747458458
# step  156000 loss  0.09862636774778366
# step  157000 loss  0.10088182985782623
# step  158000 loss  0.10287285596132278
# step  159000 loss  0.10007718205451965
# step  160000 loss  0.09461581707000732
# step  161000 loss  0.09841585904359818
# step  162000 loss  0.10216683894395828
# step  163000 loss  0.09662395715713501
# step  164000 loss  0.10358995944261551
# step  165000 loss  0.09323447197675705
# step  166000 loss  0.10138556361198425
# step  167000 loss  0.10094784945249557
# step  168000 loss  0.10384932160377502
# step  169000 loss  0.10364913940429688
# step  170000 loss  0.10126369446516037
# step  171000 loss  0.09692990779876709
# step  172000 loss  0.1032639741897583
# step  173000 loss  0.09751564264297485
# step  174000 loss  0.0980057567358017
# step  175000 loss  0.10008039325475693
# step  176000 loss  0.09430670738220215
# step  177000 loss  0.09861376136541367
# step  178000 loss  0.09205204993486404
# step  179000 loss  0.10093406587839127
# step  180000 loss  0.10833533108234406
# step  181000 loss  0.09724319726228714
# step  182000 loss  0.1059718132019043
# step  183000 loss  0.09602376073598862
# step  184000 loss  0.09378103911876678
# step  185000 loss  0.10449286550283432
# step  186000 loss  0.09900128841400146
# step  187000 loss  0.09711623191833496
# step  188000 loss  0.09898509085178375
# step  189000 loss  0.10182655602693558
# step  190000 loss  0.09329468011856079
# step  191000 loss  0.09595302492380142
# step  192000 loss  0.0882268026471138
# step  193000 loss  0.0972779393196106
# step  194000 loss  0.09983623772859573
# step  195000 loss  0.10707584023475647
# step  196000 loss  0.10311220586299896
# step  197000 loss  0.09554086625576019
# step  198000 loss  0.08734315633773804
# step  199000 loss  0.10642489045858383

# %% [markdown]
# ### Train the diffusion backbone

# %%
# !python ../src/scDiffusion/cell_train.py \
  --data_dir '../data/hem_diff.h5ad' \
  --vae_path '../models/scdiff/hem/VAE/model_seed=0_step=199999.pt' \
  --model_name 'diffusion' \
  --save_dir '../models/scdiff/hem' \
  --batch_size 128 \
  --lr 0.5e-5 \
  --lr_anneal_steps 20000
# Out:
# Logging to ../models/scdiff/emt/diffusion/logs/diffusion
# creating model and diffusion...
# creating data loader...
# training...
# WARNING: adata.X seems to be already log-transformed.
# -------------------------
# | grad_norm  | 0.867    |
# | loss       | 1.12     |
# | loss_q0    | 1.17     |
# | loss_q1    | 1.12     |
# | loss_q2    | 1.27     |
# | loss_q3    | 1.28     |
# | mse        | 1.12     |
# | mse_q0     | 1.17     |
# | mse_q1     | 1.12     |
# | mse_q2     | 1.27     |
# | mse_q3     | 1.28     |
# | param_norm | 79       |
# | samples    | 128      |
# | step       | 0        |
# -------------------------
# saving model 0...
# saving model 0.9999...
# -------------------------
# | grad_norm  | 0.638    |
# | loss       | 1.02     |
# | loss_q0    | 0.937    |
# | loss_q1    | 1.17     |
# | loss_q2    | 1.08     |
# | loss_q3    | 0.966    |
# | mse        | 1.02     |
# | mse_q0     | 0.937    |
# | mse_q1     | 1.17     |
# | mse_q2     | 1.08     |
# | mse_q3     | 0.966    |
# | param_norm | 79       |
# | samples    | 1.29e+04 |
# | step       | 100      |
# -------------------------
# -------------------------
# | grad_norm  | 0.504    |
# | loss       | 0.974    |
# | loss_q0    | 0.918    |
# | loss_q1    | 0.897    |
# | loss_q2    | 0.913    |
# | loss_q3    | 0.926    |
# | mse        | 0.974    |
# | mse_q0     | 0.918    |
# | mse_q1     | 0.897    |
# | mse_q2     | 0.913    |
# | mse_q3     | 0.926    |
# | param_norm | 79       |
# | samples    | 2.57e+04 |
# | step       | 200      |
# -------------------------
# -------------------------
# | grad_norm  | 0.472    |
# | loss       | 0.921    |
# | loss_q0    | 0.836    |
# | loss_q1    | 0.941    |
# | loss_q2    | 0.935    |
# | loss_q3    | 1        |
# | mse        | 0.921    |
# | mse_q0     | 0.836    |
# | mse_q1     | 0.941    |
# | mse_q2     | 0.935    |
# | mse_q3     | 1        |
# | param_norm | 79       |
# | samples    | 3.85e+04 |
# | step       | 300      |
# -------------------------
# -------------------------
# | grad_norm  | 0.456    |
# | loss       | 0.896    |
# | loss_q0    | 1        |
# | loss_q1    | 0.882    |
# | loss_q2    | 1.04     |
# | loss_q3    | 0.775    |
# | mse        | 0.896    |
# | mse_q0     | 1        |
# | mse_q1     | 0.882    |
# | mse_q2     | 1.04     |
# | mse_q3     | 0.775    |
# | param_norm | 79       |
# | samples    | 5.13e+04 |
# | step       | 400      |
# -------------------------
# -------------------------
# | grad_norm  | 0.454    |
# | loss       | 0.856    |
# | loss_q0    | 0.792    |
# | loss_q1    | 0.774    |
# | loss_q2    | 0.75     |
# | loss_q3    | 0.855    |
# | mse        | 0.856    |
# | mse_q0     | 0.792    |
# | mse_q1     | 0.774    |
# | mse_q2     | 0.75     |
# | mse_q3     | 0.855    |
# | param_norm | 79       |
# | samples    | 6.41e+04 |
# | step       | 500      |
# -------------------------
# -------------------------
# | grad_norm  | 0.452    |
# | loss       | 0.821    |
# | loss_q0    | 0.796    |
# | loss_q1    | 0.767    |
# | loss_q2    | 0.877    |
# | loss_q3    | 0.616    |
# | mse        | 0.821    |
# | mse_q0     | 0.796    |
# | mse_q1     | 0.767    |
# | mse_q2     | 0.877    |
# | mse_q3     | 0.616    |
# | param_norm | 79       |
# | samples    | 7.69e+04 |
# | step       | 600      |
# -------------------------
# -------------------------
# | grad_norm  | 0.452    |
# | loss       | 0.768    |
# | loss_q0    | 0.691    |
# | loss_q1    | 0.859    |
# | loss_q2    | 0.713    |
# | loss_q3    | 0.742    |
# | mse        | 0.768    |
# | mse_q0     | 0.691    |
# | mse_q1     | 0.859    |
# | mse_q2     | 0.713    |
# | mse_q3     | 0.742    |
# | param_norm | 79       |
# | samples    | 8.97e+04 |
# | step       | 700      |
# -------------------------
# -------------------------
# | grad_norm  | 0.448    |
# | loss       | 0.742    |
# | loss_q0    | 0.784    |
# | loss_q1    | 0.604    |
# | loss_q2    | 0.777    |
# | loss_q3    | 0.912    |
# | mse        | 0.742    |
# | mse_q0     | 0.784    |
# | mse_q1     | 0.604    |
# | mse_q2     | 0.777    |
# | mse_q3     | 0.912    |
# | param_norm | 79       |
# | samples    | 1.03e+05 |
# | step       | 800      |
# -------------------------
# -------------------------
# | grad_norm  | 0.444    |
# | loss       | 0.695    |
# | loss_q0    | 0.858    |
# | loss_q1    | 0.637    |
# | loss_q2    | 0.805    |
# | loss_q3    | 0.481    |
# | mse        | 0.695    |
# | mse_q0     | 0.858    |
# | mse_q1     | 0.637    |
# | mse_q2     | 0.805    |
# | mse_q3     | 0.481    |
# | param_norm | 79       |
# | samples    | 1.15e+05 |
# | step       | 900      |
# -------------------------
# -------------------------
# | grad_norm  | 0.44     |
# | loss       | 0.675    |
# | loss_q0    | 0.725    |
# | loss_q1    | 0.573    |
# | loss_q2    | 0.647    |
# | loss_q3    | 0.607    |
# | mse        | 0.675    |
# | mse_q0     | 0.725    |
# | mse_q1     | 0.573    |
# | mse_q2     | 0.647    |
# | mse_q3     | 0.607    |
# | param_norm | 79       |
# | samples    | 1.28e+05 |
# | step       | 1e+03    |
# -------------------------
# -------------------------
# | grad_norm  | 0.437    |
# | loss       | 0.637    |
# | loss_q0    | 0.652    |
# | loss_q1    | 0.569    |
# | loss_q2    | 0.735    |
# | loss_q3    | 0.613    |
# | mse        | 0.637    |
# | mse_q0     | 0.652    |
# | mse_q1     | 0.569    |
# | mse_q2     | 0.735    |
# | mse_q3     | 0.613    |
# | param_norm | 79       |
# | samples    | 1.41e+05 |
# | step       | 1.1e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.433    |
# | loss       | 0.608    |
# | loss_q0    | 0.506    |
# | loss_q1    | 0.609    |
# | loss_q2    | 0.445    |
# | loss_q3    | 0.519    |
# | mse        | 0.608    |
# | mse_q0     | 0.506    |
# | mse_q1     | 0.609    |
# | mse_q2     | 0.445    |
# | mse_q3     | 0.519    |
# | param_norm | 79       |
# | samples    | 1.54e+05 |
# | step       | 1.2e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.428    |
# | loss       | 0.593    |
# | loss_q0    | 0.914    |
# | loss_q1    | 0.723    |
# | loss_q2    | 0.485    |
# | loss_q3    | 0.64     |
# | mse        | 0.593    |
# | mse_q0     | 0.914    |
# | mse_q1     | 0.723    |
# | mse_q2     | 0.485    |
# | mse_q3     | 0.64     |
# | param_norm | 79       |
# | samples    | 1.67e+05 |
# | step       | 1.3e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.426    |
# | loss       | 0.574    |
# | loss_q0    | 0.66     |
# | loss_q1    | 0.604    |
# | loss_q2    | 0.455    |
# | loss_q3    | 0.71     |
# | mse        | 0.574    |
# | mse_q0     | 0.66     |
# | mse_q1     | 0.604    |
# | mse_q2     | 0.455    |
# | mse_q3     | 0.71     |
# | param_norm | 79       |
# | samples    | 1.79e+05 |
# | step       | 1.4e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.426    |
# | loss       | 0.542    |
# | loss_q0    | 0.468    |
# | loss_q1    | 0.559    |
# | loss_q2    | 0.62     |
# | loss_q3    | 0.543    |
# | mse        | 0.542    |
# | mse_q0     | 0.468    |
# | mse_q1     | 0.559    |
# | mse_q2     | 0.62     |
# | mse_q3     | 0.543    |
# | param_norm | 79       |
# | samples    | 1.92e+05 |
# | step       | 1.5e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.424    |
# | loss       | 0.518    |
# | loss_q0    | 0.612    |
# | loss_q1    | 0.622    |
# | loss_q2    | 0.659    |
# | loss_q3    | 0.553    |
# | mse        | 0.518    |
# | mse_q0     | 0.612    |
# | mse_q1     | 0.622    |
# | mse_q2     | 0.659    |
# | mse_q3     | 0.553    |
# | param_norm | 79       |
# | samples    | 2.05e+05 |
# | step       | 1.6e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.425    |
# | loss       | 0.494    |
# | loss_q0    | 0.576    |
# | loss_q1    | 0.412    |
# | loss_q2    | 0.351    |
# | loss_q3    | 0.357    |
# | mse        | 0.494    |
# | mse_q0     | 0.576    |
# | mse_q1     | 0.412    |
# | mse_q2     | 0.351    |
# | mse_q3     | 0.357    |
# | param_norm | 79       |
# | samples    | 2.18e+05 |
# | step       | 1.7e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.425    |
# | loss       | 0.481    |
# | loss_q0    | 0.505    |
# | loss_q1    | 0.476    |
# | loss_q2    | 0.4      |
# | loss_q3    | 0.456    |
# | mse        | 0.481    |
# | mse_q0     | 0.505    |
# | mse_q1     | 0.476    |
# | mse_q2     | 0.4      |
# | mse_q3     | 0.456    |
# | param_norm | 79       |
# | samples    | 2.31e+05 |
# | step       | 1.8e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.434    |
# | loss       | 0.451    |
# | loss_q0    | 0.434    |
# | loss_q1    | 0.354    |
# | loss_q2    | 0.467    |
# | loss_q3    | 0.521    |
# | mse        | 0.451    |
# | mse_q0     | 0.434    |
# | mse_q1     | 0.354    |
# | mse_q2     | 0.467    |
# | mse_q3     | 0.521    |
# | param_norm | 79       |
# | samples    | 2.43e+05 |
# | step       | 1.9e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.44     |
# | loss       | 0.43     |
# | loss_q0    | 0.493    |
# | loss_q1    | 0.482    |
# | loss_q2    | 0.488    |
# | loss_q3    | 0.425    |
# | mse        | 0.43     |
# | mse_q0     | 0.493    |
# | mse_q1     | 0.482    |
# | mse_q2     | 0.488    |
# | mse_q3     | 0.425    |
# | param_norm | 79       |
# | samples    | 2.56e+05 |
# | step       | 2e+03    |
# -------------------------
# -------------------------
# | grad_norm  | 0.449    |
# | loss       | 0.414    |
# | loss_q0    | 0.392    |
# | loss_q1    | 0.385    |
# | loss_q2    | 0.333    |
# | loss_q3    | 0.283    |
# | mse        | 0.414    |
# | mse_q0     | 0.392    |
# | mse_q1     | 0.385    |
# | mse_q2     | 0.333    |
# | mse_q3     | 0.283    |
# | param_norm | 79       |
# | samples    | 2.69e+05 |
# | step       | 2.1e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.453    |
# | loss       | 0.383    |
# | loss_q0    | 0.64     |
# | loss_q1    | 0.506    |
# | loss_q2    | 0.352    |
# | loss_q3    | 0.391    |
# | mse        | 0.383    |
# | mse_q0     | 0.64     |
# | mse_q1     | 0.506    |
# | mse_q2     | 0.352    |
# | mse_q3     | 0.391    |
# | param_norm | 79       |
# | samples    | 2.82e+05 |
# | step       | 2.2e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.472    |
# | loss       | 0.387    |
# | loss_q0    | 0.269    |
# | loss_q1    | 0.381    |
# | loss_q2    | 0.392    |
# | loss_q3    | 0.45     |
# | mse        | 0.387    |
# | mse_q0     | 0.269    |
# | mse_q1     | 0.381    |
# | mse_q2     | 0.392    |
# | mse_q3     | 0.45     |
# | param_norm | 79       |
# | samples    | 2.95e+05 |
# | step       | 2.3e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.483    |
# | loss       | 0.356    |
# | loss_q0    | 0.386    |
# | loss_q1    | 0.219    |
# | loss_q2    | 0.246    |
# | loss_q3    | 0.463    |
# | mse        | 0.356    |
# | mse_q0     | 0.386    |
# | mse_q1     | 0.219    |
# | mse_q2     | 0.246    |
# | mse_q3     | 0.463    |
# | param_norm | 79       |
# | samples    | 3.07e+05 |
# | step       | 2.4e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.502    |
# | loss       | 0.349    |
# | loss_q0    | 0.421    |
# | loss_q1    | 0.359    |
# | loss_q2    | 0.333    |
# | loss_q3    | 0.264    |
# | mse        | 0.349    |
# | mse_q0     | 0.421    |
# | mse_q1     | 0.359    |
# | mse_q2     | 0.333    |
# | mse_q3     | 0.264    |
# | param_norm | 79.1     |
# | samples    | 3.2e+05  |
# | step       | 2.5e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.52     |
# | loss       | 0.317    |
# | loss_q0    | 0.293    |
# | loss_q1    | 0.345    |
# | loss_q2    | 0.319    |
# | loss_q3    | 0.246    |
# | mse        | 0.317    |
# | mse_q0     | 0.293    |
# | mse_q1     | 0.345    |
# | mse_q2     | 0.319    |
# | mse_q3     | 0.246    |
# | param_norm | 79.1     |
# | samples    | 3.33e+05 |
# | step       | 2.6e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.534    |
# | loss       | 0.308    |
# | loss_q0    | 0.442    |
# | loss_q1    | 0.232    |
# | loss_q2    | 0.221    |
# | loss_q3    | 0.284    |
# | mse        | 0.308    |
# | mse_q0     | 0.442    |
# | mse_q1     | 0.232    |
# | mse_q2     | 0.221    |
# | mse_q3     | 0.284    |
# | param_norm | 79.1     |
# | samples    | 3.46e+05 |
# | step       | 2.7e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.543    |
# | loss       | 0.297    |
# | loss_q0    | 0.327    |
# | loss_q1    | 0.22     |
# | loss_q2    | 0.322    |
# | loss_q3    | 0.331    |
# | mse        | 0.297    |
# | mse_q0     | 0.327    |
# | mse_q1     | 0.22     |
# | mse_q2     | 0.322    |
# | mse_q3     | 0.331    |
# | param_norm | 79.1     |
# | samples    | 3.59e+05 |
# | step       | 2.8e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.56     |
# | loss       | 0.292    |
# | loss_q0    | 0.187    |
# | loss_q1    | 0.254    |
# | loss_q2    | 0.225    |
# | loss_q3    | 0.186    |
# | mse        | 0.292    |
# | mse_q0     | 0.187    |
# | mse_q1     | 0.254    |
# | mse_q2     | 0.225    |
# | mse_q3     | 0.186    |
# | param_norm | 79.1     |
# | samples    | 3.71e+05 |
# | step       | 2.9e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.572    |
# | loss       | 0.272    |
# | loss_q0    | 0.572    |
# | loss_q1    | 0.163    |
# | loss_q2    | 0.312    |
# | loss_q3    | 0.225    |
# | mse        | 0.272    |
# | mse_q0     | 0.572    |
# | mse_q1     | 0.163    |
# | mse_q2     | 0.312    |
# | mse_q3     | 0.225    |
# | param_norm | 79.1     |
# | samples    | 3.84e+05 |
# | step       | 3e+03    |
# -------------------------
# -------------------------
# | grad_norm  | 0.594    |
# | loss       | 0.258    |
# | loss_q0    | 0.292    |
# | loss_q1    | 0.228    |
# | loss_q2    | 0.278    |
# | loss_q3    | 0.209    |
# | mse        | 0.258    |
# | mse_q0     | 0.292    |
# | mse_q1     | 0.228    |
# | mse_q2     | 0.278    |
# | mse_q3     | 0.209    |
# | param_norm | 79.1     |
# | samples    | 3.97e+05 |
# | step       | 3.1e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.597    |
# | loss       | 0.256    |
# | loss_q0    | 0.339    |
# | loss_q1    | 0.305    |
# | loss_q2    | 0.209    |
# | loss_q3    | 0.33     |
# | mse        | 0.256    |
# | mse_q0     | 0.339    |
# | mse_q1     | 0.305    |
# | mse_q2     | 0.209    |
# | mse_q3     | 0.33     |
# | param_norm | 79.1     |
# | samples    | 4.1e+05  |
# | step       | 3.2e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.613    |
# | loss       | 0.262    |
# | loss_q0    | 0.393    |
# | loss_q1    | 0.345    |
# | loss_q2    | 0.231    |
# | loss_q3    | 0.189    |
# | mse        | 0.262    |
# | mse_q0     | 0.393    |
# | mse_q1     | 0.345    |
# | mse_q2     | 0.231    |
# | mse_q3     | 0.189    |
# | param_norm | 79.1     |
# | samples    | 4.23e+05 |
# | step       | 3.3e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.64     |
# | loss       | 0.23     |
# | loss_q0    | 0.243    |
# | loss_q1    | 0.182    |
# | loss_q2    | 0.195    |
# | loss_q3    | 0.17     |
# | mse        | 0.23     |
# | mse_q0     | 0.243    |
# | mse_q1     | 0.182    |
# | mse_q2     | 0.195    |
# | mse_q3     | 0.17     |
# | param_norm | 79.1     |
# | samples    | 4.35e+05 |
# | step       | 3.4e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.633    |
# | loss       | 0.229    |
# | loss_q0    | 0.284    |
# | loss_q1    | 0.216    |
# | loss_q2    | 0.128    |
# | loss_q3    | 0.161    |
# | mse        | 0.229    |
# | mse_q0     | 0.284    |
# | mse_q1     | 0.216    |
# | mse_q2     | 0.128    |
# | mse_q3     | 0.161    |
# | param_norm | 79.1     |
# | samples    | 4.48e+05 |
# | step       | 3.5e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.639    |
# | loss       | 0.217    |
# | loss_q0    | 0.171    |
# | loss_q1    | 0.181    |
# | loss_q2    | 0.171    |
# | loss_q3    | 0.112    |
# | mse        | 0.217    |
# | mse_q0     | 0.171    |
# | mse_q1     | 0.181    |
# | mse_q2     | 0.171    |
# | mse_q3     | 0.112    |
# | param_norm | 79.1     |
# | samples    | 4.61e+05 |
# | step       | 3.6e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.649    |
# | loss       | 0.192    |
# | loss_q0    | 0.218    |
# | loss_q1    | 0.201    |
# | loss_q2    | 0.154    |
# | loss_q3    | 0.154    |
# | mse        | 0.192    |
# | mse_q0     | 0.218    |
# | mse_q1     | 0.201    |
# | mse_q2     | 0.154    |
# | mse_q3     | 0.154    |
# | param_norm | 79.1     |
# | samples    | 4.74e+05 |
# | step       | 3.7e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.664    |
# | loss       | 0.19     |
# | loss_q0    | 0.107    |
# | loss_q1    | 0.184    |
# | loss_q2    | 0.232    |
# | loss_q3    | 0.26     |
# | mse        | 0.19     |
# | mse_q0     | 0.107    |
# | mse_q1     | 0.184    |
# | mse_q2     | 0.232    |
# | mse_q3     | 0.26     |
# | param_norm | 79.2     |
# | samples    | 4.87e+05 |
# | step       | 3.8e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.661    |
# | loss       | 0.187    |
# | loss_q0    | 0.139    |
# | loss_q1    | 0.152    |
# | loss_q2    | 0.3      |
# | loss_q3    | 0.213    |
# | mse        | 0.187    |
# | mse_q0     | 0.139    |
# | mse_q1     | 0.152    |
# | mse_q2     | 0.3      |
# | mse_q3     | 0.213    |
# | param_norm | 79.2     |
# | samples    | 4.99e+05 |
# | step       | 3.9e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.677    |
# | loss       | 0.181    |
# | loss_q0    | 0.111    |
# | loss_q1    | 0.143    |
# | loss_q2    | 0.226    |
# | loss_q3    | 0.169    |
# | mse        | 0.181    |
# | mse_q0     | 0.111    |
# | mse_q1     | 0.143    |
# | mse_q2     | 0.226    |
# | mse_q3     | 0.169    |
# | param_norm | 79.2     |
# | samples    | 5.12e+05 |
# | step       | 4e+03    |
# -------------------------
# -------------------------
# | grad_norm  | 0.675    |
# | loss       | 0.173    |
# | loss_q0    | 0.125    |
# | loss_q1    | 0.145    |
# | loss_q2    | 0.116    |
# | loss_q3    | 0.15     |
# | mse        | 0.173    |
# | mse_q0     | 0.125    |
# | mse_q1     | 0.145    |
# | mse_q2     | 0.116    |
# | mse_q3     | 0.15     |
# | param_norm | 79.2     |
# | samples    | 5.25e+05 |
# | step       | 4.1e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.7      |
# | loss       | 0.161    |
# | loss_q0    | 0.298    |
# | loss_q1    | 0.137    |
# | loss_q2    | 0.0874   |
# | loss_q3    | 0.134    |
# | mse        | 0.161    |
# | mse_q0     | 0.298    |
# | mse_q1     | 0.137    |
# | mse_q2     | 0.0874   |
# | mse_q3     | 0.134    |
# | param_norm | 79.2     |
# | samples    | 5.38e+05 |
# | step       | 4.2e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.698    |
# | loss       | 0.152    |
# | loss_q0    | 0.162    |
# | loss_q1    | 0.177    |
# | loss_q2    | 0.128    |
# | loss_q3    | 0.183    |
# | mse        | 0.152    |
# | mse_q0     | 0.162    |
# | mse_q1     | 0.177    |
# | mse_q2     | 0.128    |
# | mse_q3     | 0.183    |
# | param_norm | 79.2     |
# | samples    | 5.51e+05 |
# | step       | 4.3e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.707    |
# | loss       | 0.148    |
# | loss_q0    | 0.176    |
# | loss_q1    | 0.13     |
# | loss_q2    | 0.119    |
# | loss_q3    | 0.125    |
# | mse        | 0.148    |
# | mse_q0     | 0.176    |
# | mse_q1     | 0.13     |
# | mse_q2     | 0.119    |
# | mse_q3     | 0.125    |
# | param_norm | 79.2     |
# | samples    | 5.63e+05 |
# | step       | 4.4e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.722    |
# | loss       | 0.152    |
# | loss_q0    | 0.169    |
# | loss_q1    | 0.0976   |
# | loss_q2    | 0.115    |
# | loss_q3    | 0.133    |
# | mse        | 0.152    |
# | mse_q0     | 0.169    |
# | mse_q1     | 0.0976   |
# | mse_q2     | 0.115    |
# | mse_q3     | 0.133    |
# | param_norm | 79.2     |
# | samples    | 5.76e+05 |
# | step       | 4.5e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.726    |
# | loss       | 0.132    |
# | loss_q0    | 0.108    |
# | loss_q1    | 0.12     |
# | loss_q2    | 0.184    |
# | loss_q3    | 0.173    |
# | mse        | 0.132    |
# | mse_q0     | 0.108    |
# | mse_q1     | 0.12     |
# | mse_q2     | 0.184    |
# | mse_q3     | 0.173    |
# | param_norm | 79.2     |
# | samples    | 5.89e+05 |
# | step       | 4.6e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.727    |
# | loss       | 0.136    |
# | loss_q0    | 0.104    |
# | loss_q1    | 0.12     |
# | loss_q2    | 0.0916   |
# | loss_q3    | 0.103    |
# | mse        | 0.136    |
# | mse_q0     | 0.104    |
# | mse_q1     | 0.12     |
# | mse_q2     | 0.0916   |
# | mse_q3     | 0.103    |
# | param_norm | 79.2     |
# | samples    | 6.02e+05 |
# | step       | 4.7e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.739    |
# | loss       | 0.124    |
# | loss_q0    | 0.107    |
# | loss_q1    | 0.206    |
# | loss_q2    | 0.171    |
# | loss_q3    | 0.106    |
# | mse        | 0.124    |
# | mse_q0     | 0.107    |
# | mse_q1     | 0.206    |
# | mse_q2     | 0.171    |
# | mse_q3     | 0.106    |
# | param_norm | 79.2     |
# | samples    | 6.15e+05 |
# | step       | 4.8e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.73     |
# | loss       | 0.124    |
# | loss_q0    | 0.075    |
# | loss_q1    | 0.135    |
# | loss_q2    | 0.0977   |
# | loss_q3    | 0.0597   |
# | mse        | 0.124    |
# | mse_q0     | 0.075    |
# | mse_q1     | 0.135    |
# | mse_q2     | 0.0977   |
# | mse_q3     | 0.0597   |
# | param_norm | 79.2     |
# | samples    | 6.27e+05 |
# | step       | 4.9e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.713    |
# | loss       | 0.129    |
# | loss_q0    | 0.087    |
# | loss_q1    | 0.135    |
# | loss_q2    | 0.105    |
# | loss_q3    | 0.11     |
# | mse        | 0.129    |
# | mse_q0     | 0.087    |
# | mse_q1     | 0.135    |
# | mse_q2     | 0.105    |
# | mse_q3     | 0.11     |
# | param_norm | 79.2     |
# | samples    | 6.4e+05  |
# | step       | 5e+03    |
# -------------------------
# -------------------------
# | grad_norm  | 0.737    |
# | loss       | 0.137    |
# | loss_q0    | 0.231    |
# | loss_q1    | 0.13     |
# | loss_q2    | 0.12     |
# | loss_q3    | 0.0643   |
# | mse        | 0.137    |
# | mse_q0     | 0.231    |
# | mse_q1     | 0.13     |
# | mse_q2     | 0.12     |
# | mse_q3     | 0.0643   |
# | param_norm | 79.2     |
# | samples    | 6.53e+05 |
# | step       | 5.1e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.744    |
# | loss       | 0.123    |
# | loss_q0    | 0.0713   |
# | loss_q1    | 0.0912   |
# | loss_q2    | 0.112    |
# | loss_q3    | 0.0956   |
# | mse        | 0.123    |
# | mse_q0     | 0.0713   |
# | mse_q1     | 0.0912   |
# | mse_q2     | 0.112    |
# | mse_q3     | 0.0956   |
# | param_norm | 79.2     |
# | samples    | 6.66e+05 |
# | step       | 5.2e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.765    |
# | loss       | 0.114    |
# | loss_q0    | 0.11     |
# | loss_q1    | 0.0567   |
# | loss_q2    | 0.0899   |
# | loss_q3    | 0.162    |
# | mse        | 0.114    |
# | mse_q0     | 0.11     |
# | mse_q1     | 0.0567   |
# | mse_q2     | 0.0899   |
# | mse_q3     | 0.162    |
# | param_norm | 79.3     |
# | samples    | 6.79e+05 |
# | step       | 5.3e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.774    |
# | loss       | 0.104    |
# | loss_q0    | 0.113    |
# | loss_q1    | 0.125    |
# | loss_q2    | 0.0934   |
# | loss_q3    | 0.102    |
# | mse        | 0.104    |
# | mse_q0     | 0.113    |
# | mse_q1     | 0.125    |
# | mse_q2     | 0.0934   |
# | mse_q3     | 0.102    |
# | param_norm | 79.3     |
# | samples    | 6.91e+05 |
# | step       | 5.4e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.761    |
# | loss       | 0.11     |
# | loss_q0    | 0.0876   |
# | loss_q1    | 0.197    |
# | loss_q2    | 0.0678   |
# | loss_q3    | 0.0874   |
# | mse        | 0.11     |
# | mse_q0     | 0.0876   |
# | mse_q1     | 0.197    |
# | mse_q2     | 0.0678   |
# | mse_q3     | 0.0874   |
# | param_norm | 79.3     |
# | samples    | 7.04e+05 |
# | step       | 5.5e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.77     |
# | loss       | 0.103    |
# | loss_q0    | 0.158    |
# | loss_q1    | 0.0742   |
# | loss_q2    | 0.0876   |
# | loss_q3    | 0.0988   |
# | mse        | 0.103    |
# | mse_q0     | 0.158    |
# | mse_q1     | 0.0742   |
# | mse_q2     | 0.0876   |
# | mse_q3     | 0.0988   |
# | param_norm | 79.3     |
# | samples    | 7.17e+05 |
# | step       | 5.6e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.801    |
# | loss       | 0.106    |
# | loss_q0    | 0.218    |
# | loss_q1    | 0.11     |
# | loss_q2    | 0.0676   |
# | loss_q3    | 0.0832   |
# | mse        | 0.106    |
# | mse_q0     | 0.218    |
# | mse_q1     | 0.11     |
# | mse_q2     | 0.0676   |
# | mse_q3     | 0.0832   |
# | param_norm | 79.3     |
# | samples    | 7.3e+05  |
# | step       | 5.7e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.778    |
# | loss       | 0.0984   |
# | loss_q0    | 0.0743   |
# | loss_q1    | 0.0675   |
# | loss_q2    | 0.0565   |
# | loss_q3    | 0.0682   |
# | mse        | 0.0984   |
# | mse_q0     | 0.0743   |
# | mse_q1     | 0.0675   |
# | mse_q2     | 0.0565   |
# | mse_q3     | 0.0682   |
# | param_norm | 79.3     |
# | samples    | 7.43e+05 |
# | step       | 5.8e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.779    |
# | loss       | 0.104    |
# | loss_q0    | 0.131    |
# | loss_q1    | 0.0934   |
# | loss_q2    | 0.137    |
# | loss_q3    | 0.0955   |
# | mse        | 0.104    |
# | mse_q0     | 0.131    |
# | mse_q1     | 0.0934   |
# | mse_q2     | 0.137    |
# | mse_q3     | 0.0955   |
# | param_norm | 79.3     |
# | samples    | 7.55e+05 |
# | step       | 5.9e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.8      |
# | loss       | 0.102    |
# | loss_q0    | 0.0547   |
# | loss_q1    | 0.0853   |
# | loss_q2    | 0.0955   |
# | loss_q3    | 0.0639   |
# | mse        | 0.102    |
# | mse_q0     | 0.0547   |
# | mse_q1     | 0.0853   |
# | mse_q2     | 0.0955   |
# | mse_q3     | 0.0639   |
# | param_norm | 79.3     |
# | samples    | 7.68e+05 |
# | step       | 6e+03    |
# -------------------------
# -------------------------
# | grad_norm  | 0.794    |
# | loss       | 0.0875   |
# | loss_q0    | 0.0674   |
# | loss_q1    | 0.064    |
# | loss_q2    | 0.0465   |
# | loss_q3    | 0.102    |
# | mse        | 0.0875   |
# | mse_q0     | 0.0674   |
# | mse_q1     | 0.064    |
# | mse_q2     | 0.0465   |
# | mse_q3     | 0.102    |
# | param_norm | 79.3     |
# | samples    | 7.81e+05 |
# | step       | 6.1e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.843    |
# | loss       | 0.0978   |
# | loss_q0    | 0.0796   |
# | loss_q1    | 0.132    |
# | loss_q2    | 0.0635   |
# | loss_q3    | 0.0568   |
# | mse        | 0.0978   |
# | mse_q0     | 0.0796   |
# | mse_q1     | 0.132    |
# | mse_q2     | 0.0635   |
# | mse_q3     | 0.0568   |
# | param_norm | 79.3     |
# | samples    | 7.94e+05 |
# | step       | 6.2e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.814    |
# | loss       | 0.101    |
# | loss_q0    | 0.0675   |
# | loss_q1    | 0.0828   |
# | loss_q2    | 0.0641   |
# | loss_q3    | 0.109    |
# | mse        | 0.101    |
# | mse_q0     | 0.0675   |
# | mse_q1     | 0.0828   |
# | mse_q2     | 0.0641   |
# | mse_q3     | 0.109    |
# | param_norm | 79.3     |
# | samples    | 8.07e+05 |
# | step       | 6.3e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.784    |
# | loss       | 0.0735   |
# | loss_q0    | 0.0481   |
# | loss_q1    | 0.118    |
# | loss_q2    | 0.0703   |
# | loss_q3    | 0.0929   |
# | mse        | 0.0735   |
# | mse_q0     | 0.0481   |
# | mse_q1     | 0.118    |
# | mse_q2     | 0.0703   |
# | mse_q3     | 0.0929   |
# | param_norm | 79.3     |
# | samples    | 8.19e+05 |
# | step       | 6.4e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.825    |
# | loss       | 0.0882   |
# | loss_q0    | 0.0403   |
# | loss_q1    | 0.0884   |
# | loss_q2    | 0.0624   |
# | loss_q3    | 0.0915   |
# | mse        | 0.0882   |
# | mse_q0     | 0.0403   |
# | mse_q1     | 0.0884   |
# | mse_q2     | 0.0624   |
# | mse_q3     | 0.0915   |
# | param_norm | 79.3     |
# | samples    | 8.32e+05 |
# | step       | 6.5e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.81     |
# | loss       | 0.0898   |
# | loss_q0    | 0.056    |
# | loss_q1    | 0.0991   |
# | loss_q2    | 0.0592   |
# | loss_q3    | 0.0617   |
# | mse        | 0.0898   |
# | mse_q0     | 0.056    |
# | mse_q1     | 0.0991   |
# | mse_q2     | 0.0592   |
# | mse_q3     | 0.0617   |
# | param_norm | 79.3     |
# | samples    | 8.45e+05 |
# | step       | 6.6e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.826    |
# | loss       | 0.0882   |
# | loss_q0    | 0.0824   |
# | loss_q1    | 0.0746   |
# | loss_q2    | 0.0623   |
# | loss_q3    | 0.0536   |
# | mse        | 0.0882   |
# | mse_q0     | 0.0824   |
# | mse_q1     | 0.0746   |
# | mse_q2     | 0.0623   |
# | mse_q3     | 0.0536   |
# | param_norm | 79.3     |
# | samples    | 8.58e+05 |
# | step       | 6.7e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.827    |
# | loss       | 0.0947   |
# | loss_q0    | 1.14     |
# | loss_q1    | 0.0924   |
# | loss_q2    | 0.0638   |
# | loss_q3    | 0.0421   |
# | mse        | 0.0947   |
# | mse_q0     | 1.14     |
# | mse_q1     | 0.0924   |
# | mse_q2     | 0.0638   |
# | mse_q3     | 0.0421   |
# | param_norm | 79.3     |
# | samples    | 8.71e+05 |
# | step       | 6.8e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.788    |
# | loss       | 0.0724   |
# | loss_q0    | 0.0496   |
# | loss_q1    | 0.0552   |
# | loss_q2    | 0.053    |
# | loss_q3    | 0.0773   |
# | mse        | 0.0724   |
# | mse_q0     | 0.0496   |
# | mse_q1     | 0.0552   |
# | mse_q2     | 0.053    |
# | mse_q3     | 0.0773   |
# | param_norm | 79.3     |
# | samples    | 8.83e+05 |
# | step       | 6.9e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.84     |
# | loss       | 0.0815   |
# | loss_q0    | 0.472    |
# | loss_q1    | 0.0411   |
# | loss_q2    | 0.155    |
# | loss_q3    | 0.0831   |
# | mse        | 0.0815   |
# | mse_q0     | 0.472    |
# | mse_q1     | 0.0411   |
# | mse_q2     | 0.155    |
# | mse_q3     | 0.0831   |
# | param_norm | 79.3     |
# | samples    | 8.96e+05 |
# | step       | 7e+03    |
# -------------------------
# -------------------------
# | grad_norm  | 0.825    |
# | loss       | 0.0756   |
# | loss_q0    | 0.309    |
# | loss_q1    | 0.0444   |
# | loss_q2    | 0.0583   |
# | loss_q3    | 0.0443   |
# | mse        | 0.0756   |
# | mse_q0     | 0.309    |
# | mse_q1     | 0.0444   |
# | mse_q2     | 0.0583   |
# | mse_q3     | 0.0443   |
# | param_norm | 79.3     |
# | samples    | 9.09e+05 |
# | step       | 7.1e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.829    |
# | loss       | 0.0846   |
# | loss_q0    | 0.771    |
# | loss_q1    | 0.0485   |
# | loss_q2    | 0.0537   |
# | loss_q3    | 0.0723   |
# | mse        | 0.0846   |
# | mse_q0     | 0.771    |
# | mse_q1     | 0.0485   |
# | mse_q2     | 0.0537   |
# | mse_q3     | 0.0723   |
# | param_norm | 79.3     |
# | samples    | 9.22e+05 |
# | step       | 7.2e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.85     |
# | loss       | 0.0925   |
# | loss_q0    | 0.166    |
# | loss_q1    | 0.0427   |
# | loss_q2    | 0.0671   |
# | loss_q3    | 0.0552   |
# | mse        | 0.0925   |
# | mse_q0     | 0.166    |
# | mse_q1     | 0.0427   |
# | mse_q2     | 0.0671   |
# | mse_q3     | 0.0552   |
# | param_norm | 79.4     |
# | samples    | 9.35e+05 |
# | step       | 7.3e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.84     |
# | loss       | 0.0736   |
# | loss_q0    | 0.0668   |
# | loss_q1    | 0.0804   |
# | loss_q2    | 0.0389   |
# | loss_q3    | 0.0579   |
# | mse        | 0.0736   |
# | mse_q0     | 0.0668   |
# | mse_q1     | 0.0804   |
# | mse_q2     | 0.0389   |
# | mse_q3     | 0.0579   |
# | param_norm | 79.4     |
# | samples    | 9.47e+05 |
# | step       | 7.4e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.875    |
# | loss       | 0.0768   |
# | loss_q0    | 0.0515   |
# | loss_q1    | 0.0822   |
# | loss_q2    | 0.0633   |
# | loss_q3    | 0.0761   |
# | mse        | 0.0768   |
# | mse_q0     | 0.0515   |
# | mse_q1     | 0.0822   |
# | mse_q2     | 0.0633   |
# | mse_q3     | 0.0761   |
# | param_norm | 79.4     |
# | samples    | 9.6e+05  |
# | step       | 7.5e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.813    |
# | loss       | 0.0736   |
# | loss_q0    | 0.0794   |
# | loss_q1    | 0.0631   |
# | loss_q2    | 0.0453   |
# | loss_q3    | 0.0455   |
# | mse        | 0.0736   |
# | mse_q0     | 0.0794   |
# | mse_q1     | 0.0631   |
# | mse_q2     | 0.0453   |
# | mse_q3     | 0.0455   |
# | param_norm | 79.4     |
# | samples    | 9.73e+05 |
# | step       | 7.6e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.861    |
# | loss       | 0.0758   |
# | loss_q0    | 0.0702   |
# | loss_q1    | 0.045    |
# | loss_q2    | 0.0615   |
# | loss_q3    | 0.0582   |
# | mse        | 0.0758   |
# | mse_q0     | 0.0702   |
# | mse_q1     | 0.045    |
# | mse_q2     | 0.0615   |
# | mse_q3     | 0.0582   |
# | param_norm | 79.4     |
# | samples    | 9.86e+05 |
# | step       | 7.7e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.84     |
# | loss       | 0.0728   |
# | loss_q0    | 0.318    |
# | loss_q1    | 0.0364   |
# | loss_q2    | 0.0735   |
# | loss_q3    | 0.0298   |
# | mse        | 0.0728   |
# | mse_q0     | 0.318    |
# | mse_q1     | 0.0364   |
# | mse_q2     | 0.0735   |
# | mse_q3     | 0.0298   |
# | param_norm | 79.4     |
# | samples    | 9.99e+05 |
# | step       | 7.8e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.835    |
# | loss       | 0.0703   |
# | loss_q0    | 0.112    |
# | loss_q1    | 0.0444   |
# | loss_q2    | 0.0835   |
# | loss_q3    | 0.0497   |
# | mse        | 0.0703   |
# | mse_q0     | 0.112    |
# | mse_q1     | 0.0444   |
# | mse_q2     | 0.0835   |
# | mse_q3     | 0.0497   |
# | param_norm | 79.4     |
# | samples    | 1.01e+06 |
# | step       | 7.9e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.857    |
# | loss       | 0.0705   |
# | loss_q0    | 0.748    |
# | loss_q1    | 0.0558   |
# | loss_q2    | 0.0435   |
# | loss_q3    | 0.0573   |
# | mse        | 0.0705   |
# | mse_q0     | 0.748    |
# | mse_q1     | 0.0558   |
# | mse_q2     | 0.0435   |
# | mse_q3     | 0.0573   |
# | param_norm | 79.4     |
# | samples    | 1.02e+06 |
# | step       | 8e+03    |
# -------------------------
# -------------------------
# | grad_norm  | 0.847    |
# | loss       | 0.0959   |
# | loss_q0    | 0.628    |
# | loss_q1    | 0.0799   |
# | loss_q2    | 0.0461   |
# | loss_q3    | 0.047    |
# | mse        | 0.0959   |
# | mse_q0     | 0.628    |
# | mse_q1     | 0.0799   |
# | mse_q2     | 0.0461   |
# | mse_q3     | 0.047    |
# | param_norm | 79.4     |
# | samples    | 1.04e+06 |
# | step       | 8.1e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.858    |
# | loss       | 0.0682   |
# | loss_q0    | 0.0632   |
# | loss_q1    | 0.0532   |
# | loss_q2    | 0.0446   |
# | loss_q3    | 0.0549   |
# | mse        | 0.0682   |
# | mse_q0     | 0.0632   |
# | mse_q1     | 0.0532   |
# | mse_q2     | 0.0446   |
# | mse_q3     | 0.0549   |
# | param_norm | 79.4     |
# | samples    | 1.05e+06 |
# | step       | 8.2e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.856    |
# | loss       | 0.0753   |
# | loss_q0    | 0.0844   |
# | loss_q1    | 0.0445   |
# | loss_q2    | 0.0453   |
# | loss_q3    | 0.0445   |
# | mse        | 0.0753   |
# | mse_q0     | 0.0844   |
# | mse_q1     | 0.0445   |
# | mse_q2     | 0.0453   |
# | mse_q3     | 0.0445   |
# | param_norm | 79.4     |
# | samples    | 1.06e+06 |
# | step       | 8.3e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.858    |
# | loss       | 0.0759   |
# | loss_q0    | 0.203    |
# | loss_q1    | 0.0441   |
# | loss_q2    | 0.0461   |
# | loss_q3    | 0.0594   |
# | mse        | 0.0759   |
# | mse_q0     | 0.203    |
# | mse_q1     | 0.0441   |
# | mse_q2     | 0.0461   |
# | mse_q3     | 0.0594   |
# | param_norm | 79.4     |
# | samples    | 1.08e+06 |
# | step       | 8.4e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.868    |
# | loss       | 0.0668   |
# | loss_q0    | 0.0488   |
# | loss_q1    | 0.0493   |
# | loss_q2    | 0.0962   |
# | loss_q3    | 0.0633   |
# | mse        | 0.0668   |
# | mse_q0     | 0.0488   |
# | mse_q1     | 0.0493   |
# | mse_q2     | 0.0962   |
# | mse_q3     | 0.0633   |
# | param_norm | 79.4     |
# | samples    | 1.09e+06 |
# | step       | 8.5e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.835    |
# | loss       | 0.0681   |
# | loss_q0    | 0.0907   |
# | loss_q1    | 0.0464   |
# | loss_q2    | 0.0543   |
# | loss_q3    | 0.0487   |
# | mse        | 0.0681   |
# | mse_q0     | 0.0907   |
# | mse_q1     | 0.0464   |
# | mse_q2     | 0.0543   |
# | mse_q3     | 0.0487   |
# | param_norm | 79.4     |
# | samples    | 1.1e+06  |
# | step       | 8.6e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.854    |
# | loss       | 0.0622   |
# | loss_q0    | 0.0571   |
# | loss_q1    | 0.0389   |
# | loss_q2    | 0.0586   |
# | loss_q3    | 0.0394   |
# | mse        | 0.0622   |
# | mse_q0     | 0.0571   |
# | mse_q1     | 0.0389   |
# | mse_q2     | 0.0586   |
# | mse_q3     | 0.0394   |
# | param_norm | 79.4     |
# | samples    | 1.11e+06 |
# | step       | 8.7e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.84     |
# | loss       | 0.0664   |
# | loss_q0    | 0.0823   |
# | loss_q1    | 0.114    |
# | loss_q2    | 0.04     |
# | loss_q3    | 0.0427   |
# | mse        | 0.0664   |
# | mse_q0     | 0.0823   |
# | mse_q1     | 0.114    |
# | mse_q2     | 0.04     |
# | mse_q3     | 0.0427   |
# | param_norm | 79.4     |
# | samples    | 1.13e+06 |
# | step       | 8.8e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.846    |
# | loss       | 0.0728   |
# | loss_q0    | 0.0516   |
# | loss_q1    | 0.0437   |
# | loss_q2    | 0.0282   |
# | loss_q3    | 0.0417   |
# | mse        | 0.0728   |
# | mse_q0     | 0.0516   |
# | mse_q1     | 0.0437   |
# | mse_q2     | 0.0282   |
# | mse_q3     | 0.0417   |
# | param_norm | 79.4     |
# | samples    | 1.14e+06 |
# | step       | 8.9e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.86     |
# | loss       | 0.0624   |
# | loss_q0    | 0.0448   |
# | loss_q1    | 0.0555   |
# | loss_q2    | 0.0541   |
# | loss_q3    | 0.0732   |
# | mse        | 0.0624   |
# | mse_q0     | 0.0448   |
# | mse_q1     | 0.0555   |
# | mse_q2     | 0.0541   |
# | mse_q3     | 0.0732   |
# | param_norm | 79.4     |
# | samples    | 1.15e+06 |
# | step       | 9e+03    |
# -------------------------
# -------------------------
# | grad_norm  | 0.868    |
# | loss       | 0.0796   |
# | loss_q0    | 0.514    |
# | loss_q1    | 0.0482   |
# | loss_q2    | 0.0579   |
# | loss_q3    | 0.0421   |
# | mse        | 0.0796   |
# | mse_q0     | 0.514    |
# | mse_q1     | 0.0482   |
# | mse_q2     | 0.0579   |
# | mse_q3     | 0.0421   |
# | param_norm | 79.4     |
# | samples    | 1.16e+06 |
# | step       | 9.1e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.84     |
# | loss       | 0.0713   |
# | loss_q0    | 0.0464   |
# | loss_q1    | 0.0414   |
# | loss_q2    | 0.0374   |
# | loss_q3    | 0.0659   |
# | mse        | 0.0713   |
# | mse_q0     | 0.0464   |
# | mse_q1     | 0.0414   |
# | mse_q2     | 0.0374   |
# | mse_q3     | 0.0659   |
# | param_norm | 79.4     |
# | samples    | 1.18e+06 |
# | step       | 9.2e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.861    |
# | loss       | 0.0681   |
# | loss_q0    | 0.0525   |
# | loss_q1    | 0.0376   |
# | loss_q2    | 0.0566   |
# | loss_q3    | 0.118    |
# | mse        | 0.0681   |
# | mse_q0     | 0.0525   |
# | mse_q1     | 0.0376   |
# | mse_q2     | 0.0566   |
# | mse_q3     | 0.118    |
# | param_norm | 79.4     |
# | samples    | 1.19e+06 |
# | step       | 9.3e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.841    |
# | loss       | 0.066    |
# | loss_q0    | 0.175    |
# | loss_q1    | 0.0507   |
# | loss_q2    | 0.0679   |
# | loss_q3    | 0.0814   |
# | mse        | 0.066    |
# | mse_q0     | 0.175    |
# | mse_q1     | 0.0507   |
# | mse_q2     | 0.0679   |
# | mse_q3     | 0.0814   |
# | param_norm | 79.4     |
# | samples    | 1.2e+06  |
# | step       | 9.4e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.869    |
# | loss       | 0.0602   |
# | loss_q0    | 0.133    |
# | loss_q1    | 0.0425   |
# | loss_q2    | 0.0388   |
# | loss_q3    | 0.0407   |
# | mse        | 0.0602   |
# | mse_q0     | 0.133    |
# | mse_q1     | 0.0425   |
# | mse_q2     | 0.0388   |
# | mse_q3     | 0.0407   |
# | param_norm | 79.4     |
# | samples    | 1.22e+06 |
# | step       | 9.5e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.843    |
# | loss       | 0.0688   |
# | loss_q0    | 0.0572   |
# | loss_q1    | 0.0411   |
# | loss_q2    | 0.0438   |
# | loss_q3    | 0.0763   |
# | mse        | 0.0688   |
# | mse_q0     | 0.0572   |
# | mse_q1     | 0.0411   |
# | mse_q2     | 0.0438   |
# | mse_q3     | 0.0763   |
# | param_norm | 79.4     |
# | samples    | 1.23e+06 |
# | step       | 9.6e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.819    |
# | loss       | 0.0544   |
# | loss_q0    | 0.0515   |
# | loss_q1    | 0.0564   |
# | loss_q2    | 0.0564   |
# | loss_q3    | 0.0379   |
# | mse        | 0.0544   |
# | mse_q0     | 0.0515   |
# | mse_q1     | 0.0564   |
# | mse_q2     | 0.0564   |
# | mse_q3     | 0.0379   |
# | param_norm | 79.4     |
# | samples    | 1.24e+06 |
# | step       | 9.7e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.85     |
# | loss       | 0.0626   |
# | loss_q0    | 0.144    |
# | loss_q1    | 0.0411   |
# | loss_q2    | 0.0364   |
# | loss_q3    | 0.0405   |
# | mse        | 0.0626   |
# | mse_q0     | 0.144    |
# | mse_q1     | 0.0411   |
# | mse_q2     | 0.0364   |
# | mse_q3     | 0.0405   |
# | param_norm | 79.4     |
# | samples    | 1.25e+06 |
# | step       | 9.8e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.844    |
# | loss       | 0.0651   |
# | loss_q0    | 0.0449   |
# | loss_q1    | 0.0627   |
# | loss_q2    | 0.0531   |
# | loss_q3    | 0.0445   |
# | mse        | 0.0651   |
# | mse_q0     | 0.0449   |
# | mse_q1     | 0.0627   |
# | mse_q2     | 0.0531   |
# | mse_q3     | 0.0445   |
# | param_norm | 79.4     |
# | samples    | 1.27e+06 |
# | step       | 9.9e+03  |
# -------------------------
# -------------------------
# | grad_norm  | 0.857    |
# | loss       | 0.0717   |
# | loss_q0    | 0.0354   |
# | loss_q1    | 0.0473   |
# | loss_q2    | 0.0578   |
# | loss_q3    | 0.0609   |
# | mse        | 0.0717   |
# | mse_q0     | 0.0354   |
# | mse_q1     | 0.0473   |
# | mse_q2     | 0.0578   |
# | mse_q3     | 0.0609   |
# | param_norm | 79.4     |
# | samples    | 1.28e+06 |
# | step       | 1e+04    |
# -------------------------
# -------------------------
# | grad_norm  | 0.883    |
# | loss       | 0.0578   |
# | loss_q0    | 0.174    |
# | loss_q1    | 0.0534   |
# | loss_q2    | 0.0351   |
# | loss_q3    | 0.0483   |
# | mse        | 0.0578   |
# | mse_q0     | 0.174    |
# | mse_q1     | 0.0534   |
# | mse_q2     | 0.0351   |
# | mse_q3     | 0.0483   |
# | param_norm | 79.4     |
# | samples    | 1.29e+06 |
# | step       | 1.01e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.823    |
# | loss       | 0.0561   |
# | loss_q0    | 0.0414   |
# | loss_q1    | 0.0466   |
# | loss_q2    | 0.0374   |
# | loss_q3    | 0.0453   |
# | mse        | 0.0561   |
# | mse_q0     | 0.0414   |
# | mse_q1     | 0.0466   |
# | mse_q2     | 0.0374   |
# | mse_q3     | 0.0453   |
# | param_norm | 79.4     |
# | samples    | 1.31e+06 |
# | step       | 1.02e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.855    |
# | loss       | 0.0726   |
# | loss_q0    | 0.0537   |
# | loss_q1    | 0.046    |
# | loss_q2    | 0.0376   |
# | loss_q3    | 0.0351   |
# | mse        | 0.0726   |
# | mse_q0     | 0.0537   |
# | mse_q1     | 0.046    |
# | mse_q2     | 0.0376   |
# | mse_q3     | 0.0351   |
# | param_norm | 79.4     |
# | samples    | 1.32e+06 |
# | step       | 1.03e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.837    |
# | loss       | 0.0662   |
# | loss_q0    | 0.06     |
# | loss_q1    | 0.0484   |
# | loss_q2    | 0.0386   |
# | loss_q3    | 0.0319   |
# | mse        | 0.0662   |
# | mse_q0     | 0.06     |
# | mse_q1     | 0.0484   |
# | mse_q2     | 0.0386   |
# | mse_q3     | 0.0319   |
# | param_norm | 79.4     |
# | samples    | 1.33e+06 |
# | step       | 1.04e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.838    |
# | loss       | 0.0618   |
# | loss_q0    | 0.0688   |
# | loss_q1    | 0.0682   |
# | loss_q2    | 0.0564   |
# | loss_q3    | 0.0406   |
# | mse        | 0.0618   |
# | mse_q0     | 0.0688   |
# | mse_q1     | 0.0682   |
# | mse_q2     | 0.0564   |
# | mse_q3     | 0.0406   |
# | param_norm | 79.4     |
# | samples    | 1.34e+06 |
# | step       | 1.05e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.863    |
# | loss       | 0.0651   |
# | loss_q0    | 0.0495   |
# | loss_q1    | 0.0572   |
# | loss_q2    | 0.0427   |
# | loss_q3    | 0.0362   |
# | mse        | 0.0651   |
# | mse_q0     | 0.0495   |
# | mse_q1     | 0.0572   |
# | mse_q2     | 0.0427   |
# | mse_q3     | 0.0362   |
# | param_norm | 79.4     |
# | samples    | 1.36e+06 |
# | step       | 1.06e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.842    |
# | loss       | 0.0671   |
# | loss_q0    | 0.0459   |
# | loss_q1    | 0.0532   |
# | loss_q2    | 0.0496   |
# | loss_q3    | 0.0539   |
# | mse        | 0.0671   |
# | mse_q0     | 0.0459   |
# | mse_q1     | 0.0532   |
# | mse_q2     | 0.0496   |
# | mse_q3     | 0.0539   |
# | param_norm | 79.4     |
# | samples    | 1.37e+06 |
# | step       | 1.07e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.83     |
# | loss       | 0.0515   |
# | loss_q0    | 0.0395   |
# | loss_q1    | 0.035    |
# | loss_q2    | 0.035    |
# | loss_q3    | 0.0966   |
# | mse        | 0.0515   |
# | mse_q0     | 0.0395   |
# | mse_q1     | 0.035    |
# | mse_q2     | 0.035    |
# | mse_q3     | 0.0966   |
# | param_norm | 79.4     |
# | samples    | 1.38e+06 |
# | step       | 1.08e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.837    |
# | loss       | 0.0598   |
# | loss_q0    | 0.0821   |
# | loss_q1    | 0.0568   |
# | loss_q2    | 0.0308   |
# | loss_q3    | 0.0409   |
# | mse        | 0.0598   |
# | mse_q0     | 0.0821   |
# | mse_q1     | 0.0568   |
# | mse_q2     | 0.0308   |
# | mse_q3     | 0.0409   |
# | param_norm | 79.4     |
# | samples    | 1.4e+06  |
# | step       | 1.09e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.837    |
# | loss       | 0.0604   |
# | loss_q0    | 0.0349   |
# | loss_q1    | 0.0535   |
# | loss_q2    | 0.0641   |
# | loss_q3    | 0.0445   |
# | mse        | 0.0604   |
# | mse_q0     | 0.0349   |
# | mse_q1     | 0.0535   |
# | mse_q2     | 0.0641   |
# | mse_q3     | 0.0445   |
# | param_norm | 79.4     |
# | samples    | 1.41e+06 |
# | step       | 1.1e+04  |
# -------------------------
# -------------------------
# | grad_norm  | 0.868    |
# | loss       | 0.0642   |
# | loss_q0    | 0.0717   |
# | loss_q1    | 0.058    |
# | loss_q2    | 0.0417   |
# | loss_q3    | 0.0512   |
# | mse        | 0.0642   |
# | mse_q0     | 0.0717   |
# | mse_q1     | 0.058    |
# | mse_q2     | 0.0417   |
# | mse_q3     | 0.0512   |
# | param_norm | 79.4     |
# | samples    | 1.42e+06 |
# | step       | 1.11e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.849    |
# | loss       | 0.0633   |
# | loss_q0    | 0.0559   |
# | loss_q1    | 0.0311   |
# | loss_q2    | 0.0448   |
# | loss_q3    | 0.032    |
# | mse        | 0.0633   |
# | mse_q0     | 0.0559   |
# | mse_q1     | 0.0311   |
# | mse_q2     | 0.0448   |
# | mse_q3     | 0.032    |
# | param_norm | 79.5     |
# | samples    | 1.43e+06 |
# | step       | 1.12e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.846    |
# | loss       | 0.0518   |
# | loss_q0    | 0.0735   |
# | loss_q1    | 0.0414   |
# | loss_q2    | 0.0416   |
# | loss_q3    | 0.0396   |
# | mse        | 0.0518   |
# | mse_q0     | 0.0735   |
# | mse_q1     | 0.0414   |
# | mse_q2     | 0.0416   |
# | mse_q3     | 0.0396   |
# | param_norm | 79.5     |
# | samples    | 1.45e+06 |
# | step       | 1.13e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.834    |
# | loss       | 0.0585   |
# | loss_q0    | 0.0464   |
# | loss_q1    | 0.0368   |
# | loss_q2    | 0.0466   |
# | loss_q3    | 0.0519   |
# | mse        | 0.0585   |
# | mse_q0     | 0.0464   |
# | mse_q1     | 0.0368   |
# | mse_q2     | 0.0466   |
# | mse_q3     | 0.0519   |
# | param_norm | 79.5     |
# ...
# | mse_q3     | 0.0295   |
# | param_norm | 79.5     |
# | samples    | 2.06e+06 |
# | step       | 1.61e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.786    |
# | loss       | 0.0573   |
# | loss_q0    | 0.0689   |
# | loss_q1    | 0.0357   |
# | loss_q2    | 0.0333   |
# | loss_q3    | 0.0363   |
# | mse        | 0.0573   |
# | mse_q0     | 0.0689   |
# | mse_q1     | 0.0357   |
# | mse_q2     | 0.0333   |
# | mse_q3     | 0.0363   |
# | param_norm | 79.5     |
# | samples    | 2.07e+06 |
# | step       | 1.62e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.764    |
# | loss       | 0.0566   |
# | loss_q0    | 0.0373   |
# | loss_q1    | 0.0456   |
# | loss_q2    | 0.056    |
# | loss_q3    | 0.0391   |
# | mse        | 0.0566   |
# | mse_q0     | 0.0373   |
# | mse_q1     | 0.0456   |
# | mse_q2     | 0.056    |
# | mse_q3     | 0.0391   |
# | param_norm | 79.5     |
# | samples    | 2.09e+06 |
# | step       | 1.63e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.799    |
# | loss       | 0.0566   |
# | loss_q0    | 0.0304   |
# | loss_q1    | 0.0492   |
# | loss_q2    | 0.0534   |
# | loss_q3    | 0.0475   |
# | mse        | 0.0566   |
# | mse_q0     | 0.0304   |
# | mse_q1     | 0.0492   |
# | mse_q2     | 0.0534   |
# | mse_q3     | 0.0475   |
# | param_norm | 79.5     |
# | samples    | 2.1e+06  |
# | step       | 1.64e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.792    |
# | loss       | 0.0459   |
# | loss_q0    | 0.231    |
# | loss_q1    | 0.0393   |
# | loss_q2    | 0.038    |
# | loss_q3    | 0.0313   |
# | mse        | 0.0459   |
# | mse_q0     | 0.231    |
# | mse_q1     | 0.0393   |
# | mse_q2     | 0.038    |
# | mse_q3     | 0.0313   |
# | param_norm | 79.5     |
# | samples    | 2.11e+06 |
# | step       | 1.65e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.77     |
# | loss       | 0.042    |
# | loss_q0    | 0.0744   |
# | loss_q1    | 0.0265   |
# | loss_q2    | 0.0462   |
# | loss_q3    | 0.0401   |
# | mse        | 0.042    |
# | mse_q0     | 0.0744   |
# | mse_q1     | 0.0265   |
# | mse_q2     | 0.0462   |
# | mse_q3     | 0.0401   |
# | param_norm | 79.5     |
# | samples    | 2.12e+06 |
# | step       | 1.66e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.783    |
# | loss       | 0.0418   |
# | loss_q0    | 0.0301   |
# | loss_q1    | 0.0381   |
# | loss_q2    | 0.0407   |
# | loss_q3    | 0.0287   |
# | mse        | 0.0418   |
# | mse_q0     | 0.0301   |
# | mse_q1     | 0.0381   |
# | mse_q2     | 0.0407   |
# | mse_q3     | 0.0287   |
# | param_norm | 79.5     |
# | samples    | 2.14e+06 |
# | step       | 1.67e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.774    |
# | loss       | 0.0404   |
# | loss_q0    | 0.0427   |
# | loss_q1    | 0.0264   |
# | loss_q2    | 0.0364   |
# | loss_q3    | 0.0254   |
# | mse        | 0.0404   |
# | mse_q0     | 0.0427   |
# | mse_q1     | 0.0264   |
# | mse_q2     | 0.0364   |
# | mse_q3     | 0.0254   |
# | param_norm | 79.5     |
# | samples    | 2.15e+06 |
# | step       | 1.68e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.771    |
# | loss       | 0.0594   |
# | loss_q0    | 0.0925   |
# | loss_q1    | 0.0405   |
# | loss_q2    | 0.0414   |
# | loss_q3    | 0.0264   |
# | mse        | 0.0594   |
# | mse_q0     | 0.0925   |
# | mse_q1     | 0.0405   |
# | mse_q2     | 0.0414   |
# | mse_q3     | 0.0264   |
# | param_norm | 79.5     |
# | samples    | 2.16e+06 |
# | step       | 1.69e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.789    |
# | loss       | 0.052    |
# | loss_q0    | 0.806    |
# | loss_q1    | 0.0506   |
# | loss_q2    | 0.0334   |
# | loss_q3    | 0.0455   |
# | mse        | 0.052    |
# | mse_q0     | 0.806    |
# | mse_q1     | 0.0506   |
# | mse_q2     | 0.0334   |
# | mse_q3     | 0.0455   |
# | param_norm | 79.5     |
# | samples    | 2.18e+06 |
# | step       | 1.7e+04  |
# -------------------------
# -------------------------
# | grad_norm  | 0.765    |
# | loss       | 0.0402   |
# | loss_q0    | 0.0383   |
# | loss_q1    | 0.0309   |
# | loss_q2    | 0.0295   |
# | loss_q3    | 0.0296   |
# | mse        | 0.0402   |
# | mse_q0     | 0.0383   |
# | mse_q1     | 0.0309   |
# | mse_q2     | 0.0295   |
# | mse_q3     | 0.0296   |
# | param_norm | 79.5     |
# | samples    | 2.19e+06 |
# | step       | 1.71e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.788    |
# | loss       | 0.0554   |
# | loss_q0    | 0.0423   |
# | loss_q1    | 0.0294   |
# | loss_q2    | 0.0448   |
# | loss_q3    | 0.035    |
# | mse        | 0.0554   |
# | mse_q0     | 0.0423   |
# | mse_q1     | 0.0294   |
# | mse_q2     | 0.0448   |
# | mse_q3     | 0.035    |
# | param_norm | 79.5     |
# | samples    | 2.2e+06  |
# | step       | 1.72e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.759    |
# | loss       | 0.0506   |
# | loss_q0    | 0.301    |
# | loss_q1    | 0.032    |
# | loss_q2    | 0.0375   |
# | loss_q3    | 0.0367   |
# | mse        | 0.0506   |
# | mse_q0     | 0.301    |
# | mse_q1     | 0.032    |
# | mse_q2     | 0.0375   |
# | mse_q3     | 0.0367   |
# | param_norm | 79.5     |
# | samples    | 2.21e+06 |
# | step       | 1.73e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.766    |
# | loss       | 0.0459   |
# | loss_q0    | 0.0251   |
# | loss_q1    | 0.0263   |
# | loss_q2    | 0.0272   |
# | loss_q3    | 0.0329   |
# | mse        | 0.0459   |
# | mse_q0     | 0.0251   |
# | mse_q1     | 0.0263   |
# | mse_q2     | 0.0272   |
# | mse_q3     | 0.0329   |
# | param_norm | 79.5     |
# | samples    | 2.23e+06 |
# | step       | 1.74e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.758    |
# | loss       | 0.0663   |
# | loss_q0    | 0.395    |
# | loss_q1    | 0.0315   |
# | loss_q2    | 0.0295   |
# | loss_q3    | 0.0311   |
# | mse        | 0.0663   |
# | mse_q0     | 0.395    |
# | mse_q1     | 0.0315   |
# | mse_q2     | 0.0295   |
# | mse_q3     | 0.0311   |
# | param_norm | 79.5     |
# | samples    | 2.24e+06 |
# | step       | 1.75e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.761    |
# | loss       | 0.0502   |
# | loss_q0    | 0.272    |
# | loss_q1    | 0.0314   |
# | loss_q2    | 0.0238   |
# | loss_q3    | 0.0197   |
# | mse        | 0.0502   |
# | mse_q0     | 0.272    |
# | mse_q1     | 0.0314   |
# | mse_q2     | 0.0238   |
# | mse_q3     | 0.0197   |
# | param_norm | 79.5     |
# | samples    | 2.25e+06 |
# | step       | 1.76e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.765    |
# | loss       | 0.0545   |
# | loss_q0    | 0.0361   |
# | loss_q1    | 0.041    |
# | loss_q2    | 0.0357   |
# | loss_q3    | 0.0361   |
# | mse        | 0.0545   |
# | mse_q0     | 0.0361   |
# | mse_q1     | 0.041    |
# | mse_q2     | 0.0357   |
# | mse_q3     | 0.0361   |
# | param_norm | 79.5     |
# | samples    | 2.27e+06 |
# | step       | 1.77e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.765    |
# | loss       | 0.054    |
# | loss_q0    | 0.606    |
# | loss_q1    | 0.0376   |
# | loss_q2    | 0.0406   |
# | loss_q3    | 0.0346   |
# | mse        | 0.054    |
# | mse_q0     | 0.606    |
# | mse_q1     | 0.0376   |
# | mse_q2     | 0.0406   |
# | mse_q3     | 0.0346   |
# | param_norm | 79.5     |
# | samples    | 2.28e+06 |
# | step       | 1.78e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.749    |
# | loss       | 0.0407   |
# | loss_q0    | 0.0317   |
# | loss_q1    | 0.0272   |
# | loss_q2    | 0.0269   |
# | loss_q3    | 0.0352   |
# | mse        | 0.0407   |
# | mse_q0     | 0.0317   |
# | mse_q1     | 0.0272   |
# | mse_q2     | 0.0269   |
# | mse_q3     | 0.0352   |
# | param_norm | 79.5     |
# | samples    | 2.29e+06 |
# | step       | 1.79e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.755    |
# | loss       | 0.0409   |
# | loss_q0    | 0.057    |
# | loss_q1    | 0.0657   |
# | loss_q2    | 0.0289   |
# | loss_q3    | 0.0324   |
# | mse        | 0.0409   |
# | mse_q0     | 0.057    |
# | mse_q1     | 0.0657   |
# | mse_q2     | 0.0289   |
# | mse_q3     | 0.0324   |
# | param_norm | 79.5     |
# | samples    | 2.3e+06  |
# | step       | 1.8e+04  |
# -------------------------
# -------------------------
# | grad_norm  | 0.769    |
# | loss       | 0.0448   |
# | loss_q0    | 0.0339   |
# | loss_q1    | 0.024    |
# | loss_q2    | 0.0406   |
# | loss_q3    | 0.0523   |
# | mse        | 0.0448   |
# | mse_q0     | 0.0339   |
# | mse_q1     | 0.024    |
# | mse_q2     | 0.0406   |
# | mse_q3     | 0.0523   |
# | param_norm | 79.5     |
# | samples    | 2.32e+06 |
# | step       | 1.81e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.781    |
# | loss       | 0.0433   |
# | loss_q0    | 0.0406   |
# | loss_q1    | 0.0554   |
# | loss_q2    | 0.0363   |
# | loss_q3    | 0.041    |
# | mse        | 0.0433   |
# | mse_q0     | 0.0406   |
# | mse_q1     | 0.0554   |
# | mse_q2     | 0.0363   |
# | mse_q3     | 0.041    |
# | param_norm | 79.5     |
# | samples    | 2.33e+06 |
# | step       | 1.82e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.737    |
# | loss       | 0.0474   |
# | loss_q0    | 0.032    |
# | loss_q1    | 0.0226   |
# | loss_q2    | 0.0329   |
# | loss_q3    | 0.0444   |
# | mse        | 0.0474   |
# | mse_q0     | 0.032    |
# | mse_q1     | 0.0226   |
# | mse_q2     | 0.0329   |
# | mse_q3     | 0.0444   |
# | param_norm | 79.5     |
# | samples    | 2.34e+06 |
# | step       | 1.83e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.788    |
# | loss       | 0.0504   |
# | loss_q0    | 0.437    |
# | loss_q1    | 0.0341   |
# | loss_q2    | 0.0347   |
# | loss_q3    | 0.0314   |
# | mse        | 0.0504   |
# | mse_q0     | 0.437    |
# | mse_q1     | 0.0341   |
# | mse_q2     | 0.0347   |
# | mse_q3     | 0.0314   |
# | param_norm | 79.5     |
# | samples    | 2.36e+06 |
# | step       | 1.84e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.767    |
# | loss       | 0.0495   |
# | loss_q0    | 0.0373   |
# | loss_q1    | 0.0334   |
# | loss_q2    | 0.0376   |
# | loss_q3    | 0.032    |
# | mse        | 0.0495   |
# | mse_q0     | 0.0373   |
# | mse_q1     | 0.0334   |
# | mse_q2     | 0.0376   |
# | mse_q3     | 0.032    |
# | param_norm | 79.5     |
# | samples    | 2.37e+06 |
# | step       | 1.85e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.74     |
# | loss       | 0.052    |
# | loss_q0    | 0.0284   |
# | loss_q1    | 0.0334   |
# | loss_q2    | 0.0454   |
# | loss_q3    | 0.0328   |
# | mse        | 0.052    |
# | mse_q0     | 0.0284   |
# | mse_q1     | 0.0334   |
# | mse_q2     | 0.0454   |
# | mse_q3     | 0.0328   |
# | param_norm | 79.5     |
# | samples    | 2.38e+06 |
# | step       | 1.86e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.758    |
# | loss       | 0.0741   |
# | loss_q0    | 0.0384   |
# | loss_q1    | 0.0304   |
# | loss_q2    | 0.0317   |
# | loss_q3    | 0.0307   |
# | mse        | 0.0741   |
# | mse_q0     | 0.0384   |
# | mse_q1     | 0.0304   |
# | mse_q2     | 0.0317   |
# | mse_q3     | 0.0307   |
# | param_norm | 79.5     |
# | samples    | 2.39e+06 |
# | step       | 1.87e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.73     |
# | loss       | 0.0608   |
# | loss_q0    | 0.109    |
# | loss_q1    | 0.0358   |
# | loss_q2    | 0.0489   |
# | loss_q3    | 0.0272   |
# | mse        | 0.0608   |
# | mse_q0     | 0.109    |
# | mse_q1     | 0.0358   |
# | mse_q2     | 0.0489   |
# | mse_q3     | 0.0272   |
# | param_norm | 79.5     |
# | samples    | 2.41e+06 |
# | step       | 1.88e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.734    |
# | loss       | 0.0624   |
# | loss_q0    | 0.0368   |
# | loss_q1    | 0.0388   |
# | loss_q2    | 0.04     |
# | loss_q3    | 0.0361   |
# | mse        | 0.0624   |
# | mse_q0     | 0.0368   |
# | mse_q1     | 0.0388   |
# | mse_q2     | 0.04     |
# | mse_q3     | 0.0361   |
# | param_norm | 79.5     |
# | samples    | 2.42e+06 |
# | step       | 1.89e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.755    |
# | loss       | 0.0602   |
# | loss_q0    | 0.0493   |
# | loss_q1    | 0.0498   |
# | loss_q2    | 0.0229   |
# | loss_q3    | 0.0272   |
# | mse        | 0.0602   |
# | mse_q0     | 0.0493   |
# | mse_q1     | 0.0498   |
# | mse_q2     | 0.0229   |
# | mse_q3     | 0.0272   |
# | param_norm | 79.5     |
# | samples    | 2.43e+06 |
# | step       | 1.9e+04  |
# -------------------------
# -------------------------
# | grad_norm  | 0.736    |
# | loss       | 0.0681   |
# | loss_q0    | 0.025    |
# | loss_q1    | 0.0408   |
# | loss_q2    | 0.0279   |
# | loss_q3    | 0.0585   |
# | mse        | 0.0681   |
# | mse_q0     | 0.025    |
# | mse_q1     | 0.0408   |
# | mse_q2     | 0.0279   |
# | mse_q3     | 0.0585   |
# | param_norm | 79.5     |
# | samples    | 2.44e+06 |
# | step       | 1.91e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.752    |
# | loss       | 0.0561   |
# | loss_q0    | 0.0728   |
# | loss_q1    | 0.0308   |
# | loss_q2    | 0.0318   |
# | loss_q3    | 0.0431   |
# | mse        | 0.0561   |
# | mse_q0     | 0.0728   |
# | mse_q1     | 0.0308   |
# | mse_q2     | 0.0318   |
# | mse_q3     | 0.0431   |
# | param_norm | 79.5     |
# | samples    | 2.46e+06 |
# | step       | 1.92e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.734    |
# | loss       | 0.0626   |
# | loss_q0    | 0.0522   |
# | loss_q1    | 0.0233   |
# | loss_q2    | 0.0464   |
# | loss_q3    | 0.0275   |
# | mse        | 0.0626   |
# | mse_q0     | 0.0522   |
# | mse_q1     | 0.0233   |
# | mse_q2     | 0.0464   |
# | mse_q3     | 0.0275   |
# | param_norm | 79.5     |
# | samples    | 2.47e+06 |
# | step       | 1.93e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.763    |
# | loss       | 0.0559   |
# | loss_q0    | 0.0398   |
# | loss_q1    | 0.0292   |
# | loss_q2    | 0.0204   |
# | loss_q3    | 0.0213   |
# | mse        | 0.0559   |
# | mse_q0     | 0.0398   |
# | mse_q1     | 0.0292   |
# | mse_q2     | 0.0204   |
# | mse_q3     | 0.0213   |
# | param_norm | 79.5     |
# | samples    | 2.48e+06 |
# | step       | 1.94e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.726    |
# | loss       | 0.0547   |
# | loss_q0    | 0.0395   |
# | loss_q1    | 0.0355   |
# | loss_q2    | 0.0286   |
# | loss_q3    | 0.0301   |
# | mse        | 0.0547   |
# | mse_q0     | 0.0395   |
# | mse_q1     | 0.0355   |
# | mse_q2     | 0.0286   |
# | mse_q3     | 0.0301   |
# | param_norm | 79.5     |
# | samples    | 2.5e+06  |
# | step       | 1.95e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.726    |
# | loss       | 0.0577   |
# | loss_q0    | 0.0469   |
# | loss_q1    | 0.0573   |
# | loss_q2    | 0.0495   |
# | loss_q3    | 0.055    |
# | mse        | 0.0577   |
# | mse_q0     | 0.0469   |
# | mse_q1     | 0.0573   |
# | mse_q2     | 0.0495   |
# | mse_q3     | 0.055    |
# | param_norm | 79.5     |
# | samples    | 2.51e+06 |
# | step       | 1.96e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.739    |
# | loss       | 0.0575   |
# | loss_q0    | 0.0329   |
# | loss_q1    | 0.0241   |
# | loss_q2    | 0.0401   |
# | loss_q3    | 0.0306   |
# | mse        | 0.0575   |
# | mse_q0     | 0.0329   |
# | mse_q1     | 0.0241   |
# | mse_q2     | 0.0401   |
# | mse_q3     | 0.0306   |
# | param_norm | 79.5     |
# | samples    | 2.52e+06 |
# | step       | 1.97e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.706    |
# | loss       | 0.0514   |
# | loss_q0    | 0.445    |
# | loss_q1    | 0.0781   |
# | loss_q2    | 0.0446   |
# | loss_q3    | 0.036    |
# | mse        | 0.0514   |
# | mse_q0     | 0.445    |
# | mse_q1     | 0.0781   |
# | mse_q2     | 0.0446   |
# | mse_q3     | 0.036    |
# | param_norm | 79.5     |
# | samples    | 2.53e+06 |
# | step       | 1.98e+04 |
# -------------------------
# -------------------------
# | grad_norm  | 0.704    |
# | loss       | 0.0506   |
# | loss_q0    | 0.116    |
# | loss_q1    | 0.0367   |
# | loss_q2    | 0.0252   |
# | loss_q3    | 0.0404   |
# | mse        | 0.0506   |
# | mse_q0     | 0.116    |
# | mse_q1     | 0.0367   |
# | mse_q2     | 0.0252   |
# | mse_q3     | 0.0404   |
# | param_norm | 79.5     |
# | samples    | 2.55e+06 |
# | step       | 1.99e+04 |
# -------------------------
# saving model 0...
# saving model 0.9999...

# %%
device     = "cuda" if torch.cuda.is_available() else "cpu"
batch_size = 512
num_cells, num_genes = adata.shape

# %%
X = adata.X
if not isinstance(X, np.ndarray):
    X = X.toarray()

sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
X = adata.X
if not isinstance(X, np.ndarray):
    X = X.toarray()
# Out:
# WARNING: adata.X seems to be already log-transformed.

# %%
latent_dim = 128  

model = VAE(
    num_genes=num_genes,
    hidden_dim=latent_dim,
    device=device,
    seed=0,
    decoder_activation="ReLU",
)
state = torch.load('../models/scdiff/hem/VAE/model_seed=0_step=199999.pt', map_location=device)
model.load_state_dict(state)
model.to(device)
model.eval()
# Out:
# VAE(
#   (encoder): Encoder(
#     (network): ModuleList(
#       (0): Sequential(
#         (0): Dropout(p=0.0, inplace=False)
#         (1): Linear(in_features=2000, out_features=1024, bias=True)
#         (2): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): PReLU(num_parameters=1)
#       )
#       (1-2): 2 x Sequential(
#         (0): Dropout(p=0.0, inplace=False)
#         (1): Linear(in_features=1024, out_features=1024, bias=True)
#         (2): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): PReLU(num_parameters=1)
#       )
#       (3): Linear(in_features=1024, out_features=128, bias=True)
#     )
#   )
#   (decoder): Decoder(
#     (network): ModuleList(
#       (0): Sequential(
#         (0): Linear(in_features=128, out_features=1024, bias=True)
#         (1): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): PReLU(num_parameters=1)
#       )
#       (1-2): 2 x Sequential(
#         (0): Dropout(p=0.0, inplace=False)
#         (1): Linear(in_features=1024, out_features=1024, bias=True)
#         (2): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): PReLU(num_parameters=1)
#       )
#       (3): Linear(in_features=1024, out_features=2000, bias=True)
#     )
#   )
#   (loss_autoencoder): MSELoss()
# )

# %%
X_latent = np.zeros((num_cells, latent_dim), dtype=np.float32)

with torch.no_grad():
    for start in range(0, num_cells, batch_size):
        end = min(start + batch_size, num_cells)
        batch = torch.tensor(X[start:end], dtype=torch.float32, device=device)

        z = model.encoder(batch)    

        X_latent[start:end] = z.cpu().numpy()

# %% [markdown]
# ### Train the classifier

# %%
# !python ../src/scDiffusion/classifier_train.py \
  --data_dir '../data/hem_diff.h5ad' \
  --vae_path '../models/scdiff/hem/VAE/model_seed=0_step=199999.pt' \
  --model_path '../models/scdiff/hem/classifier/' \
  --num_class 3 \
  --batch_size 64 \
  --iterations 10000 \
  --lr 1e-3 \
  --weight_decay 0.0 \
  --log_interval 100 \
  --save_interval 1000 \
  --noised False
# Out:
# Logging to /tmp/openai-2025-12-11-12-28-45-390786
# creating model and diffusion...
# Running in single GPU mode without DDP
# creating data loader...
# creating optimizer...
# training classifier model...
# WARNING: adata.X seems to be already log-transformed.
# -----------------------------
# | grad_norm      | 3.04     |
# | param_norm     | 49.8     |
# | samples        | 64       |
# | step           | 0        |
# | train_acc@1    | 0.281    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 1.2      |
# | train_loss_q0  | 0.81     |
# -----------------------------
# -----------------------------
# | grad_norm      | 1.44     |
# | param_norm     | 50       |
# | samples        | 6.46e+03 |
# | step           | 100      |
# | train_acc@1    | 0.844    |
# | train_acc@1_q0 | 0        |
# | train_loss     | 0.492    |
# | train_loss_q0  | 1.24     |
# -----------------------------
# -----------------------------
# | grad_norm      | 1.27     |
# | param_norm     | 50.4     |
# | samples        | 1.29e+04 |
# | step           | 200      |
# | train_acc@1    | 0.812    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.327    |
# | train_loss_q0  | 0.0344   |
# -----------------------------
# -----------------------------
# | grad_norm      | 1.44     |
# | param_norm     | 51.2     |
# | samples        | 1.93e+04 |
# | step           | 300      |
# | train_acc@1    | 0.844    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.284    |
# | train_loss_q0  | 0.202    |
# -----------------------------
# -----------------------------
# | grad_norm      | 1.49     |
# | param_norm     | 52.4     |
# | samples        | 2.57e+04 |
# | step           | 400      |
# | train_acc@1    | 0.906    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.199    |
# | train_loss_q0  | 0.0914   |
# -----------------------------
# -----------------------------
# | grad_norm      | 1.54     |
# | param_norm     | 53.5     |
# | samples        | 3.21e+04 |
# | step           | 500      |
# | train_acc@1    | 0.828    |
# | train_acc@1_q0 | 0        |
# | train_loss     | 0.306    |
# | train_loss_q0  | 2.53     |
# -----------------------------
# -----------------------------
# | grad_norm      | 1.41     |
# | param_norm     | 54.8     |
# | samples        | 3.85e+04 |
# | step           | 600      |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0445   |
# | train_loss_q0  | 0.00127  |
# -----------------------------
# -----------------------------
# | grad_norm      | 1.37     |
# | param_norm     | 55.5     |
# | samples        | 4.49e+04 |
# | step           | 700      |
# | train_acc@1    | 0.953    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.127    |
# | train_loss_q0  | 0.000131 |
# -----------------------------
# -----------------------------
# | grad_norm      | 1.23     |
# | param_norm     | 56       |
# | samples        | 5.13e+04 |
# | step           | 800      |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0376   |
# | train_loss_q0  | 0.0315   |
# -----------------------------
# -----------------------------
# | grad_norm      | 1.29     |
# | param_norm     | 56.4     |
# | samples        | 5.77e+04 |
# | step           | 900      |
# | train_acc@1    | 0.984    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0553   |
# | train_loss_q0  | 0.0185   |
# -----------------------------
# -----------------------------
# | grad_norm      | 1        |
# | param_norm     | 56.9     |
# | samples        | 6.41e+04 |
# | step           | 1e+03    |
# | train_acc@1    | 0.984    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.112    |
# | train_loss_q0  | 0.000802 |
# -----------------------------
# saving model...
# -----------------------------
# | grad_norm      | 1.01     |
# | param_norm     | 57.7     |
# | samples        | 7.05e+04 |
# | step           | 1.1e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0327   |
# | train_loss_q0  | 0.00227  |
# -----------------------------
# -----------------------------
# | grad_norm      | 1.02     |
# | param_norm     | 58.9     |
# | samples        | 7.69e+04 |
# | step           | 1.2e+03  |
# | train_acc@1    | 0.984    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0173   |
# | train_loss_q0  | 8.75e-05 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.988    |
# | param_norm     | 59.3     |
# | samples        | 8.33e+04 |
# | step           | 1.3e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0231   |
# | train_loss_q0  | 0.00186  |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.905    |
# | param_norm     | 59.6     |
# | samples        | 8.97e+04 |
# | step           | 1.4e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0208   |
# | train_loss_q0  | 0.00178  |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.939    |
# | param_norm     | 60       |
# | samples        | 9.61e+04 |
# | step           | 1.5e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0064   |
# | train_loss_q0  | 7.59e-05 |
# -----------------------------
# -----------------------------
# | grad_norm      | 1.03     |
# | param_norm     | 60.3     |
# | samples        | 1.02e+05 |
# | step           | 1.6e+03  |
# | train_acc@1    | 0.984    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0586   |
# | train_loss_q0  | 0.000107 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.959    |
# | param_norm     | 60.8     |
# | samples        | 1.09e+05 |
# | step           | 1.7e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0162   |
# | train_loss_q0  | 0.00138  |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.854    |
# | param_norm     | 61.1     |
# | samples        | 1.15e+05 |
# | step           | 1.8e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00275  |
# | train_loss_q0  | 0.00139  |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.781    |
# | param_norm     | 61.5     |
# | samples        | 1.22e+05 |
# | step           | 1.9e+03  |
# | train_acc@1    | 0.984    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0985   |
# | train_loss_q0  | 0.00141  |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.815    |
# | param_norm     | 61.9     |
# | samples        | 1.28e+05 |
# | step           | 2e+03    |
# | train_acc@1    | 0.969    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0528   |
# | train_loss_q0  | 0.000441 |
# -----------------------------
# saving model...
# -----------------------------
# | grad_norm      | 0.77     |
# | param_norm     | 62.2     |
# | samples        | 1.34e+05 |
# | step           | 2.1e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0159   |
# | train_loss_q0  | 6.44e-06 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.702    |
# | param_norm     | 62.5     |
# | samples        | 1.41e+05 |
# | step           | 2.2e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0301   |
# | train_loss_q0  | 0.00173  |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.661    |
# | param_norm     | 62.9     |
# | samples        | 1.47e+05 |
# | step           | 2.3e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0135   |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.618    |
# | param_norm     | 63.8     |
# | samples        | 1.54e+05 |
# | step           | 2.4e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0216   |
# | train_loss_q0  | 0.00501  |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.676    |
# | param_norm     | 66       |
# | samples        | 1.6e+05  |
# | step           | 2.5e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0141   |
# | train_loss_q0  | 1.19e-07 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.742    |
# | param_norm     | 66.9     |
# | samples        | 1.66e+05 |
# | step           | 2.6e+03  |
# | train_acc@1    | 0.984    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0355   |
# | train_loss_q0  | 0.000424 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.797    |
# | param_norm     | 67.5     |
# | samples        | 1.73e+05 |
# | step           | 2.7e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00869  |
# | train_loss_q0  | 0.138    |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.567    |
# | param_norm     | 67.8     |
# | samples        | 1.79e+05 |
# | step           | 2.8e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.023    |
# | train_loss_q0  | 0.00192  |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.709    |
# | param_norm     | 68.1     |
# | samples        | 1.86e+05 |
# | step           | 2.9e+03  |
# | train_acc@1    | 0.984    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0207   |
# | train_loss_q0  | 4.68e-05 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.442    |
# | param_norm     | 68.3     |
# | samples        | 1.92e+05 |
# | step           | 3e+03    |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00222  |
# | train_loss_q0  | 4.77e-07 |
# -----------------------------
# saving model...
# -----------------------------
# | grad_norm      | 0.687    |
# | param_norm     | 68.6     |
# | samples        | 1.98e+05 |
# | step           | 3.1e+03  |
# | train_acc@1    | 0.984    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0328   |
# | train_loss_q0  | 8.46e-05 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.803    |
# | param_norm     | 69       |
# | samples        | 2.05e+05 |
# | step           | 3.2e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0189   |
# | train_loss_q0  | 4.53e-06 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.697    |
# | param_norm     | 69.9     |
# | samples        | 2.11e+05 |
# | step           | 3.3e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.000453 |
# | train_loss_q0  | 6.82e-05 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.858    |
# | param_norm     | 70.8     |
# | samples        | 2.18e+05 |
# | step           | 3.4e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00395  |
# | train_loss_q0  | 2.8e-05  |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.694    |
# | param_norm     | 71.4     |
# | samples        | 2.24e+05 |
# | step           | 3.5e+03  |
# | train_acc@1    | 0.984    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0217   |
# | train_loss_q0  | 6.32e-06 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.603    |
# | param_norm     | 71.7     |
# | samples        | 2.3e+05  |
# | step           | 3.6e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00104  |
# | train_loss_q0  | 0.000829 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.368    |
# | param_norm     | 71.9     |
# | samples        | 2.37e+05 |
# | step           | 3.7e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00275  |
# | train_loss_q0  | 7.87e-06 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.381    |
# | param_norm     | 72.1     |
# | samples        | 2.43e+05 |
# | step           | 3.8e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.021    |
# | train_loss_q0  | 0.000161 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.371    |
# | param_norm     | 72.2     |
# | samples        | 2.5e+05  |
# | step           | 3.9e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00273  |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.486    |
# | param_norm     | 72.4     |
# | samples        | 2.56e+05 |
# | step           | 4e+03    |
# | train_acc@1    | 0.984    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0579   |
# | train_loss_q0  | 0.000822 |
# -----------------------------
# saving model...
# -----------------------------
# | grad_norm      | 0.618    |
# | param_norm     | 72.8     |
# | samples        | 2.62e+05 |
# | step           | 4.1e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.000392 |
# | train_loss_q0  | 1.19e-07 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.564    |
# | param_norm     | 73.1     |
# | samples        | 2.69e+05 |
# | step           | 4.2e+03  |
# | train_acc@1    | 0.984    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0215   |
# | train_loss_q0  | 0.0365   |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.38     |
# | param_norm     | 73.3     |
# | samples        | 2.75e+05 |
# | step           | 4.3e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00034  |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.437    |
# | param_norm     | 73.5     |
# | samples        | 2.82e+05 |
# | step           | 4.4e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00276  |
# | train_loss_q0  | 3.58e-07 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.521    |
# | param_norm     | 73.8     |
# | samples        | 2.88e+05 |
# | step           | 4.5e+03  |
# | train_acc@1    | 0.984    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0198   |
# | train_loss_q0  | 1.86e-05 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.661    |
# | param_norm     | 74.2     |
# | samples        | 2.94e+05 |
# | step           | 4.6e+03  |
# | train_acc@1    | 0.969    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0795   |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.546    |
# | param_norm     | 74.7     |
# | samples        | 3.01e+05 |
# | step           | 4.7e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00123  |
# | train_loss_q0  | 8.34e-07 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.509    |
# | param_norm     | 75.1     |
# | samples        | 3.07e+05 |
# | step           | 4.8e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00194  |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.478    |
# | param_norm     | 75.4     |
# | samples        | 3.14e+05 |
# | step           | 4.9e+03  |
# | train_acc@1    | 0.969    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0745   |
# | train_loss_q0  | 0.000136 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.462    |
# | param_norm     | 75.8     |
# | samples        | 3.2e+05  |
# | step           | 5e+03    |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00199  |
# | train_loss_q0  | 0.000859 |
# -----------------------------
# saving model...
# -----------------------------
# | grad_norm      | 0.309    |
# | param_norm     | 76       |
# | samples        | 3.26e+05 |
# | step           | 5.1e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.000467 |
# | train_loss_q0  | 0.00074  |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.324    |
# | param_norm     | 76.2     |
# | samples        | 3.33e+05 |
# | step           | 5.2e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00106  |
# | train_loss_q0  | 2.38e-07 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.297    |
# | param_norm     | 76.4     |
# | samples        | 3.39e+05 |
# | step           | 5.3e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00147  |
# | train_loss_q0  | 0.000184 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.552    |
# | param_norm     | 76.8     |
# | samples        | 3.46e+05 |
# | step           | 5.4e+03  |
# | train_acc@1    | 0.984    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0662   |
# | train_loss_q0  | 1.19e-07 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.482    |
# | param_norm     | 77.6     |
# | samples        | 3.52e+05 |
# | step           | 5.5e+03  |
# | train_acc@1    | 0.984    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0422   |
# | train_loss_q0  | 1.19e-07 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.296    |
# | param_norm     | 78.1     |
# | samples        | 3.58e+05 |
# | step           | 5.6e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00153  |
# | train_loss_q0  | 1.19e-07 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.487    |
# | param_norm     | 78.7     |
# | samples        | 3.65e+05 |
# | step           | 5.7e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00526  |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.603    |
# | param_norm     | 79.9     |
# | samples        | 3.71e+05 |
# | step           | 5.8e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00576  |
# | train_loss_q0  | 0.00179  |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.418    |
# | param_norm     | 81.6     |
# | samples        | 3.78e+05 |
# | step           | 5.9e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00642  |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.553    |
# | param_norm     | 82.3     |
# | samples        | 3.84e+05 |
# | step           | 6e+03    |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00312  |
# | train_loss_q0  | 0.00255  |
# -----------------------------
# saving model...
# -----------------------------
# | grad_norm      | 0.399    |
# | param_norm     | 82.7     |
# | samples        | 3.9e+05  |
# | step           | 6.1e+03  |
# | train_acc@1    | 0.984    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0366   |
# | train_loss_q0  | 4.05e-06 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.377    |
# | param_norm     | 83       |
# | samples        | 3.97e+05 |
# | step           | 6.2e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.000688 |
# | train_loss_q0  | 0.000475 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.428    |
# | param_norm     | 83.2     |
# | samples        | 4.03e+05 |
# | step           | 6.3e+03  |
# | train_acc@1    | 0.984    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.021    |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.389    |
# | param_norm     | 83.5     |
# | samples        | 4.1e+05  |
# | step           | 6.4e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00302  |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.355    |
# | param_norm     | 83.8     |
# | samples        | 4.16e+05 |
# | step           | 6.5e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00407  |
# | train_loss_q0  | 2.38e-07 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.402    |
# | param_norm     | 84.1     |
# | samples        | 4.22e+05 |
# | step           | 6.6e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00456  |
# | train_loss_q0  | 3.35e-05 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.331    |
# | param_norm     | 84.4     |
# | samples        | 4.29e+05 |
# | step           | 6.7e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00712  |
# | train_loss_q0  | 8.23e-06 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.314    |
# | param_norm     | 84.6     |
# | samples        | 4.35e+05 |
# | step           | 6.8e+03  |
# | train_acc@1    | 0.969    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0861   |
# | train_loss_q0  | 0.00171  |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.345    |
# | param_norm     | 84.9     |
# | samples        | 4.42e+05 |
# | step           | 6.9e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00137  |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.343    |
# | param_norm     | 85.2     |
# | samples        | 4.48e+05 |
# | step           | 7e+03    |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00109  |
# | train_loss_q0  | 5.96e-07 |
# -----------------------------
# saving model...
# -----------------------------
# | grad_norm      | 0.38     |
# | param_norm     | 85.5     |
# | samples        | 4.54e+05 |
# | step           | 7.1e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00606  |
# | train_loss_q0  | 2.5e-06  |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.233    |
# | param_norm     | 85.7     |
# | samples        | 4.61e+05 |
# | step           | 7.2e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.000147 |
# | train_loss_q0  | 1.19e-07 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.279    |
# | param_norm     | 86       |
# | samples        | 4.67e+05 |
# | step           | 7.3e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00175  |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.286    |
# | param_norm     | 86.2     |
# | samples        | 4.74e+05 |
# | step           | 7.4e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.000634 |
# | train_loss_q0  | 4.17e-06 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.298    |
# | param_norm     | 86.5     |
# | samples        | 4.8e+05  |
# | step           | 7.5e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00047  |
# | train_loss_q0  | 4.84e-05 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.358    |
# | param_norm     | 86.7     |
# | samples        | 4.86e+05 |
# | step           | 7.6e+03  |
# | train_acc@1    | 0.984    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0277   |
# | train_loss_q0  | 1.61e-05 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.515    |
# | param_norm     | 87.1     |
# | samples        | 4.93e+05 |
# | step           | 7.7e+03  |
# | train_acc@1    | 0.984    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0208   |
# | train_loss_q0  | 3.58e-07 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.312    |
# | param_norm     | 87.5     |
# | samples        | 4.99e+05 |
# | step           | 7.8e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00754  |
# | train_loss_q0  | 5.96e-07 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.417    |
# | param_norm     | 87.8     |
# | samples        | 5.06e+05 |
# | step           | 7.9e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00557  |
# | train_loss_q0  | 0.0626   |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.421    |
# | param_norm     | 88.3     |
# | samples        | 5.12e+05 |
# | step           | 8e+03    |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00622  |
# | train_loss_q0  | -0       |
# -----------------------------
# saving model...
# -----------------------------
# | grad_norm      | 0.487    |
# | param_norm     | 88.8     |
# | samples        | 5.18e+05 |
# | step           | 8.1e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0016   |
# | train_loss_q0  | 1.16e-05 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.293    |
# | param_norm     | 89.2     |
# | samples        | 5.25e+05 |
# | step           | 8.2e+03  |
# | train_acc@1    | 0.984    |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.012    |
# | train_loss_q0  | 2.5e-06  |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.224    |
# | param_norm     | 89.4     |
# | samples        | 5.31e+05 |
# | step           | 8.3e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00337  |
# | train_loss_q0  | 6.43e-05 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.163    |
# | param_norm     | 89.5     |
# | samples        | 5.38e+05 |
# | step           | 8.4e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.000386 |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.221    |
# | param_norm     | 89.8     |
# | samples        | 5.44e+05 |
# | step           | 8.5e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00882  |
# | train_loss_q0  | 6.32e-06 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.23     |
# | param_norm     | 89.9     |
# | samples        | 5.5e+05  |
# | step           | 8.6e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00193  |
# | train_loss_q0  | 2.38e-07 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.226    |
# | param_norm     | 90.1     |
# | samples        | 5.57e+05 |
# | step           | 8.7e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0094   |
# | train_loss_q0  | 5.36e-06 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.304    |
# | param_norm     | 90.4     |
# | samples        | 5.63e+05 |
# | step           | 8.8e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00532  |
# | train_loss_q0  | 4.05e-06 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.292    |
# | param_norm     | 90.7     |
# | samples        | 5.7e+05  |
# | step           | 8.9e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.000172 |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.237    |
# | param_norm     | 90.9     |
# | samples        | 5.76e+05 |
# | step           | 9e+03    |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00196  |
# | train_loss_q0  | 1.19e-07 |
# -----------------------------
# saving model...
# -----------------------------
# | grad_norm      | 0.315    |
# | param_norm     | 91.1     |
# | samples        | 5.82e+05 |
# | step           | 9.1e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00215  |
# | train_loss_q0  | 0.00107  |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.452    |
# | param_norm     | 91.5     |
# | samples        | 5.89e+05 |
# | step           | 9.2e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00266  |
# | train_loss_q0  | 6.32e-06 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.33     |
# | param_norm     | 91.9     |
# | samples        | 5.95e+05 |
# | step           | 9.3e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00846  |
# | train_loss_q0  | 1.19e-07 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.245    |
# | param_norm     | 92.2     |
# | samples        | 6.02e+05 |
# | step           | 9.4e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.000701 |
# | train_loss_q0  | 7.87e-06 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.352    |
# | param_norm     | 92.5     |
# | samples        | 6.08e+05 |
# | step           | 9.5e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.0138   |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.428    |
# | param_norm     | 93       |
# | samples        | 6.14e+05 |
# | step           | 9.6e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.000649 |
# | train_loss_q0  | -0       |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.265    |
# | param_norm     | 93.4     |
# | samples        | 6.21e+05 |
# | step           | 9.7e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.000689 |
# | train_loss_q0  | 0.0058   |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.227    |
# | param_norm     | 93.6     |
# | samples        | 6.27e+05 |
# | step           | 9.8e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00327  |
# | train_loss_q0  | 0.000187 |
# -----------------------------
# -----------------------------
# | grad_norm      | 0.236    |
# | param_norm     | 93.7     |
# | samples        | 6.34e+05 |
# | step           | 9.9e+03  |
# | train_acc@1    | 1        |
# | train_acc@1_q0 | 1        |
# | train_loss     | 0.00585  |
# | train_loss_q0  | -0       |
# -----------------------------
# saving model...

# %% [markdown]
# ### Generate Trajectory

# %%
# !python ../src/scDiffusion/classifier_sample.py
# Out:
# Logging to /tmp/openai-2025-12-11-12-38-19-306520
# creating model and diffusion...
# loading classifier...
# WARNING: adata.X seems to be already log-transformed.
# sampling...
# step  0
# step  200
# step  400
# step  600
# step  800
# created 128 samples
# step  0
# step  200
# step  400
# step  600
# step  800
# created 256 samples
# Saved 256 cells to ../data/generated/interpolation_0.npz
# sampling complete

# %%
data = np.load("../data/generated/interpolation_0.npz")

print(data.files)
# Out:
# ['cell_gen']

# %%
Z_interp = data["cell_gen"]

# %%
with torch.no_grad():
    z_t = torch.tensor(Z_interp, dtype=torch.float32, device=device)

    X_syn = model.decoder(z_t)

    X_syn = X_syn.cpu().numpy()

# %%
adata_interpolated_cells = anndata.AnnData(X_syn)

# %%
adata_interpolated_cells.var_names = adata.var_names
adata_interpolated_cells.obs['cell_type'] = 'Interpolated'

# %%
combined_adata = combine_adatas(adata, adata_interpolated_cells)

# %%
plot_umap(combined_adata, 'cell_type')
# Out:
# /mnt/home/islamsa3/anaconda3/envs/global/lib/python3.10/site-packages/scanpy/neighbors/__init__.py:577: UserWarning: You’re trying to run this on 2000 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
#   x = _choose_representation(self._adata, use_rep=use_rep, n_pcs=n_pcs)

# %%
hsc_markers = ['THY1', 'KIT', 'GATA2']
cmp_markers = ['TFRC', 'KIT', 'IRF8']
gmp_markers = ['CEBPA', 'CEBPD', 'MPO']

gene_names = adata.var['gene_short_name'].values if 'gene_short_name' in adata.var else adata.var_names.values

available_hsc = [g for g in hsc_markers if g in gene_names]
available_cmp = [g for g in cmp_markers if g in gene_names]
available_gmp = [g for g in gmp_markers if g in gene_names]

print(f"Available hsc markers: {available_hsc}")
print(f"Available cmp markers: {available_cmp}")
print(f"Available gmp markers: {available_gmp}")

if available_hsc or available_cmp or available_gmp:
    n_markers = len(available_hsc) + len(available_cmp) + len(available_gmp)
    n_cols = 3
    n_rows = 3
    
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(5*n_cols, 6*n_rows))
    axes = axes.flatten() if n_markers > 1 else [axes]
    
    pseudotime = np.linspace(0,1,256)
    
    plot_idx = 0
    for gene in available_hsc:
        gene_idx = np.where(gene_names == gene)[0][0]
        expression = X_syn[:, gene_idx]
        
        ax = axes[plot_idx]
        ax.scatter(pseudotime, expression, c=pseudotime, cmap='viridis', s=10, alpha=0.6)
        ax.plot(pseudotime, expression, 'k-', alpha=0.3, linewidth=0.5)
        ax.set_xlabel('Pseudotime')
        ax.set_ylabel('Expression')
        ax.set_title(f'{gene} (HSC)', fontsize=10)
        plot_idx += 1
    
    for gene in available_cmp:
        gene_idx = np.where(gene_names == gene)[0][0]
        expression = X_syn[:, gene_idx]
        
        ax = axes[plot_idx]
        ax.scatter(pseudotime, expression, c=pseudotime, cmap='viridis', s=10, alpha=0.6)
        ax.plot(pseudotime, expression, 'k-', alpha=0.3, linewidth=0.5)
        ax.set_xlabel('Pseudotime')
        ax.set_ylabel('Expression')
        ax.set_title(f'{gene} (CMP)', fontsize=10)
        plot_idx += 1

    for gene in available_gmp:
        gene_idx = np.where(gene_names == gene)[0][0]
        expression = X_syn[:, gene_idx]
        
        ax = axes[plot_idx]
        ax.scatter(pseudotime, expression, c=pseudotime, cmap='viridis', s=10, alpha=0.6)
        ax.plot(pseudotime, expression, 'k-', alpha=0.3, linewidth=0.5)
        ax.set_xlabel('Pseudotime')
        ax.set_ylabel('Expression')
        ax.set_title(f'{gene} (GMP)', fontsize=10)
        plot_idx += 1
    
    for i in range(plot_idx, len(axes)):
        axes[i].set_visible(False)
    
    plt.tight_layout()
    plt.show()
else:
    print("No common markers found in the dataset")
# Out:
# Available hsc markers: ['THY1', 'KIT', 'GATA2']
# Available cmp markers: ['TFRC', 'KIT', 'IRF8']
# Available gmp markers: ['CEBPA', 'CEBPD', 'MPO']

# %%
original_labels = adata.obs['cell_type'].values
interpolated_labels = np.array(['Interpolated'] * len(adata_interpolated_cells))

combined_latent = np.vstack([X_latent, Z_interp])
combined_labels = np.concatenate([original_labels, interpolated_labels])

pca = PCA(n_components=2, random_state=42)
latent_pca = pca.fit_transform(combined_latent)


unique_labels = np.unique(combined_labels)

unique_colors = plt.cm.tab10(np.linspace(0, 1, len(unique_labels)))
palette = {label: unique_colors[i] for i, label in enumerate(unique_labels)}

for i, label in enumerate(unique_labels):
    mask = combined_labels == label
    plt.scatter(
        latent_pca[mask, 0], 
        latent_pca[mask, 1],
        color=palette[label],
        label=label,
        alpha=0.7,
        s=50 if label == 'interpolated' else 80,
        #edgecolors='w',
        linewidths=0.5
    )

plt.title('PCA of Latent Representations', fontsize=18)
plt.legend(fontsize=18)
plt.tight_layout()

# %%
adata_latent_syn = anndata.AnnData(Z_interp)
adata_latent_syn.obs["cell_type"] = "Interpolated"
adata_new = anndata.AnnData(
    X=X_latent,
    obs=adata.obs[['cell_type']].copy()
)
combined_adata_latent = combine_adatas(adata_new, adata_latent_syn)
plot_umap(combined_adata_latent, "cell_type")
# Out:
# /mnt/home/islamsa3/anaconda3/envs/global/lib/python3.10/site-packages/scanpy/neighbors/__init__.py:577: UserWarning: You’re trying to run this on 128 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
#   x = _choose_representation(self._adata, use_rep=use_rep, n_pcs=n_pcs)

# %%
pt_df, pt_summary = evaluate_pseudotime_distance_error(
    X_syn,
    np.linspace(0, 1, 256),
    adata,
    list(gene_names),
    real_pseudotime_key="dpt_pseudotime",
)

print(pt_summary)
pt_df.head()
# Out:
# {'delta_t_mean': 0.43433365821267717, 'delta_t_median': 0.4187405916259569, 'delta_t_max': 0.9509079232811928, 'dist_mean': 47.70890688896179, 'dist_median': 44.432064056396484, 'dist_max': 121.3682861328125}
#       alpha  nearest_pseudotime   delta_t  dist_to_nearest
# 0  0.000000            0.198145  0.198145        59.452908
# 1  0.003922            0.063163  0.059242        37.422665
# 2  0.007843            0.032204  0.024360        59.325420
# 3  0.011765            0.024571  0.012806        64.932678
# 4  0.015686            0.063163  0.047477        36.812405

# %%
dist_series, dist_summary = evaluate_distance_to_manifold_smoothness(
    X_syn,
    adata,
    list(gene_names),
)

print(dist_summary)
# Out:
# {'dist_mean': 47.70890688896179, 'dist_median': 44.432064056396484, 'dist_max': 121.3682861328125, 'smooth_mean_abs_delta': 13.226764140409582, 'smooth_max_abs_delta': 71.15005874633789}

# %%
marker_sets = {
    "HSC": ['THY1', 'KIT', 'GATA2'],
    "CMP": ['TFRC', 'KIT', 'IRF8'],
    "GMP": ['CEBPA', 'CEBPD', 'MPO']
}

expected_directions = {
    "HSC": -1,   
    "CMP": 1,   
    "GMP": 1,   
}


df_markers, summary_markers = evaluate_marker_monotonicity_general(
    X_syn=X_syn,
    traj_coord=np.linspace(0, 1, 256),      
    gene_list=list(gene_names),
    marker_sets=marker_sets,
    expected_directions=expected_directions,

)

print(summary_markers)
df_markers.head()
# Out:
#   group  n_genes  mean_rho  median_rho  frac_sign_ok
# 0   CMP        3  0.005045    0.024479      0.666667
# 1   GMP        3 -0.019645   -0.024888      0.333333
# 2   HSC        3 -0.067230   -0.063046      1.000000
#   group   gene       rho      pval  expected_dir  sign_ok
# 0   HSC   THY1 -0.063046  0.314995            -1     True
# 1   HSC    KIT -0.040639  0.517436            -1     True
# 2   HSC  GATA2 -0.098007  0.117771            -1     True
# 3   CMP   TFRC  0.024479  0.696685             1     True
# 4   CMP    KIT -0.040639  0.517436             1    False

# %%
adata_interpolated_cells.write_h5ad('../data/syn_hem_scdiff.h5ad')
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
